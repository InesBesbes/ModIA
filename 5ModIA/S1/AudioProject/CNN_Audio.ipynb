# %%
import librosa
import numpy as np
import scipy

# %%
y, sr = librosa.load("./clips/spain_H_1.mp3", sr=None)

# %%
sr
# Out:
# 48000

# %%
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

# %%
mfccs
# Out:
# array([[-6.52328552e+02, -6.52328552e+02, -6.52328552e+02, ...,
#         -3.90862152e+02, -3.75992065e+02, -3.67610657e+02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          1.82605942e+02,  1.89811142e+02,  1.98754364e+02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          4.84089355e+01,  5.41206512e+01,  5.30126152e+01],
#        ...,
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.65726471e+00, -2.46236324e+00, -1.23497105e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -1.41868753e+01, -1.71574211e+01, -1.56984215e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.45099425e-01, -8.08836555e+00, -1.16439791e+01]], dtype=float32)
