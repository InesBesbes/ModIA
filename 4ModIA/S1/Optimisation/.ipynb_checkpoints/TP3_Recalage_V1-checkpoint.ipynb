# %% [markdown]
# TP- Recalage d'images
# =============

# %%
import numpy as np
from scipy import signal
from scipy import interpolate
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# Un problème fréquemment rencontré dans le domaine du traitement d’images est celui du recalage. On dispose de plusieurs images prises à des temps différents, ou par des appareils différents, et on aimerait les mettre en correspondence, c’est-à-dire trouver une déformation du plan, qui assure une correspondence point à point des objets sous-jacents. Donnons quelques exemples d’applications :
# * Traitements/retouches d’images. Par exemple, on peut vouloir construire un panoramique à partir d’images de petite taille. Il faut les recaler préalablement.
# * Evaluation des déplacements d’objets dans des séquences vidéos (e.g. trouver un défaut de fonctionnement d’un organe, caméras de surveillance, design de robots intelligents ou de systèmes de navigation automatiques ...)
# * Couplage d’informations. Par exemple, en imagerie médicale, on obtient une information plus riche en utilisant à la fois une radio et une angiographie. L’une apporte des informations structurelles, l’autre des informations fonctionnelles. Le couplage des deux images donne plus d’information au praticien.
# * Beaucoup d’autres applications...
#
# Dans ce TP, nous allons proposer un modèle de recalage assez élémentaire. Les idées constitutives se retrouvent cependant dans presque toutes les techniques récentes.

# %%
def get_images() :
    n=21
    sigma=0.3
    [X,Y]=np.meshgrid(np.linspace(-1,1,n),np.linspace(-1,1,n), indexing='xy')
    Z=np.sqrt(X*X+Y*Y)
    im1=np.zeros((n,n))
    im1[Z<=.7]=1.
    im1[Z<=.3]=.5
    im1[Z<=.1]=.7
    im2=np.zeros((n,n));
    Z=np.sqrt((X-.3)**2+(Y+.2)**2)
    im2[Z<=.7]=1
    im2[Z<=.3]=.5
    im2[Z<=.1]=.7
    G=np.fft.fftshift(np.exp(-(X**2+Y**2)/sigma**2))
    f=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im1)))
    g=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im2))) 
    f=f/np.max(f)
    g=g/np.max(g)
    return f,g,im1,im2

# %%
f,g,im1,im2=get_images()
fig, axarr = plt.subplots(2, 2, figsize=(10,10))
axarr[0,0].imshow(im1)
axarr[0,0].set_title('Image im1')
axarr[1,0].imshow(f)
axarr[1,0].set_title('function f ( blurry version of im1)')
axarr[0,1].imshow(im2)
axarr[0,1].set_title('Image im2')
axarr[1,1].imshow(g)
axarr[1,1].set_title('function g ( blurry version of im2)')
plt.show()

# %% [markdown]
# # 1. Formalisation du problème
# ## 1.1 Formalisme continu
#
# On modélise les images en niveaux de gris comme des fonctions d’un ensemble borné $\Omega\subset \mathbb{R}$ (typiquement un carré) dans $\mathbb{R}$. La valeur de la fonction en chaque point représente l’intensité lumineuse de l’image.
#
# Soient $f$ et $g$ deux images. On a donc :
# $$
# f:\Omega\subset \mathbb{R}^2 \to \mathbb{R},  g:\Omega\subset \mathbb{R}^2 \to \mathbb{R}
# $$
# En supposant que les images $f$ et $g$ dépendent seulement d’une transformation géométrique qui conserve la luminosité, le problème de recalage peut être formulé comme suit:
#
# <div style="background-color:rgba(0, 0, 255, 0.1); padding:15px;margin:5px">
# Problème $(P_1)$ : <br>
# Etant donnés $f$ et $g$ dans $H_1(\Omega)$ (les images ont une amplitude bornée et une énergie finie), trouver un champ de vecteurs $u = (u_1, u_2) \in H_1(\Omega)^2$ tel que:
# $$f(x + u(x)) = g(x), \forall x\in \Omega.$$
# </div>
#
# Le problème inverse est mal posé: tout d'abord, l'existence d'une solution n'est pas garantie, et dans le cas où il existe une solution, on n'a pas nécessairement unicité de cette solution. Par exemple, si $f$ et $g$ sont des fonctions constantes, n'importe quel déplacement $u$ est solution. Si $f$ est la constante $1$ et si $g$ est la constante $0$, il n'existe pas de solutions.
#
# Pour le résoudre, on se propose de le reformuler comme un problème d'optimisation:
#
# <div style="background-color:rgba(0, 0, 255, 0.1); padding:15px;margin:5px">
# Problème $(P_2)$ : <br>
# On cherche une déformation $u$ du plan qui minimise:
# $$
# E(u)=\displaystyle\frac{1}{2}\int_\Omega (f(x+u(x))-g(x))^2 dx=\frac{1}{2}\|f\circ (id+u)-g\|^2.
# $$
# </div>
#
# Sans hypothèse supplémentaire, le problème $\displaystyle \min_{u \in H^1(\Omega)^2} E(u)$ n'est a priori pas convexe, toujours mal posé et même éventuellement non différentiable si $u$ et $f$ ne sont pas assez régulières. On pourrait facilement rendre $f$ différentiable (en ajoutant du flou (on dit aussi du "bruit") par exemple à l'image, ce qui revient à convoler $f$ avec une gaussienne) mais il faut également "forcer" $u$ à être différentiable. Pour cela on propose de régulariser le problème de façon à assurer la convexité du problème d'optimisation considéré ainsi que l'existence et l'unicité des solutions.
#
# Pour régulariser le problème inverse, nous allons faire une analogie avec l’élasticité linéaire. La fonction $u = (u_x,u_y)$ représente un champ de déformations. En notant $\partial x$ et $\partial y$ les opérateurs de dérivation partielle par rapport à chacun des axes du plan, on peut définir un potentiel élastique linéarisé :
# $$
# R(u)= \frac{\mu}{2}\int_{\Omega} \underbrace{ (\partial_x u_y + \partial_y u_x)^2(x,y) dxdy}_{R_1(u)=\textrm{cisaillement}} +\frac{\lambda+\mu}{2}\int_{\Omega} \underbrace{(\partial_x u_x + \partial_y u_y)^2(x,y) dxdy}_{R_2(u)=\textrm{variations  de  volume}}.
# $$
# En mécanique des structures, $\mu$ et $\lambda$ sont appelées constantes de Lamé. Le paramètre $\lambda$ n’a pas d’interprétation directe, tandis que le paramètre $\mu$ est appelé module de cisaillement.
#
# Le problème d'optimisation à résoudre dans ce TP est le suivant:
# <div style="background-color:rgba(0, 0, 255, 0.1); padding:15px;margin:5px">
#
# $$(P)\qquad \min_{u} E(u)+R(u).$$
# $$
# E(u)=\displaystyle\frac{1}{2}\int_\Omega (f(x+u(x))-g(x))^2 dx=\frac{1}{2}\|f\circ (id+u)-g\|^2.
# $$
# $$
# R(u)= \frac{\mu}{2}\int_{\Omega} \underbrace{ (\partial_x u_y + \partial_y u_x)^2(x,y) dxdy}_{R_1(u)=\textrm{cisaillement}} +\frac{\lambda+\mu}{2}\int_{\Omega} \underbrace{(\partial_x u_x + \partial_y u_y)^2(x,y) dxdy}_{R_2(u)=\textrm{variations  de  volume}}.
# $$
# </div>
#
# **Q1.** A l'aide d'un développement de Taylor, vérifier que le gradient de $E$ s'écrit:
#
# $$\nabla E(u) = \left(f\circ (id+u) -g\right)\nabla f\circ (id+u)$$
#
# au sens où la différentielle de $E$ est définie par:
#
# $$dE(u)\cdot h= \displaystyle\int_\Omega \langle (f(x+u(x))-g(x))\nabla f(x+u(x)),h(x)\rangle dx.$$
#
# Puis par définition, on a $$ dE(u)\cdot h =\langle \nabla E(u),h\rangle \quad \forall h$$
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# On a $\forall (u,h) \in (H_1(\Omega)^2)^2 : \\$
# $$
# \begin{align*}
# E(u+h)
# &= \frac{1}{2}\int_{\Omega} \left[ f(x+u(x)+h(x)) - g(x)\right]^2 \, dx \\
# &= \frac{1}{2} \int_{\Omega} \left[f(x+u(x)) + \langle \nabla f(x+u(x)), h(x) \rangle + o(\|h\|) - g(x) \right]^2 \, dx  &\text{car on suppose que } f \text{ est différentiable} \\
# &= \frac{1}{2} \int_{\Omega} \left( \left[f(x+u(x)) - g(x)\right]^2 + 2 \langle \nabla f(x+u(x)), h(x) \rangle \left( f(x+u(x)) - g(x) \right) + o(\|h\|) \right) \, dx \\
# &= E(u) + \int_{\Omega} \langle \left( f(x + u(x) - g(x) \right) \nabla f(x + u(x)), h(x) \rangle \, dx + o(\|h\|) \\
# &= E(u) + dE(u)\cdot h + o(\|h\|) \\
# &= E(u) + \langle \nabla E(u),h\rangle + o(\|h\|) \\
# \end{align*}
# $$
#
# D'où $\nabla E(u) = \displaystyle\int_\Omega  (f(x+u(x))-g(x))\nabla f(x+u(x)) dx = \left(f\circ (id+u) -g\right)\nabla f\circ (id+u).$
#
#
# </div>

# %% [markdown]
# # 2. Discrétisation
#
# Pour pouvoir résoudre numériquement le problème $(P)$ (dont les variables de l'optimisation sont des fonctions !), on propose de le discrétiser au préalable.
#
# Soit $1\le i \le n$ and $1\le j\le m$. Notons $(x_i,y_j)$ le point de la grille $(i,j)$ et $f_{i,j}$ la valeur de $f$ au point $(x_i,y_j)$. Le produit scalaire sur $V=\mathcal M_{n,m}(\mathbb{R})$ est défini par:
# $$\langle f,g\rangle_V=\sum_{i=1}^n\sum_{j=1}^m f_{i,j}g_{i,j},$$
#
# ## 2.1. Calcul du $E$ et de son gradient
# Pour pouvoir calculer $E$ et son gradient, on va avoir besoin d'évaluer $f\circ (Id+u)$ et $\nabla f\circ(id+u)$. Pour cela, vous aurez besoin de la fonction `interpol` ci-dessous.

# %%
def interpol(function,ux,uy) :
    # function that computes f \circ Id+u and interpolates it on a mesh
    nx,ny=f.shape
    ip=interpolate.RectBivariateSpline(np.arange(nx),np.arange(ny),function)
    [X,Y]=np.meshgrid(np.arange(nx),np.arange(ny), indexing='ij')
    X=X+ux
    Y=Y+uy
    return np.reshape(ip.ev(X.ravel(),Y.ravel()),(nx,ny))

# %% [markdown]
# **Q2.** Lisez la documentation de la fonction `RectBivariateSpline` afin de comprendre ce que fait la fonction `interpol`.
#
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Votre réponse ici
# </div>
#
#
# ## 2.2. Calcul de $R$ et de son gradient
# On discrétise également les opérateurs de dérivation partielles par différences finies ; par exemple la dérivée partielle par rapport à $x$ est donnée par, pour tout $f\in V$ par
# $$\begin{cases}(\partial_x f)_{i,j}=f_{i+1,j}-f_{i,j} \text{ si } i<n \\
# (\partial_x f)_{n,j}=0 \end{cases}.$$
# On a ainsi $\partial_x f\in V$.
#
# On définit les opérateurs $\partial_x^T$ et $\partial_y^T$ comme les uniques opérateurs qui vérifient
#
# $$ \langle \partial_x^T f, g\rangle_V = \langle f,\partial_x  g\rangle_V \quad \forall f,g\in V$$
# $$ \langle \partial_y^T f, g\rangle_V = \langle f,\partial_y  g\rangle_V \quad \forall f,g\in V$$
#
# **Q2.** Donner les formules de discrétisation des opérateurs $\partial_y$, $\partial_x^\top$ et $\partial_y^\top$. Implémenter ces opérateurs ci-après. On donne un test de vérification.

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Pour $\partial _y$ :
# $$\begin{cases}(\partial_y f)_{i,j}=f_{i,j+1}-f_{i,j} \text{ si } j<n \\
# (\partial_y f)_{i,n}=0 \end{cases} $$
#
# Pour $\partial _x ^T$ :
# $$\begin{align}
# \langle \partial _x u, v \rangle_V &= \sum_{i=1}^{n-1}\sum_{j=1}^{n}(u_{i+1,j}-u_{ij})v_{ij}\\
# &=\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{i+1,j}v_{ij}-\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij}\\
# &=\sum_{i=2}^{n}\sum_{j=1}^{n}u_{ij}v_{i-1,j}-\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij}\\
# &=\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{ij}v_{i-1,j}-\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij} - \sum_{j=1}^{n} u_{1j}v_{1j} + \sum_{j=1}^{n} u_{nj}v_{n-1,j}\\
# &=\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{ij}(v_{i-1,j}-v_{ij}) + \sum_{j=1}^{n} u_{nj}v_{n-1,j}-u_{1j}v_{1j}\\ \\ \\
# \end{align}$$
#
# Par identification :
# $$\partial _x ^T=\begin{cases}f_{i-1,j}-f_{ij} \text{ si } i\in[2;n-1] \\
#         f_{n-1,j} \text{ si } i=n \\
#         -f_{1j} \text{ si } i=1 \end{cases} $$
#
# Pour $\partial _y ^T$ :
# $$\begin{align}
# \langle \partial _y u, v \rangle_V &= \sum_{i=1}^{n}\sum_{j=1}^{n-1}(u_{i,j+1}-u_{ij})v_{ij}\\
# &=\sum_{i=1}^{n}\sum_{j=1}^{n-1}u_{i,j+1}v_{ij}-\sum_{i=1}^{n}\sum_{j=1}^{n-1}u_{ij}v_{ij}\\
# &=\sum_{i=1}^{n}\sum_{j=2}^{n}u_{ij}v_{i,j-1}-\sum_{i=1}^{n}\sum_{j=1}^{n-1}u_{ij}v_{ij}\\
# &=\sum_{i=1}^{n}\sum_{j=2}^{n-1}u_{ij}v_{i,j-1}-\sum_{i=1}^{n}\sum_{j=2}^{n-1}u_{ij}v_{ij} - \sum_{i=1}^{n} u_{i1}v_{i1} + \sum_{i=1}^{n} u_{in}v_{i,n-1}\\
# &=\sum_{i=1}^{n}\sum_{j=2}^{n-1}u_{ij}(v_{i,j-1}-v_{ij}) + \sum_{i=1}^{n} u_{in}v_{i,n-1}-u_{i1}v_{i1}\\ \\ \\
# \end{align}$$
#
# Par identification:
# $$\partial _y ^T=\begin{cases}f_{i,j-1}-f_{ij} \text{ si } j\in[2;n-1] \\
#         f_{i,n-1} \text{ si } j=n \\
#         -f_{i1} \text{ si } j=1 \end{cases} $$
#
# </div>

# %%
def dx(im) :
    d=np.zeros(im.shape)
    d[:-1,:]=im[1:,:]-im[:-1,:]
    return d
def dy(im) :
    d=np.zeros(im.shape)
    d[:,:-1]=im[:,1:]-im[:,:-1]
    return d
def dyT(im) :
    d=np.zeros(im.shape)
    d[:,0]=-im[:,0]
    d[:,-1]=im[:,-2]
    d[:,1:-1]=im[:,0:-2]-im[:,1:-1]  
    return d  
def dxT(im) :
    d=np.zeros(im.shape)
    d[0,:]=-im[0,:]
    d[-1,:]=im[-2,:]
    d[1:-1,:]=im[0:-2,:]-im[1:-1,:]   
    return d

def scal(a,b) :
    assert a.shape==b.shape
    return np.sum(a*b)

np.random.seed(42)
im1=np.random.randn(12,15)
im2=np.random.randn(12,15)
print(scal(dx(im1),im2),'=',scal(im1,dxT(im2)))
# Out:
# -17.489408391382973 = -17.489408391382973

# %% [markdown]
# **Q3.**  On peut alors écrire :
# $$
# R(u)= \frac{\mu}{2}\underbrace{\sum_{i}(\partial_x u_y + \partial_y u_x)^2(i)}_{=R_1(u)} + \frac{\lambda+\mu}{2} \underbrace{\sum_i(\partial_x u_x + \partial_y u_y)^2(i)}_{=R_2(u)}.
# $$
# où:
# * $u_x\in V$ et $u_y\in V$ sont les discrétisations des composantes du champ de vecteurs $u$ sur la grille choisie
# * $\partial_x:V \rightarrow V$ et $\partial_y:V\rightarrow V$ représentent les opérateurs de différences finies.
#
# On peut ré-écrire $R(u)=\frac{\mu}{2}R_1(u)+ \frac{\lambda+\mu}{2} R_2(u)$ avec :
# $$
# R_1(u)=\langle A_1 u , A_1 u\rangle_V,\qquad R_2(u)=\langle A_2 u , A_2 u\rangle_V.
# $$
# Où $A_i$ est un opérateur de $V^2$ dans $V$.
# Donnez l'expression des matrices $A_1$ et $A_2$ en fonction des opérateurs $\partial_x$ et $\partial_y$.
#
#
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Pour $A_1$ :
# $$R_1(u) = \langle A_1 u , A_1 u\rangle_V = \|A_1u\|^2_V = \|A_1 \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}\|^2_V =  \|\partial_x u_y + \partial_y u_x \|^2_V = \|
# \begin{bmatrix}
#     dy \\
#     dx
# \end{bmatrix}^T \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}
#  \
#  \|^2_V$$
# D'où, $$A_1 = \begin{bmatrix}
#     dy &  dx
# \end{bmatrix}$$
#
# Pour $A_2$ :
# $$R_2(u) = \langle A_2 u , A_2 u\rangle_V = \|A_2u\|^2_V = \|A_2 \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}\|^2_V =  \|\partial_x u_x + \partial_y u_y \|^2_V = \|
# \begin{bmatrix}
#     dx \\
#     dy
# \end{bmatrix}^T \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}
#  \
#  \|^2_V$$
# D'où, $$A_2 = \begin{bmatrix}
#     dx &  dy
# \end{bmatrix}$$
# </div>
#
#
# **Q3b.**
# Pour tout $u=(u_x,u_y)$ et $v=(v_x,v_y)$ dans $V^2$, on définit le produit scalaire dans $V^2$ par
# $$\langle u,v\rangle_{V^2}=\langle u_x,v_x\rangle_{V}+\langle u_y,v_y\rangle_{V}$$
#
# Montrer que $R(u)$ peut s'écrire sous la forme:
# $$R(u)=\frac{1}{2} \langle A\left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right),\left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right)\rangle_{V^2},$$
#
# Avec $$A=\mu A_1^TA_1 +(\lambda+\mu) A_2^TA_2$$ et $A_i^T$ un opérateur de $V^2$ dans $V$.
#
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# \[
# \begin{align*}
# R(u) &= \frac{\mu}{2}\langle A_1 u, A_1 u\rangle_{V^2} + \frac{\lambda + \mu}{2}\langle A_2 u, A_2 u\rangle_{V^2} \\
# &= \frac{\mu}{2}\left(\langle \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &\quad+ \frac{\lambda + \mu}{2}\left(\langle \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\left(\mu \langle \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &\quad+ \frac{1}{2}\left((\lambda + \mu) \langle \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\left(\langle \mu \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} + (\lambda + \mu) \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \mu \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} + (\lambda + \mu) \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\left(\langle \mu A_1^TA_1 \begin{bmatrix} u_x \\ u_y \end{bmatrix} + (\lambda + \mu) A_2^TA_2 \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\langle A\begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V^2},
# \end{align*}
# \]
#
# où $$A = \mu A_1^TA_1 + (\lambda + \mu) A_2^TA_2$$
#
# </div>
#
# **Q4.** Donner l'expression du gradient de $R$.
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Comme $R(u)=\frac{\mu}{2}R_1(u)+ \frac{\lambda+\mu}{2} R_2(u)$, on a $\nabla R(u) = \frac{\mu}{2} \nabla R_1(u) + \frac{\lambda+\mu}{2} \nabla R_2(u)$.
#
# Pour $\nabla R_1(u)$ :
#
# On a $\forall (u,h) \in V^2$ :
# $$
# \begin{align*}
# R_1(u+h)
# &= R_1(u) + 2 \langle A_1^T A_1 u,h\rangle + o(\|h\|) \\
# \end{align*}
# $$
# Ainsi :
#
# $$
# \begin{align}
# \nabla R_1(u) &= 2 A_1^T A_1 u \\
# &= 2 \begin{bmatrix}
# \partial_y^T \\
# \partial_x^T
# \end{bmatrix} \begin{bmatrix}
# \partial_y & \partial_x
# \end{bmatrix} \begin{bmatrix}
# u_x \\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}
# \partial_y^T \partial_y & \partial_y^T \partial_x \\
# \partial_x^T \partial_y & \partial_x^T \partial_x
# \end{bmatrix} \begin{bmatrix}
# u_x \\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}
# \partial_y^T \partial_y u_x + \partial_y^T \partial_x u_y \\
# \partial_x^T \partial_y u_x + \partial_x^T \partial_x u_y
# \end{bmatrix}
# \end{align}
# $$
#
# Pour $\nabla R_2(u)$ :
#
# On a $\forall (u,h) \in V^2$ :
# $$
# \begin{align*}
# R_2(u+h)
# &= R_2(u) + 2 \langle A_2^T A_2 u,h\rangle + o(\|h\|) \\
# \end{align*}
# $$
# Ainsi :
# $$\begin{align}
# \nabla R_2(u) &= 2 A_2^T A_2 u \\
# &= 2 \begin{bmatrix}
# \partial_x^T\\
# \partial_y^T
# \end{bmatrix} (\partial_x \text{ } \partial_y) \begin{bmatrix}
# u_x\\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}\partial_x^T\partial_x & \partial_x^T\partial_y \\ \partial_y^T\partial_x & \partial_y^T\partial_y \end{bmatrix} \begin{bmatrix}
# u_x\\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}\partial_x^T\partial_x u_x + \partial_x^T\partial_y u_y\\ \partial_y^T\partial_x u_x +  \partial_y^T\partial_y u_y\end{bmatrix}
# \end{align}$$
#
# Finalement, on a :
# $$ \nabla R(u) = \mu \begin{bmatrix}\partial_y^T\partial_yu_x + \partial_y^T\partial_xu_y\\ \partial_x^T\partial_yu_x +  \partial_x^T\partial_xu_y\end{bmatrix} + (\lambda +\mu) \begin{bmatrix}\partial_x^T\partial_x u_x + \partial_x^T\partial_y u_y\\ \partial_y^T\partial_x u_x +  \partial_y^T\partial_y u_y\end{bmatrix}
# $$
# </div>
#
# ## 2.3. Implémentation de la fonction objectif $E+R$
#
# Créez une fonction `objective_function` qui calcul $E(u)+R(u)$.
#
# Cette fonction prend en variable d'entrée
# * `f`,`g` et `ux` et `uy` qui sont nécessaires au calcul de $E(u)$
# * `ux`,`uy` ,`lamb` et `mu` qui sont nécessaires au calcul de $R(u)$. Ici `lamb` et `mu` sont deux variables réelles positives qui représentent $\lambda$ et $\mu$.
#
#
# Cette fonction doit rendre deux arguments :
# * `obj` qui est la valeur de $E(u)+R(u)$
# * `fu` qui est un tableau qui représente le résultat du calcul de $f\circ(Id +u)$. On rend ce tableau car il sera utile pour les prochains calculs.

# %%
def objective_function(f,g,ux,uy,lamb,mu) :
    #implementation de E(u)+R(u)
    fu=interpol(f, ux, uy)
    
    #Calcul de R
    R= mu/2 * np.linalg.norm(dx(uy)+dy(ux))**2 + (lamb+mu)/2 * np.linalg.norm(dx(ux)+dy(uy))**2
    
    #Calcul de E
    E=1/2*np.linalg.norm(fu-g)**2  
    
    obj = R+E
    return obj,fu

np.random.seed(12)
ux=np.random.randn(f.shape[0],f.shape[1])
uy=np.random.randn(f.shape[0],f.shape[1])
obj,fu=objective_function(2*f,3*g,ux,uy,10,5)
print(obj,fu.shape,np.linalg.norm(fu)) #18215.406074781582 (21, 21) 22.047265562734097
# Out:
# 18215.406074781582 (21, 21) 22.047265562734097

# %% [markdown]
# ## 2.4 Implémentation des gradients
# Créez une fonction `gradE` et `gradR` qui calcule $\nabla E(u)$ et $\nabla R(u)$. On garde les conventions de noms de variable de la section précédente et on notera `gradxE,gradyE` les deux composantes de  $\nabla E(u)$ et `gradxR,gradyR` les deux composantes de $\nabla R(u)$. Les variables `dfx` et `dfy`contiennent les dérivées selon `x` et `y` de `f`, elles seront initalisées par `dfx=dx(f)` et `dfy=dy(f)`

# %%
def gradE(dfx,dfy,g,fu,ux,uy) :
    gradxE=(fu-g)*(interpol(dfx,ux,uy))
    gradyE=(fu-g)*(interpol(dfy,ux,uy))
    return gradxE,gradyE

def gradR(lamb,mu,ux,uy) :
    gradxR = mu*dyT(dy(ux)) + (lamb+mu)*dxT(dx(ux)) + mu*dyT(dx(uy)) + (lamb+mu)*dxT(dy(uy))
    gradyR = mu*dxT(dy(ux)) + (mu+lamb)*dyT(dx(ux)) + mu*dxT(dx(uy)) + (lamb+mu)*dyT(dy(uy))
    return gradxR,gradyR

# %%
dfx=dx(f)
dfy=dy(f)  
np.random.seed(12)
ux=np.random.randn(f.shape[0],f.shape[1])
uy=np.random.randn(f.shape[0],f.shape[1])
obj,fu=objective_function(f,g,ux,uy,10,5)
gradxE,gradyE=gradE(dfx,dfy,g,fu,ux,uy)
print(gradxE.shape,gradyE.shape) #(21, 21) (21, 21)
print(np.linalg.norm(gradxE),np.linalg.norm(gradyE)) #0.6513993385167333 0.6040320505869908
gradxR,gradyR=gradR(10.,5.,ux,uy) 
print(gradxR.shape,gradyR.shape)  #(21, 21) (21, 21)
print(np.linalg.norm(gradxR),np.linalg.norm(gradyR)) #1180.7792368512296 1239.1880693357143
# Out:
# (21, 21) (21, 21)
# 0.6513993385167333 0.6040320505869909
# (21, 21) (21, 21)
# 1180.7792368512296 1239.1880693357143

# %% [markdown]
# # 3. Un algorithme de gradient
#
# Une itération de la méthode de descente de gradient est de la forme:
#
# $$
# u_{k+1}=u_k-s_k(\nabla E(u) + \nabla R(u))
# $$
#
# **Q5.** Compléter la fonction RecalageDG implémentant la descente de gradient et utilisant l'algorithme de recherche linéaire par rebroussement proposé ci-dessous.

# %%
def linesearch(ux,uy,step,descentx,descenty,obj_old,f,g,lamb,mu) :
    step=2*step
    tmpx=ux-step*descentx
    tmpy=uy-step*descenty
    obj,fu=objective_function(f,g,tmpx,tmpy,lamb,mu)
    while obj >obj_old and step > 1.e-8:
        step=0.5*step
        tmpx=ux-step*descentx
        tmpy=uy-step*descenty
        obj,fu=objective_function(f,g,tmpx,tmpy,lamb,mu)
    return tmpx,tmpy,step


def RecalageDG(f,g,lamb,mu,nitermax,stepini) : 
    ux=np.zeros(f.shape)
    uy=np.zeros(f.shape)  
    CF=[]
    step_list=[]
    niter=0
    step=stepini
    dfx = dx(f)
    dfy = dy(f)
    # raise ValueError('Compute dfx and dfy here')
    while niter < nitermax and step > 1.e-8 : 
        niter+=1
        obj,fu=objective_function(f,g,ux,uy,lamb,mu)
        CF.append(obj) 
        gradiE = gradE(dfx,dfy,g,fu,ux,uy)
        gradiR = gradR(lamb,mu,ux,uy)
        # raise ValueError('Compute gradxE and gradyE here')
        # raise ValueError('Compute gradRx and gradRy here')
        # raise ValueError('Compute gradx and grady here')

        gradx = gradiE[0] + gradiR[0]
        grady = gradiE[1] + gradiR[1]
        
        ux,uy,step=linesearch(ux,uy,step,gradx,grady,obj,f,g,lamb,mu)
        step_list.append(step)
        if (niter % 3 ==0) :
            print('iteration :',niter,' cost function :',obj,'step :',step)
    return ux,uy,np.array(CF),np.array(step_list)

# %% [markdown]
# **Q5.** Ecrire un compte-rendu des expériences réalisées et des résultats obtenus. Commentez.

# %%
lamb=10
mu=20
nitermax=500

step0 = 0.001
ux,uy,CF,step=RecalageDG(f,g,lamb,mu,nitermax,step0)
# la premiere ligne est 
# iteration : 3  cost function : 19.08125492560699 step : 0.08
# Out:
# iteration : 3  cost function : 19.112289689788053 step : 0.008
# iteration : 6  cost function : 19.080809760237084 step : 0.064
# iteration : 9  cost function : 19.015661151820996 step : 0.008
# iteration : 12  cost function : 18.993244914551816 step : 0.004
# iteration : 15  cost function : 18.984449312445296 step : 0.004
# iteration : 18  cost function : 18.97872999702707 step : 0.008
# iteration : 21  cost function : 18.973943486002316 step : 0.004
# iteration : 24  cost function : 18.968923093986326 step : 0.008
# iteration : 27  cost function : 18.96517686285944 step : 0.004
# iteration : 30  cost function : 18.959584915962502 step : 0.004
# iteration : 33  cost function : 18.954723821099307 step : 0.008
# iteration : 36  cost function : 18.951389262205147 step : 0.004
# iteration : 39  cost function : 18.9457077229742 step : 0.004
# iteration : 42  cost function : 18.94078951763308 step : 0.008
# iteration : 45  cost function : 18.93621620353223 step : 0.008
# iteration : 48  cost function : 18.93223627381541 step : 0.004
# iteration : 51  cost function : 18.92712335102124 step : 0.004
# iteration : 54  cost function : 18.922470383975018 step : 0.008
# iteration : 57  cost function : 18.919315732901858 step : 0.004
# iteration : 60  cost function : 18.913800965221558 step : 0.004
# iteration : 63  cost function : 18.908962218215954 step : 0.004
# iteration : 66  cost function : 18.90445381543379 step : 0.008
# iteration : 69  cost function : 18.90100396493106 step : 0.004
# iteration : 72  cost function : 18.895783690157472 step : 0.004
# iteration : 75  cost function : 18.89109515362346 step : 0.008
# iteration : 78  cost function : 18.886674746096414 step : 0.008
# iteration : 81  cost function : 18.88314799858367 step : 0.004
# iteration : 84  cost function : 18.878074022228944 step : 0.004
# iteration : 87  cost function : 18.873465796624917 step : 0.008
# iteration : 90  cost function : 18.869098623479992 step : 0.008
# iteration : 93  cost function : 18.86565238428218 step : 0.004
# iteration : 96  cost function : 18.860624270933616 step : 0.004
# iteration : 99  cost function : 18.856045406950862 step : 0.008
# iteration : 102  cost function : 18.851704329711556 step : 0.008
# iteration : 105  cost function : 18.848484823650544 step : 0.004
# iteration : 108  cost function : 18.843415488076925 step : 0.004
# iteration : 111  cost function : 18.838819393934862 step : 0.004
# iteration : 114  cost function : 18.834478543177305 step : 0.008
# iteration : 117  cost function : 18.831648060268797 step : 0.004
# iteration : 120  cost function : 18.826446305473432 step : 0.004
# iteration : 123  cost function : 18.821782719664764 step : 0.004
# iteration : 126  cost function : 18.81741368801037 step : 0.008
# iteration : 129  cost function : 18.813207758267282 step : 0.008
# iteration : 132  cost function : 18.809729836426424 step : 0.004
# iteration : 135  cost function : 18.804938699531203 step : 0.004
# iteration : 138  cost function : 18.800507383643954 step : 0.004
# iteration : 141  cost function : 18.79627675984989 step : 0.008
# iteration : 144  cost function : 18.793294294191455 step : 0.004
# iteration : 147  cost function : 18.788299508722694 step : 0.004
# iteration : 150  cost function : 18.78376272181005 step : 0.004
# iteration : 153  cost function : 18.779482500904898 step : 0.008
# iteration : 156  cost function : 18.775347243579112 step : 0.008
# iteration : 159  cost function : 18.771887710232242 step : 0.004
# iteration : 162  cost function : 18.767188976182396 step : 0.004
# iteration : 165  cost function : 18.762826738554935 step : 0.004
# iteration : 168  cost function : 18.758654721602586 step : 0.008
# iteration : 171  cost function : 18.75573944417343 step : 0.004
# iteration : 174  cost function : 18.750803606587596 step : 0.004
# iteration : 177  cost function : 18.746316656150608 step : 0.004
# iteration : 180  cost function : 18.74208325295128 step : 0.008
# iteration : 183  cost function : 18.737993845864555 step : 0.008
# iteration : 186  cost function : 18.734634327705518 step : 0.004
# iteration : 189  cost function : 18.7299652396822 step : 0.004
# iteration : 192  cost function : 18.7256376501902 step : 0.004
# iteration : 195  cost function : 18.72150348154089 step : 0.008
# iteration : 198  cost function : 18.71872223418681 step : 0.004
# iteration : 201  cost function : 18.71379333658476 step : 0.004
# iteration : 204  cost function : 18.709327427178064 step : 0.004
# iteration : 207  cost function : 18.70512321270195 step : 0.008
# iteration : 210  cost function : 18.701067848029673 step : 0.008
# iteration : 213  cost function : 18.697832200130883 step : 0.004
# iteration : 216  cost function : 18.693168186447636 step : 0.004
# iteration : 219  cost function : 18.688859888596962 step : 0.004
# iteration : 222  cost function : 18.684753256901505 step : 0.008
# iteration : 225  cost function : 18.680761545871448 step : 0.008
# iteration : 228  cost function : 18.67718357604364 step : 0.004
# iteration : 231  cost function : 18.67272508118222 step : 0.004
# iteration : 234  cost function : 18.668540878830925 step : 0.008
# iteration : 237  cost function : 18.66451235355774 step : 0.008
# iteration : 240  cost function : 18.661408016692054 step : 0.004
# iteration : 243  cost function : 18.656736592174788 step : 0.004
# iteration : 246  cost function : 18.65243920676449 step : 0.004
# iteration : 249  cost function : 18.648353508241833 step : 0.008
# iteration : 252  cost function : 18.644388374147915 step : 0.008
# iteration : 255  cost function : 18.640920553546973 step : 0.004
# iteration : 258  cost function : 18.636461563187623 step : 0.004
# iteration : 261  cost function : 18.632291160400353 step : 0.008
# iteration : 264  cost function : 18.628284511806537 step : 0.008
# iteration : 267  cost function : 18.625314335784218 step : 0.004
# iteration : 270  cost function : 18.62062771718356 step : 0.004
# iteration : 273  cost function : 18.616335208719796 step : 0.004
# iteration : 276  cost function : 18.612265745896014 step : 0.008
# iteration : 279  cost function : 18.608322963762344 step : 0.008
# iteration : 282  cost function : 18.604966124136208 step : 0.004
# iteration : 285  cost function : 18.600500544436866 step : 0.004
# iteration : 288  cost function : 18.59633936397051 step : 0.008
# iteration : 291  cost function : 18.592350544179013 step : 0.008
# iteration : 294  cost function : 18.589517015522866 step : 0.004
# iteration : 297  cost function : 18.584808775861834 step : 0.004
# iteration : 300  cost function : 18.580516523209567 step : 0.004
# iteration : 303  cost function : 18.576459314166552 step : 0.008
# iteration : 306  cost function : 18.572535565084824 step : 0.008
# iteration : 309  cost function : 18.569290608204756 step : 0.004
# iteration : 312  cost function : 18.564813577889257 step : 0.004
# iteration : 315  cost function : 18.560657576003912 step : 0.004
# iteration : 318  cost function : 18.55668335163855 step : 0.008
# iteration : 321  cost function : 18.55398911952329 step : 0.004
# iteration : 324  cost function : 18.54925391223277 step : 0.004
# iteration : 327  cost function : 18.544957655530784 step : 0.004
# iteration : 330  cost function : 18.54090945828062 step : 0.008
# iteration : 333  cost function : 18.537001794745187 step : 0.008
# iteration : 336  cost function : 18.533870464063497 step : 0.004
# iteration : 339  cost function : 18.52937731345738 step : 0.004
# iteration : 342  cost function : 18.52522312544432 step : 0.004
# iteration : 345  cost function : 18.521260535085712 step : 0.008
# iteration : 348  cost function : 18.51740682632198 step : 0.008
# iteration : 351  cost function : 18.513941689350286 step : 0.004
# iteration : 354  cost function : 18.50963779739742 step : 0.004
# iteration : 357  cost function : 18.505595543404613 step : 0.008
# iteration : 360  cost function : 18.50170153227328 step : 0.008
# iteration : 363  cost function : 18.498685974521283 step : 0.004
# iteration : 366  cost function : 18.494172619534538 step : 0.004
# iteration : 369  cost function : 18.49001695291343 step : 0.004
# iteration : 372  cost function : 18.48606352066356 step : 0.008
# iteration : 375  cost function : 18.48222473901282 step : 0.008
# iteration : 378  cost function : 18.47885449762829 step : 0.004
# iteration : 381  cost function : 18.474539303411618 step : 0.004
# iteration : 384  cost function : 18.470500387433262 step : 0.008
# iteration : 387  cost function : 18.46661771491796 step : 0.008
# iteration : 390  cost function : 18.463720926573885 step : 0.004
# iteration : 393  cost function : 18.459183127677044 step : 0.004
# iteration : 396  cost function : 18.455023136162197 step : 0.004
# iteration : 399  cost function : 18.451076435729743 step : 0.008
# iteration : 402  cost function : 18.447250682285354 step : 0.008
# iteration : 405  cost function : 18.44397713104588 step : 0.004
# iteration : 408  cost function : 18.4396474000607 step : 0.004
# iteration : 411  cost function : 18.435609191467005 step : 0.008
# iteration : 414  cost function : 18.431735907226265 step : 0.008
# iteration : 417  cost function : 18.428961183570213 step : 0.004
# iteration : 420  cost function : 18.42439512131703 step : 0.004
# iteration : 423  cost function : 18.42022784996416 step : 0.004
# iteration : 426  cost function : 18.416285812149507 step : 0.008
# iteration : 429  cost function : 18.412471230258255 step : 0.008
# iteration : 432  cost function : 18.40929685679886 step : 0.004
# iteration : 435  cost function : 18.404949150648104 step : 0.004
# iteration : 438  cost function : 18.400909373130677 step : 0.004
# iteration : 441  cost function : 18.39704351484183 step : 0.008
# iteration : 444  cost function : 18.394394942037533 step : 0.004
# iteration : 447  cost function : 18.38979648126088 step : 0.004
# iteration : 450  cost function : 18.385619329216336 step : 0.004
# iteration : 453  cost function : 18.3816798127962 step : 0.008
# iteration : 456  cost function : 18.377874834652133 step : 0.008
# iteration : 459  cost function : 18.374802316136275 step : 0.004
# iteration : 462  cost function : 18.370433551395863 step : 0.004
# iteration : 465  cost function : 18.366389788327737 step : 0.004
# iteration : 468  cost function : 18.362529684789813 step : 0.008
# iteration : 471  cost function : 18.35877359083066 step : 0.008
# iteration : 474  cost function : 18.35537692161063 step : 0.004
# iteration : 477  cost function : 18.351187068130262 step : 0.004
# iteration : 480  cost function : 18.347248228268032 step : 0.008
# iteration : 483  cost function : 18.343451239652776 step : 0.008
# iteration : 486  cost function : 18.34048391063241 step : 0.004
# iteration : 489  cost function : 18.336090689316574 step : 0.004
# iteration : 492  cost function : 18.332040828092545 step : 0.004
# iteration : 495  cost function : 18.328184711783578 step : 0.008
# iteration : 498  cost function : 18.324438382724786 step : 0.008

# %%
fig, ax = plt.subplots(2,3, figsize=(10,10))
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Algorithme de moindres carrés.
#
# On souhaite maintenant implémenter un algorithme de second ordre pour résoudre le problème $$(P)\quad\min_u E(u)+R(u)$$ afin d'accélérer la convergence de l'algorithme. Pour cela, on va reformuler le problème $(P)$ en un problème de moindres carrés et appliquer l'algorithme de Levenberg-Marquardt.
#
# Soit:
# $$\Psi(u)=\begin{pmatrix}
# f\circ(Id+u)-g \\
# \sqrt{\mu}(\partial_xu_y+\partial_yu_x) \\
# \sqrt{\mu+\lambda}(\partial_xu_x+\partial_yu_y) \end{pmatrix},$$
# où $f\circ(id+u)$ est l'interpolation de $x\mapsto f(x+u(x))$ sur la grille. Minimiser $E(u)+R(u)$ est équivalent à résoudre le problème suivant:
#
# >$$\min_u \|\Psi(u)\|_2^2.$$
#
# Il s'agit maintenant d'un problème de moindres carrés que l'on va résoudre à l'aide de l'algorithme de Levenberg Marquardt :
#
# $$
# u_{k+1}=u_k- H_k^{-1} J_{\Psi}(u_k)^\top \Psi(u_k) \quad\mbox{ avec }\quad H_k=J_{\Psi}(u_k)^\top J_{\Psi}(u_k) +\varepsilon Id
# $$
#
# **Q6.** Calculer la matrice jacobienne de $\Psi$, notée $J_\Psi(u)$.
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# On cherche:
# $$J_{\psi}(u)=\begin{pmatrix}
# \nabla \psi_1(u)^T \\
# \nabla \psi_2(u)^T \\
# \nabla \psi_3(u)^T \
#  \end{pmatrix}$$
#
# Cherchons $\nabla \psi_1(u)$ :
# $$\begin{align}
# J_{\psi_1}(u)&=J_f(Id+u) \times J_{Id+u}(u) \\
# &=\nabla^Tf(Id+u) \times Id \\
# &=\nabla^Tf(Id+u)
# \end{align}$$
# Et $\nabla \psi_1(u)=(J_{\psi_1}(u))^T $
#
# Cherchons $\nabla \psi_2(u)$ :
# $$\begin{align}
# \nabla \psi_2(u)&=\sqrt{\mu} \nabla (\partial _x u_y + \partial _y u_x)\\
# &=\sqrt{\mu} \begin{pmatrix}
# \partial _x  \\
# \partial _y  \\
# \end{pmatrix}
# \end{align}$$
#
# Cherchons $\nabla \psi_3(u)$ :
# $$\begin{align}
# \nabla \psi_3(u)&=\sqrt{\lambda +\mu} \nabla (\partial _x u_x + \partial _y u_y)\\
# &=\sqrt{\lambda + \mu} \begin{pmatrix}
# \partial _x  \\
# \partial _y  \\
# \end{pmatrix}
# \end{align}$$
#
# Ainsi, on obtient:
# $$\begin{align}
# J_{\psi}(u) = \begin{pmatrix}
# df_x(Id+u) & df_y(Id+u) \\
# \sqrt{\mu}\partial _x   &\sqrt{\mu}\partial _y \\
# \sqrt{\lambda + \mu}\partial _x & \sqrt{\lambda +\mu}\partial _y \\
# \end{pmatrix}
# \end{align}$$
# </div>
#
# **Q7.** Implémenter les fonctions `Psi`,`JPsi`, `JTPsi` et `JTJ` qui calculent respectivement:
# - La valeur de $\Psi(u)$
# - le produit de $J_\Psi(u)$ par une direction $v=(v_x,v_y)\in V^2$,
#
# - le produit de $J_\Psi(u)^\top$ par $\phi=(\phi_1,\phi_2,\phi_3)\in V^3$,
#
# - le produit de $(J_\Psi(u)^\top J_\Psi(u)+\epsilon I)$ par une direction $v=(v_x,v_y)\in V^2$.
#
#
# Par convention `fu` représente $f\circ(Id+u)$ et `dfxu`et `dfyu` représentent les deux coordonnées de $(\nabla f)\circ(Id +u)$. On vous donne dans la cellulle suivante des tests de vérification.

# %%
def Psi(fu,g,ux,uy,lamb,mu) :
    Psi0 = fu - g
    Psi1 = np.sqrt(mu)*(dx(uy)+dy(ux))
    Psi2 = np.sqrt(mu+lamb)*(dx(ux)+dy(uy))
    return Psi0,Psi1,Psi2

def JPsi(vx,vy,dfxu,dfyu,lamb,mu) :
    JPsi0=dfxu*vx+dfyu*vy
    JPsi1=np.sqrt(mu)*dy(vx)+np.sqrt(mu)*dx(vy)
    JPsi2=np.sqrt(lamb+mu)*dx(vx)+np.sqrt(lamb+mu)*dy(vy)
    return JPsi0,JPsi1,JPsi2

def JTPsi(phi,dfxu,dfyu,lamb,mu) :
    ux=phi[0]*dfxu+np.sqrt(mu)*dyT(phi[1])+np.sqrt(lamb+mu)*dxT(phi[2])
    uy=phi[0]*dfyu+np.sqrt(mu)*dxT(phi[1])+np.sqrt(lamb+mu)*dyT(phi[2])
    return ux,uy
  
def JTJ(vx,vy,dfxu,dfyu,lamb,mu,epsilon) :
    uxs, uys = JTPsi(JPsi(vx,vy,dfxu,dfyu,lamb,mu),dfxu,dfyu,lamb,mu)
    uxs = uxs + epsilon*vx
    uys = uys + epsilon*vy
    return uxs,uys

# %%
n=50
np.random.seed(42)
fu=np.random.randn(n,n)
tmp_g=np.random.randn(n,n)
ux=np.random.randn(n,n)
uy=np.random.randn(n,n)
dfxu=np.random.randn(n,n)
dfyu=np.random.randn(n,n)
print('## TESTING PSI')
Psi0,Psi1,Psi2=Psi(fu,tmp_g,ux,uy,5,10)
print(Psi0.shape,Psi1.shape,Psi2.shape) #(50, 50) (50, 50) (50, 50)
print(np.linalg.norm(Psi0),np.linalg.norm(Psi1),np.linalg.norm(Psi2)) # 70.85046394690714 320.74675708932546 389.63146864883447
print('## TESTING JPSI')
Psi0,Psi1,Psi2=JPsi(ux,uy,dfxu,dfyu,5,10)
print(Psi0.shape,Psi1.shape,Psi2.shape) # (50, 50) (50, 50) (50, 50)
print(np.linalg.norm(Psi0),np.linalg.norm(Psi1),np.linalg.norm(Psi2)) #69.27576209907774 320.74675708932546 389.63146864883447
print('## TESTING JTPSI')
Psi0=np.random.randn(n,n)
Psi1=np.random.randn(n,n)
Psi2=np.random.randn(n,n)
vx,vy=JTPsi((Psi0,Psi1,Psi2),dfxu,dfyu,5,10)
print(vx.shape,vy.shape) # (50, 50) (50, 50)
print(np.linalg.norm(vx),np.linalg.norm(vy)) #355.08391793335545 352.46941362403214
print('## TESTING JTJ')
vx,vy=JTJ(ux,uy,dfxu,dfyu,5.,10.,1.)
print(vx.shape,vy.shape) # (50, 50) (50, 50)
print(np.linalg.norm(vx),np.linalg.norm(vy)) #3571.889912528785 3522.237528300008
# Out:
# ## TESTING PSI
# (50, 50) (50, 50) (50, 50)
# 70.85046394690714 320.74675708932546 389.63146864883436
# ## TESTING JPSI
# (50, 50) (50, 50) (50, 50)
# 69.27576209907774 320.74675708932546 389.63146864883436
# ## TESTING JTPSI
# (50, 50) (50, 50)
# 355.08391793335545 352.46941362403214
# ## TESTING JTJ
# (50, 50) (50, 50)
# 3571.889912528785 3522.2375283000083

# %% [markdown]
# Calculons maintenant la direction de recherche $d_k$ comme solution du système linéaire:
# $$(J_\Psi(u_k)^\top J_\Psi(u_k) +\epsilon I)\left(\begin{array}{c}
# d_x\\
# d_y
# \end{array}\right) = -J_\Psi(u_k)^\top \Psi(u_k)$$
# Pour cela, on vous donne l'algorithme suivant qui par la méthode du gradient conjugué calcule une solution $d=(d_x,d_y)\in V^2$ du problème:
# $$(J_\Psi(u_k)^\top J_\Psi(u_k) +\epsilon I)\left(\begin{array}{c}
# d_x\\
# d_y
# \end{array}\right) = b$$

# %%
 def CGSolve(u0x,u0y,lamb,mu,b,epsilon,dfxu,dfyu) :
    nitmax=100
    ux,uy=u0x,u0y #point de départ de l'algorithme
    # Computes JTJu
    Ax,Ay=JTJ(ux,uy,dfxu,dfyu,lamb,mu,epsilon)
    rx=b[0]-Ax
    ry=b[1]-Ay
    px,py=np.copy(rx),np.copy(ry)
    rsold=np.linalg.norm(rx)**2+np.linalg.norm(ry)**2
    for i in range(nitmax) :
        Apx,Apy=JTJ(px,py,dfxu,dfyu,lamb,mu,epsilon);
        alpha=rsold/(np.vdot(rx[:],Apx[:])+np.vdot(ry[:],Apy[:]))
        ux=ux+alpha*px
        uy=uy+alpha*py
        rx=rx-alpha*Apx
        ry=ry-alpha*Apy
        rsnew=np.linalg.norm(rx)**2+np.linalg.norm(ry)**2
        if np.sqrt(rsnew)<1e-10 :
            return [ux,uy]
        px=rx+rsnew/rsold*px
        py=ry+rsnew/rsold*py
        rsold=rsnew
    return ux,uy

# %% [markdown]
# **Q8.** Compléter l'algorithme RecalageGN implémentant la méthode de Levenberg-Marquardt.

# %%
def RecalageGN(f,g,lamb,mu,nitermax,stepini,epsi) : 
    ux=np.zeros(f.shape)
    uy=np.zeros(f.shape)  
    descentx=np.zeros(f.shape)
    descenty=np.zeros(f.shape) 
    # raise ValueError('Compute dfx and dfy here')
    dfx = dx(f)
    dfy = dy(f)
    CF=[]
    step_list=[]
    niter=0
    step=stepini
    while niter < nitermax and step > 1.e-8 : 
        niter+=1
        obj,fu=objective_function(f,g,ux,uy,lamb,mu)
        CF.append(obj)
        # raise ValueError('Compute dfxu,dfyu here')
        dfxu = interpol(dfx,ux,uy)
        dfyu = interpol(dfy,ux,uy)
        # raise ValueError('Compute b here')
        b=JTPsi(Psi(fu,g,ux,uy,mu,lamb),dfxu,dfyu,lamb,mu)
        [descentx,descenty]=CGSolve(descentx,descenty,lamb,mu,b,epsi,dfxu,dfyu)
        ux,uy,step=linesearch(ux,uy,step,descentx,descenty,obj,f,g,lamb,mu)
        step_list.append(step)
        # Display
        if (niter % 3 ==0) :
            print('iteration :',niter,' cost function :',obj,'step :',step)
    return ux,uy,np.array(CF),np.array(step_list)

# %% [markdown]
# **Q9.** Tester le nouvel algorithme et comparer sa vitesse de convergence avec celle de l'algorithme de gradient.

# %%
epsi=0.1
nitermax=1000
ux,uy,CF,step=RecalageGN(f,g,lamb,mu,nitermax,step0,epsi)
# On doit trouver comme première ligne
#iteration : 3  cost function : 18.9861786936971 step : 0.08
# Out:
# iteration : 3  cost function : 19.10400110364247 step : 0.008
# iteration : 6  cost function : 18.981859356598648 step : 0.064
# iteration : 9  cost function : 18.04405896012249 step : 0.512
# iteration : 12  cost function : 11.97223049483726 step : 4.096
# iteration : 15  cost function : 2.09539943776353 step : 2.048
# iteration : 18  cost function : 1.0152592968352288 step : 1.024
# iteration : 21  cost function : 0.2859736842265416 step : 2.048
# iteration : 24  cost function : 0.27051736776796054 step : 2.048
# iteration : 27  cost function : 0.26299593261892423 step : 2.048
# iteration : 30  cost function : 0.2596330084280595 step : 2.048
# iteration : 33  cost function : 0.2585802675748629 step : 2.048
# iteration : 36  cost function : 0.25166024041093243 step : 4.096
# iteration : 39  cost function : 0.25092532002042806 step : 2.048
# iteration : 42  cost function : 0.25039597816022807 step : 2.048
# iteration : 45  cost function : 0.25023539921317545 step : 0.256

# %%
fig, ax = plt.subplots(2,3)
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Jeu des différences
# Maintenant que vous avez implémenté et testé les deux algorithmes sur l'image-jouet proposée, voyons que cela donne sur une image IRM d'un cerveau. Saurez-vous détecter les différences/déplacements entre les deux images ?

# %%
im1=Image.open('IRM1.png')
im2=Image.open("IRM2.png")
plt.imshow(plt.imread('IRM1.png'))
plt.show()
plt.imshow(plt.imread('IRM2.png'))
plt.show()

# %%
[n,m]=im1.size
sigma=0.1
[X,Y]=np.meshgrid(np.linspace(-1,1,n),np.linspace(-1,1,m), indexing='xy')
Z=np.sqrt(X*X+Y*Y)
G=np.fft.fftshift(np.exp(-(X**2+Y**2)/sigma**2))
f=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im1)))
g=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im2))) 
f=f/np.max(f)
g=g/np.max(g)

# %%
lamb=10
mu=20
nitermax=500

step0 = 0.01
ux,uy,CF,step=RecalageDG(f,g,lamb,mu,nitermax,step0)
# Out:
# iteration : 3  cost function : 0.14381076908556115 step : 0.08
# iteration : 6  cost function : 0.1438096152752509 step : 0.01
# iteration : 9  cost function : 0.1438092281331238 step : 0.02
# iteration : 12  cost function : 0.14380902677406662 step : 0.04
# iteration : 15  cost function : 0.14380887503431738 step : 0.005
# iteration : 18  cost function : 0.14380883379757162 step : 0.005
# iteration : 21  cost function : 0.14380879419074236 step : 0.005
# iteration : 24  cost function : 0.14380875543386593 step : 0.005
# iteration : 27  cost function : 0.14380871725169816 step : 0.005
# iteration : 30  cost function : 0.14380867951277623 step : 0.005
# iteration : 33  cost function : 0.1438086421448682 step : 0.01
# iteration : 36  cost function : 0.14380861564441574 step : 0.005
# iteration : 39  cost function : 0.1438085767481822 step : 0.005
# iteration : 42  cost function : 0.14380853850622244 step : 0.005
# iteration : 45  cost function : 0.14380850081364238 step : 0.005
# iteration : 48  cost function : 0.14380846359506075 step : 0.005
# iteration : 51  cost function : 0.14380842679444314 step : 0.005
# iteration : 54  cost function : 0.1438083903689138 step : 0.005
# iteration : 57  cost function : 0.1438083542848357 step : 0.005
# iteration : 60  cost function : 0.143808318515246 step : 0.005
# iteration : 63  cost function : 0.14380828303808688 step : 0.005
# iteration : 66  cost function : 0.14380824783500132 step : 0.005
# iteration : 69  cost function : 0.1438082128904727 step : 0.005
# iteration : 72  cost function : 0.14380817819122366 step : 0.005
# iteration : 75  cost function : 0.14380814372572692 step : 0.005
# iteration : 78  cost function : 0.14380810948387002 step : 0.005
# iteration : 81  cost function : 0.14380807545669122 step : 0.005
# iteration : 84  cost function : 0.14380804163619637 step : 0.005
# iteration : 87  cost function : 0.1438080080151778 step : 0.005
# iteration : 90  cost function : 0.14380797458708564 step : 0.005
# iteration : 93  cost function : 0.14380794134594432 step : 0.005
# iteration : 96  cost function : 0.1438079082862744 step : 0.005
# iteration : 99  cost function : 0.14380787540300777 step : 0.005
# iteration : 102  cost function : 0.1438078426914338 step : 0.005
# iteration : 105  cost function : 0.14380781014717758 step : 0.005
# iteration : 108  cost function : 0.14380777776614545 step : 0.005
# iteration : 111  cost function : 0.1438077455444904 step : 0.005
# iteration : 114  cost function : 0.14380771347857907 step : 0.005
# iteration : 117  cost function : 0.14380768156500368 step : 0.005
# iteration : 120  cost function : 0.14380764980052488 step : 0.005
# iteration : 123  cost function : 0.14380761818205842 step : 0.005
# iteration : 126  cost function : 0.14380758670668342 step : 0.005
# iteration : 129  cost function : 0.14380755537161563 step : 0.005
# iteration : 132  cost function : 0.14380752417418607 step : 0.005
# iteration : 135  cost function : 0.14380749311184224 step : 0.005
# iteration : 138  cost function : 0.1438074621821512 step : 0.005
# iteration : 141  cost function : 0.14380743138276383 step : 0.005
# iteration : 144  cost function : 0.14380740071142353 step : 0.005
# iteration : 147  cost function : 0.14380737016597053 step : 0.005
# iteration : 150  cost function : 0.14380733974431156 step : 0.005
# iteration : 153  cost function : 0.14380730944443146 step : 0.005
# iteration : 156  cost function : 0.14380727926439157 step : 0.005
# iteration : 159  cost function : 0.14380724920230675 step : 0.005
# iteration : 162  cost function : 0.14380721925636297 step : 0.005
# iteration : 165  cost function : 0.14380718942480206 step : 0.005
# iteration : 168  cost function : 0.14380715970591504 step : 0.005
# iteration : 171  cost function : 0.1438071300980574 step : 0.005
# iteration : 174  cost function : 0.14380710059961874 step : 0.005
# iteration : 177  cost function : 0.143807071209051 step : 0.005
# iteration : 180  cost function : 0.1438070419248363 step : 0.005
# iteration : 183  cost function : 0.1438070127455117 step : 0.005
# iteration : 186  cost function : 0.14380698366964453 step : 0.005
# iteration : 189  cost function : 0.14380695469584887 step : 0.005
# iteration : 192  cost function : 0.14380692582276902 step : 0.005
# iteration : 195  cost function : 0.1438068970490897 step : 0.005
# iteration : 198  cost function : 0.14380686837352777 step : 0.005
# iteration : 201  cost function : 0.1438068397948304 step : 0.005
# iteration : 204  cost function : 0.14380681131177855 step : 0.005
# iteration : 207  cost function : 0.14380678292318322 step : 0.005
# iteration : 210  cost function : 0.14380675462788153 step : 0.005
# iteration : 213  cost function : 0.14380672642474068 step : 0.005
# iteration : 216  cost function : 0.14380669831265303 step : 0.005
# iteration : 219  cost function : 0.14380667029053587 step : 0.005
# iteration : 222  cost function : 0.1438066423573336 step : 0.005
# iteration : 225  cost function : 0.14380661451201482 step : 0.005
# iteration : 228  cost function : 0.14380658675356958 step : 0.005
# iteration : 231  cost function : 0.14380655908100975 step : 0.005
# iteration : 234  cost function : 0.1438065314933685 step : 0.005
# iteration : 237  cost function : 0.1438065039896989 step : 0.005
# iteration : 240  cost function : 0.1438064765690754 step : 0.005
# iteration : 243  cost function : 0.14380644923059085 step : 0.005
# iteration : 246  cost function : 0.14380642197335725 step : 0.005
# iteration : 249  cost function : 0.14380639479650373 step : 0.005
# iteration : 252  cost function : 0.14380636769917887 step : 0.005
# iteration : 255  cost function : 0.1438063406805452 step : 0.005
# iteration : 258  cost function : 0.1438063137397852 step : 0.005
# iteration : 261  cost function : 0.14380628687609506 step : 0.005
# iteration : 264  cost function : 0.1438062600886873 step : 0.005
# iteration : 267  cost function : 0.1438062333767884 step : 0.005
# iteration : 270  cost function : 0.14380620673964195 step : 0.005
# iteration : 273  cost function : 0.14380618017650265 step : 0.005
# iteration : 276  cost function : 0.14380615368664093 step : 0.005
# iteration : 279  cost function : 0.14380612726934036 step : 0.005
# iteration : 282  cost function : 0.14380610092389567 step : 0.005
# iteration : 285  cost function : 0.14380607464961728 step : 0.005
# iteration : 288  cost function : 0.1438060484458268 step : 0.005
# iteration : 291  cost function : 0.14380602231185718 step : 0.005
# iteration : 294  cost function : 0.1438059962470529 step : 0.005
# iteration : 297  cost function : 0.1438059702507703 step : 0.005
# iteration : 300  cost function : 0.14380594432237723 step : 0.005
# iteration : 303  cost function : 0.14380591846125157 step : 0.005
# iteration : 306  cost function : 0.14380589266678218 step : 0.005
# iteration : 309  cost function : 0.1438058669383671 step : 0.005
# iteration : 312  cost function : 0.14380584127541673 step : 0.005
# iteration : 315  cost function : 0.14380581567734718 step : 0.005
# iteration : 318  cost function : 0.14380579014358866 step : 0.005
# iteration : 321  cost function : 0.1438057646735769 step : 0.01
# iteration : 324  cost function : 0.14380574763469472 step : 0.005
# iteration : 327  cost function : 0.14380572215896822 step : 0.005
# iteration : 330  cost function : 0.14380569674801144 step : 0.005
# iteration : 333  cost function : 0.14380567140121925 step : 0.005
# iteration : 336  cost function : 0.14380564611799743 step : 0.005
# iteration : 339  cost function : 0.14380562089776172 step : 0.005
# iteration : 342  cost function : 0.1438055957399403 step : 0.005
# iteration : 345  cost function : 0.14380557064396987 step : 0.005
# iteration : 348  cost function : 0.14380554560929648 step : 0.005
# iteration : 351  cost function : 0.14380552063537833 step : 0.005
# iteration : 354  cost function : 0.1438054957216808 step : 0.005
# iteration : 357  cost function : 0.14380547086767953 step : 0.005
# iteration : 360  cost function : 0.14380544607285767 step : 0.005
# iteration : 363  cost function : 0.14380542133670832 step : 0.005
# iteration : 366  cost function : 0.14380539665873254 step : 0.005
# iteration : 369  cost function : 0.14380537203843965 step : 0.005
# iteration : 372  cost function : 0.1438053474753463 step : 0.005
# iteration : 375  cost function : 0.14380532296897713 step : 0.005
# iteration : 378  cost function : 0.14380529851886564 step : 0.005
# iteration : 381  cost function : 0.1438052741245499 step : 0.005
# iteration : 384  cost function : 0.143805249785579 step : 0.005
# iteration : 387  cost function : 0.14380522550150462 step : 0.005
# iteration : 390  cost function : 0.1438052012718895 step : 0.005
# iteration : 393  cost function : 0.14380517709629934 step : 0.005
# iteration : 396  cost function : 0.1438051529743089 step : 0.005
# iteration : 399  cost function : 0.14380512890549796 step : 0.005
# iteration : 402  cost function : 0.14380510488945372 step : 0.005
# iteration : 405  cost function : 0.14380508092576766 step : 0.005
# iteration : 408  cost function : 0.14380505701403945 step : 0.005
# iteration : 411  cost function : 0.14380503315387186 step : 0.005
# iteration : 414  cost function : 0.1438050093448756 step : 0.005
# iteration : 417  cost function : 0.14380498558666574 step : 0.005
# iteration : 420  cost function : 0.143804961878863 step : 0.005
# iteration : 423  cost function : 0.14380493822109316 step : 0.005
# iteration : 426  cost function : 0.143804914612988 step : 0.005
# iteration : 429  cost function : 0.14380489105418334 step : 0.005
# iteration : 432  cost function : 0.1438048675443207 step : 0.005
# iteration : 435  cost function : 0.14380484408304528 step : 0.005
# iteration : 438  cost function : 0.14380482067000896 step : 0.005
# iteration : 441  cost function : 0.1438047973048657 step : 0.005
# iteration : 444  cost function : 0.14380477398727629 step : 0.005
# iteration : 447  cost function : 0.14380475071690513 step : 0.005
# iteration : 450  cost function : 0.14380472749342071 step : 0.005
# iteration : 453  cost function : 0.14380470431649656 step : 0.005
# iteration : 456  cost function : 0.14380468118580914 step : 0.005
# iteration : 459  cost function : 0.1438046581010403 step : 0.005
# iteration : 462  cost function : 0.1438046350618759 step : 0.005
# iteration : 465  cost function : 0.14380461206800377 step : 0.005
# iteration : 468  cost function : 0.14380458911911811 step : 0.005
# iteration : 471  cost function : 0.1438045662149164 step : 0.005
# iteration : 474  cost function : 0.14380454335509701 step : 0.005
# iteration : 477  cost function : 0.14380452053936643 step : 0.005
# iteration : 480  cost function : 0.14380449776743204 step : 0.005
# iteration : 483  cost function : 0.1438044750390041 step : 0.005
# iteration : 486  cost function : 0.14380445235379927 step : 0.005
# iteration : 489  cost function : 0.14380442971153398 step : 0.005
# iteration : 492  cost function : 0.14380440711193118 step : 0.005
# iteration : 495  cost function : 0.1438043845547149 step : 0.005
# iteration : 498  cost function : 0.14380436203961314 step : 0.005

# %%
fig, ax = plt.subplots(2,3, figsize=(10,10))
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %%
epsi=0.1
nitermax=1000
ux,uy,CF,step=RecalageGN(f,g,lamb,mu,nitermax,step0,epsi)
# Out:
# iteration : 3  cost function : 0.14381006413170266 step : 0.08
# iteration : 6  cost function : 0.14380223044988968 step : 0.64
# iteration : 9  cost function : 0.14377088701701538 step : 5.12
# iteration : 12  cost function : 0.14371495650416666 step : 2.56
# iteration : 15  cost function : 0.14369509082974266 step : 2.56
# iteration : 18  cost function : 0.14368033700961919 step : 2.56
# iteration : 21  cost function : 0.14366108805976163 step : 2.56
# iteration : 24  cost function : 0.14364472715623564 step : 2.56
# iteration : 27  cost function : 0.14363409953136372 step : 1.28
# iteration : 30  cost function : 0.14361473802384683 step : 2.56
# iteration : 33  cost function : 0.14359840158425025 step : 2.56
# iteration : 36  cost function : 0.1435833980261023 step : 2.56
# iteration : 39  cost function : 0.14357439654890375 step : 1.28
# iteration : 42  cost function : 0.14355594153186987 step : 2.56
# iteration : 45  cost function : 0.14354034624983808 step : 2.56
# iteration : 48  cost function : 0.1435260910702879 step : 2.56
# iteration : 51  cost function : 0.1435125159347618 step : 2.56
# iteration : 54  cost function : 0.14350092443179094 step : 1.28
# iteration : 57  cost function : 0.14348569397151875 step : 2.56
# iteration : 60  cost function : 0.1434719603491329 step : 2.56
# iteration : 63  cost function : 0.14345897055997056 step : 2.56
# iteration : 66  cost function : 0.14344902469820003 step : 1.28
# iteration : 69  cost function : 0.14343389146635413 step : 2.56
# iteration : 72  cost function : 0.1434205136208344 step : 2.56
# iteration : 75  cost function : 0.14340798815258032 step : 2.56
# iteration : 78  cost function : 0.14339989723597574 step : 1.28
# iteration : 81  cost function : 0.1433845991470271 step : 2.56
# iteration : 84  cost function : 0.14337142141182765 step : 2.56
# iteration : 87  cost function : 0.14335925488448817 step : 2.56
# iteration : 90  cost function : 0.14334759831537427 step : 2.56
# iteration : 93  cost function : 0.14333758519816123 step : 1.28
# iteration : 96  cost function : 0.1433244452491622 step : 2.56
# iteration : 99  cost function : 0.14331253620831527 step : 2.56
# iteration : 102  cost function : 0.14330123179728968 step : 2.56
# iteration : 105  cost function : 0.14329269404623945 step : 1.28
# iteration : 108  cost function : 0.14327940525676955 step : 2.56
# iteration : 111  cost function : 0.14326764689632746 step : 2.56
# iteration : 114  cost function : 0.14325662400250772 step : 2.56
# iteration : 117  cost function : 0.1432498308702201 step : 1.28
# iteration : 120  cost function : 0.1432361705179172 step : 2.56
# iteration : 123  cost function : 0.14322444326262523 step : 2.56
# iteration : 126  cost function : 0.14321362994256967 step : 2.56
# iteration : 129  cost function : 0.14320327465714527 step : 2.56
# iteration : 132  cost function : 0.14319465403579618 step : 1.28
# iteration : 135  cost function : 0.14318281684501438 step : 2.56
# iteration : 138  cost function : 0.14317213317965877 step : 2.56
# iteration : 141  cost function : 0.14316201409122709 step : 2.56
# iteration : 144  cost function : 0.14315480622895524 step : 1.28
# iteration : 147  cost function : 0.1431426836510164 step : 2.56
# iteration : 150  cost function : 0.14313203754698042 step : 2.56
# iteration : 153  cost function : 0.14312210014797802 step : 2.56
# iteration : 156  cost function : 0.14311661808161236 step : 1.28
# iteration : 159  cost function : 0.14310398878679756 step : 1.28
# iteration : 162  cost function : 0.14309326866392458 step : 2.56
# iteration : 165  cost function : 0.14308345124599273 step : 2.56
# iteration : 168  cost function : 0.14307407581793682 step : 2.56
# iteration : 171  cost function : 0.14306670552582673 step : 1.28
# iteration : 174  cost function : 0.14305577084615642 step : 2.56
# iteration : 177  cost function : 0.14304600003754603 step : 2.56
# iteration : 180  cost function : 0.1430367874940557 step : 2.56
# iteration : 183  cost function : 0.1430308346183391 step : 1.28
# iteration : 186  cost function : 0.14301950575315844 step : 2.56
# iteration : 189  cost function : 0.1430096914804346 step : 2.56
# iteration : 192  cost function : 0.1430005926346892 step : 2.56
# iteration : 195  cost function : 0.14299185092524305 step : 2.56
# iteration : 198  cost function : 0.1429844568811469 step : 1.28
# iteration : 201  cost function : 0.142974485571747 step : 2.56
# iteration : 204  cost function : 0.1429654408758934 step : 2.56
# iteration : 207  cost function : 0.14295684839760742 step : 2.56
# iteration : 210  cost function : 0.14295062943769757 step : 1.28
# iteration : 213  cost function : 0.1429403537895274 step : 2.56
# iteration : 216  cost function : 0.14293128963657664 step : 2.56
# iteration : 219  cost function : 0.14292280632919074 step : 2.56
# iteration : 222  cost function : 0.1429180565551814 step : 1.28
# iteration : 225  cost function : 0.1429072843236958 step : 1.28
# iteration : 228  cost function : 0.1428981075083964 step : 2.56
# iteration : 231  cost function : 0.14288968478150676 step : 2.56
# iteration : 234  cost function : 0.14288162867943563 step : 2.56
# iteration : 237  cost function : 0.14287528474059855 step : 1.28
# iteration : 240  cost function : 0.14286587351323524 step : 2.56
# iteration : 243  cost function : 0.14285745072183703 step : 2.56
# iteration : 246  cost function : 0.14284949957949633 step : 2.56
# iteration : 249  cost function : 0.14284438301518132 step : 1.28
# iteration : 252  cost function : 0.142834578366232 step : 2.56
# iteration : 255  cost function : 0.14282607793839036 step : 2.56
# iteration : 258  cost function : 0.1428181916320806 step : 2.56
# iteration : 261  cost function : 0.14281060983770855 step : 2.56
# iteration : 264  cost function : 0.14280422846574173 step : 1.28
# iteration : 267  cost function : 0.142795550156293 step : 2.56
# iteration : 270  cost function : 0.14278767807298562 step : 2.56
# iteration : 273  cost function : 0.14278019762156757 step : 2.56
# iteration : 276  cost function : 0.14277484819562908 step : 1.28
# iteration : 279  cost function : 0.14276585927617463 step : 2.56
# iteration : 282  cost function : 0.14275793695395586 step : 2.56
# iteration : 285  cost function : 0.1427505243053983 step : 2.56
# iteration : 288  cost function : 0.14274648549535376 step : 1.28
# iteration : 291  cost function : 0.14273701039950204 step : 1.28
# iteration : 294  cost function : 0.14272895402547559 step : 2.56
# iteration : 297  cost function : 0.14272156708664518 step : 2.56
# iteration : 300  cost function : 0.14271450321858095 step : 2.56
# iteration : 303  cost function : 0.1427090245104281 step : 1.28
# iteration : 306  cost function : 0.14270072321531932 step : 2.56
# iteration : 309  cost function : 0.14269330794784227 step : 2.56
# iteration : 312  cost function : 0.14268631338679413 step : 2.56
# iteration : 315  cost function : 0.14268194117551572 step : 1.28
# iteration : 318  cost function : 0.1426732479313423 step : 2.56
# iteration : 321  cost function : 0.14266573397096124 step : 2.56
# iteration : 324  cost function : 0.1426587733874601 step : 2.56
# iteration : 327  cost function : 0.14265208520140085 step : 2.56
# iteration : 330  cost function : 0.14264654520768766 step : 1.28
# iteration : 333  cost function : 0.1426388399851348 step : 2.56
# iteration : 336  cost function : 0.14263186784735024 step : 2.56
# iteration : 339  cost function : 0.14262524984018993 step : 2.56
# iteration : 342  cost function : 0.1426206481889072 step : 1.28
# iteration : 345  cost function : 0.1426126281034236 step : 2.56
# iteration : 348  cost function : 0.14260558521739677 step : 2.56
# iteration : 351  cost function : 0.1425990075372417 step : 2.56
# iteration : 354  cost function : 0.14259265710151034 step : 2.56
# iteration : 357  cost function : 0.1425871119542813 step : 1.28
# iteration : 360  cost function : 0.1425799203774203 step : 2.56
# iteration : 363  cost function : 0.14257334473291502 step : 2.56
# iteration : 366  cost function : 0.14256706442719885 step : 2.56
# iteration : 369  cost function : 0.1425623192218434 step : 1.28
# iteration : 372  cost function : 0.14255487483308055 step : 2.56
# iteration : 375  cost function : 0.14254825125866502 step : 2.56
# iteration : 378  cost function : 0.14254201567859032 step : 2.56
# iteration : 381  cost function : 0.1425382955974919 step : 1.28
# iteration : 384  cost function : 0.14253045918582857 step : 1.28
# iteration : 387  cost function : 0.1425237219110099 step : 2.56
# iteration : 390  cost function : 0.14251749862358784 step : 2.56
# iteration : 393  cost function : 0.1425115266300159 step : 2.56
# iteration : 396  cost function : 0.1425066963948901 step : 1.28
# iteration : 399  cost function : 0.142499757541725 step : 2.56
# iteration : 402  cost function : 0.1424935042367899 step : 2.56
# iteration : 405  cost function : 0.14248758030649072 step : 2.56
# iteration : 408  cost function : 0.14248362439730689 step : 1.28
# iteration : 411  cost function : 0.14247636637297087 step : 2.56
# iteration : 414  cost function : 0.14247002724044727 step : 2.56
# iteration : 417  cost function : 0.14246412383346163 step : 2.56
# iteration : 420  cost function : 0.14245843166384656 step : 2.56
# iteration : 423  cost function : 0.14245356699930634 step : 1.28
# iteration : 426  cost function : 0.14244706784977684 step : 2.56
# iteration : 429  cost function : 0.1424411491051455 step : 2.56
# iteration : 432  cost function : 0.14243550713158196 step : 2.56
# iteration : 435  cost function : 0.14243139133121918 step : 1.28
# iteration : 438  cost function : 0.1424246324889104 step : 2.56
# iteration : 441  cost function : 0.14241865105594256 step : 2.56
# iteration : 444  cost function : 0.1424130357263987 step : 2.56
# iteration : 447  cost function : 0.1424098886998515 step : 1.28
# iteration : 450  cost function : 0.14240273606320966 step : 1.28
# iteration : 453  cost function : 0.14239662906290634 step : 2.56
# iteration : 456  cost function : 0.14239100984548803 step : 2.56
# iteration : 459  cost function : 0.14238562744749028 step : 2.56
# iteration : 462  cost function : 0.1423814052150444 step : 1.28
# iteration : 465  cost function : 0.14237508808641774 step : 2.56
# iteration : 468  cost function : 0.1423694247218655 step : 2.56
# iteration : 471  cost function : 0.1423640738334741 step : 2.56
# iteration : 474  cost function : 0.1423606811352959 step : 1.28
# iteration : 477  cost function : 0.14235404012569916 step : 2.56
# iteration : 480  cost function : 0.1423482790257208 step : 2.56
# iteration : 483  cost function : 0.14234293363697184 step : 2.56
# iteration : 486  cost function : 0.14233778851427206 step : 2.56
# iteration : 489  cost function : 0.1423335071163291 step : 1.28
# iteration : 492  cost function : 0.14232757658056483 step : 2.56
# iteration : 495  cost function : 0.14232220237713825 step : 2.56
# iteration : 498  cost function : 0.14231709224201558 step : 2.56
# iteration : 501  cost function : 0.1423135236623758 step : 1.28
# iteration : 504  cost function : 0.14230732688101144 step : 2.56
# iteration : 507  cost function : 0.14230187826464832 step : 2.56
# iteration : 510  cost function : 0.1422967808499106 step : 2.56
# iteration : 513  cost function : 0.1422918559425146 step : 2.56
# iteration : 516  cost function : 0.14228754794319434 step : 1.28
# iteration : 519  cost function : 0.14228196389113368 step : 2.56
# iteration : 522  cost function : 0.14227684992873826 step : 2.56
# iteration : 525  cost function : 0.14227196272872197 step : 2.56
# iteration : 528  cost function : 0.142268268797619 step : 1.28
# iteration : 531  cost function : 0.14226246691304142 step : 2.56
# iteration : 534  cost function : 0.14225729746205792 step : 2.56
# iteration : 537  cost function : 0.14225242887701667 step : 2.56
# iteration : 540  cost function : 0.14224953304138158 step : 1.28
# iteration : 543  cost function : 0.14224340199438315 step : 1.28
# iteration : 546  cost function : 0.1422381249950281 step : 2.56
# iteration : 549  cost function : 0.14223324999337175 step : 2.56
# iteration : 552  cost function : 0.14222856762701222 step : 2.56
# iteration : 555  cost function : 0.14222479347420144 step : 1.28
# iteration : 558  cost function : 0.14221933864756486 step : 2.56
# iteration : 561  cost function : 0.1422144239849271 step : 2.56
# iteration : 564  cost function : 0.14220976468755647 step : 2.56
# iteration : 567  cost function : 0.14220667793790379 step : 1.28
# iteration : 570  cost function : 0.14220095034903088 step : 2.56
# iteration : 573  cost function : 0.14219595150522793 step : 2.56
# iteration : 576  cost function : 0.14219129382002949 step : 2.56
# iteration : 579  cost function : 0.14218680244241153 step : 2.56
# iteration : 582  cost function : 0.1421829802205247 step : 1.28
# iteration : 585  cost function : 0.14217783734592174 step : 2.56
# iteration : 588  cost function : 0.14217315280926487 step : 2.56
# iteration : 591  cost function : 0.14216868811214906 step : 2.56
# iteration : 594  cost function : 0.1421654592235643 step : 1.28
# iteration : 597  cost function : 0.1421600912084955 step : 2.56
# iteration : 600  cost function : 0.14215534172397895 step : 2.56
# iteration : 603  cost function : 0.14215088526160866 step : 2.56
# iteration : 606  cost function : 0.14214843276505257 step : 1.28
# iteration : 609  cost function : 0.14214272968910663 step : 1.28
# iteration : 612  cost function : 0.14213786406095832 step : 2.56
# iteration : 615  cost function : 0.14213339144019824 step : 2.56
# iteration : 618  cost function : 0.1421291062171477 step : 2.56
# iteration : 621  cost function : 0.14212577888931047 step : 1.28
# iteration : 624  cost function : 0.1421207277698614 step : 2.56
# iteration : 627  cost function : 0.14211620638589603 step : 2.56
# iteration : 630  cost function : 0.1421119345707637 step : 2.56
# iteration : 633  cost function : 0.14210927710914056 step : 1.28
# iteration : 636  cost function : 0.14210394652431677 step : 2.56
# iteration : 639  cost function : 0.14209933250595605 step : 2.56
# iteration : 642  cost function : 0.1420950531654663 step : 2.56
# iteration : 645  cost function : 0.1420909358829696 step : 2.56
# iteration : 648  cost function : 0.14208754213396568 step : 1.28
# iteration : 651  cost function : 0.142082776270831 step : 2.56
# iteration : 654  cost function : 0.14207846140042263 step : 2.56
# iteration : 657  cost function : 0.14207436176759353 step : 2.56
# iteration : 660  cost function : 0.14207154704296085 step : 1.28
# iteration : 663  cost function : 0.14206654887009906 step : 2.56
# iteration : 666  cost function : 0.14206216087180792 step : 2.56
# iteration : 669  cost function : 0.14205806087919745 step : 2.56
# iteration : 672  cost function : 0.14205409957090295 step : 2.56
# iteration : 675  cost function : 0.14205066852087309 step : 1.28
# iteration : 678  cost function : 0.14204615663827538 step : 2.56
# iteration : 681  cost function : 0.14204203227740098 step : 2.56
# iteration : 684  cost function : 0.14203809188869887 step : 2.56
# iteration : 687  cost function : 0.14203516267455055 step : 1.28
# iteration : 690  cost function : 0.1420304579769056 step : 2.56
# iteration : 693  cost function : 0.1420262769801751 step : 2.56
# iteration : 696  cost function : 0.1420223419602674 step : 2.56
# iteration : 699  cost function : 0.14202007115402626 step : 1.28
# iteration : 702  cost function : 0.14201507998879276 step : 1.28
# iteration : 705  cost function : 0.14201079884959852 step : 2.56
# iteration : 708  cost function : 0.14200684854602852 step : 2.56
# iteration : 711  cost function : 0.14200305754469453 step : 2.56
# iteration : 714  cost function : 0.1420000458903487 step : 1.28
# iteration : 717  cost function : 0.1419956055109445 step : 2.56
# iteration : 720  cost function : 0.14199161219935652 step : 2.56
# iteration : 723  cost function : 0.14198783131838305 step : 2.56
# iteration : 726  cost function : 0.1419853893994348 step : 1.28
# iteration : 729  cost function : 0.14198070950363184 step : 2.56
# iteration : 732  cost function : 0.14197663576694103 step : 2.56
# iteration : 735  cost function : 0.14197284723704603 step : 2.56
# iteration : 738  cost function : 0.14196919533658256 step : 2.56
# iteration : 741  cost function : 0.14196613032655658 step : 1.28
# iteration : 744  cost function : 0.14196192551874035 step : 2.56
# iteration : 747  cost function : 0.1419581054966513 step : 2.56
# iteration : 750  cost function : 0.14195446745076395 step : 2.56
# iteration : 753  cost function : 0.1419518966173732 step : 1.28
# iteration : 756  cost function : 0.1419474917967335 step : 2.56
# iteration : 759  cost function : 0.14194360814462936 step : 2.56
# iteration : 762  cost function : 0.14193996861774782 step : 2.56
# iteration : 765  cost function : 0.14193644786427087 step : 2.56
# iteration : 768  cost function : 0.1419333509465241 step : 1.28
# iteration : 771  cost function : 0.14192936017563293 step : 2.56
# iteration : 774  cost function : 0.14192569865054183 step : 2.56
# iteration : 777  cost function : 0.14192219483577814 step : 2.56
# iteration : 780  cost function : 0.14191952728188656 step : 1.28
# iteration : 783  cost function : 0.14191537019421546 step : 2.56
# iteration : 786  cost function : 0.1419116590026313 step : 2.56
# iteration : 789  cost function : 0.14190815887847308 step : 2.56
# iteration : 792  cost function : 0.1419060558137925 step : 1.28
# iteration : 795  cost function : 0.1419016518337821 step : 2.56
# iteration : 798  cost function : 0.14189785353279516 step : 2.56
# iteration : 801  cost function : 0.14189433942174753 step : 2.56
# iteration : 804  cost function : 0.14189096080859995 step : 2.56
# iteration : 807  cost function : 0.1418882256918728 step : 1.28
# iteration : 810  cost function : 0.14188428946591577 step : 2.56
# iteration : 813  cost function : 0.14188073755012537 step : 2.56
# iteration : 816  cost function : 0.14187736676628632 step : 2.56
# iteration : 819  cost function : 0.14187512156781978 step : 1.28
# iteration : 822  cost function : 0.1418709781199967 step : 2.56
# iteration : 825  cost function : 0.14186735619152904 step : 2.56
# iteration : 828  cost function : 0.14186397796768 step : 2.56
# iteration : 831  cost function : 0.1418607175906815 step : 2.56
# iteration : 834  cost function : 0.14185793684847225 step : 1.28
# iteration : 837  cost function : 0.14185420121500603 step : 2.56
# iteration : 840  cost function : 0.14185079503341444 step : 2.56
# iteration : 843  cost function : 0.14184754594574975 step : 2.56
# iteration : 846  cost function : 0.14184519104408866 step : 1.28
# iteration : 849  cost function : 0.14184128211685346 step : 2.56
# iteration : 852  cost function : 0.1418378202178632 step : 2.56
# iteration : 855  cost function : 0.14183456921764456 step : 2.56
# iteration : 858  cost function : 0.1418327769160038 step : 1.28
# iteration : 861  cost function : 0.14182861346158193 step : 1.28
# iteration : 864  cost function : 0.14182505822095154 step : 2.56
# iteration : 867  cost function : 0.1418217876075637 step : 2.56
# iteration : 870  cost function : 0.14181865215698372 step : 2.56
# iteration : 873  cost function : 0.1418162168784419 step : 1.28
# iteration : 876  cost function : 0.14181251699794684 step : 2.56
# iteration : 879  cost function : 0.14180920286001705 step : 2.56
# iteration : 882  cost function : 0.14180606997577877 step : 2.56
# iteration : 885  cost function : 0.14180412320022737 step : 1.28
# iteration : 888  cost function : 0.14180020876781008 step : 2.56
# iteration : 891  cost function : 0.14179681866348393 step : 2.56
# iteration : 894  cost function : 0.14179367306606677 step : 2.56
# iteration : 897  cost function : 0.1417906450714154 step : 2.56
# iteration : 900  cost function : 0.14178815183368806 step : 1.28
# iteration : 903  cost function : 0.14178464167365057 step : 2.56
# iteration : 906  cost function : 0.1417814627095279 step : 2.56
# iteration : 909  cost function : 0.14177844104394374 step : 2.56
# iteration : 912  cost function : 0.14177637254183342 step : 1.28
# iteration : 915  cost function : 0.14177268209704114 step : 2.56
# iteration : 918  cost function : 0.14176944179610051 step : 2.56
# iteration : 921  cost function : 0.14176641324590242 step : 2.56
# iteration : 924  cost function : 0.14176348612917639 step : 2.56
# iteration : 927  cost function : 0.14176095541620656 step : 1.28
# iteration : 930  cost function : 0.14175761576653417 step : 2.56
# iteration : 933  cost function : 0.14175456252422258 step : 2.56
# iteration : 936  cost function : 0.14175164477009766 step : 2.56
# iteration : 939  cost function : 0.1417494841263243 step : 1.28
# iteration : 942  cost function : 0.14174599322858497 step : 2.56
# iteration : 945  cost function : 0.14174289116162941 step : 2.56
# iteration : 948  cost function : 0.14173997130567634 step : 2.56
# iteration : 951  cost function : 0.1417383001892598 step : 1.28
# iteration : 954  cost function : 0.14173458720456536 step : 1.28
# iteration : 957  cost function : 0.14173140354959302 step : 2.56
# iteration : 960  cost function : 0.14172846619925591 step : 2.56
# iteration : 963  cost function : 0.14172564678492403 step : 2.56
# iteration : 966  cost function : 0.1417234168991568 step : 1.28
# iteration : 969  cost function : 0.14172010691692782 step : 2.56
# iteration : 972  cost function : 0.14171713122941976 step : 2.56
# iteration : 975  cost function : 0.14171431375557375 step : 2.56
# iteration : 978  cost function : 0.14171250958944664 step : 1.28
# iteration : 981  cost function : 0.14170901222989216 step : 2.56
# iteration : 984  cost function : 0.14170596988742767 step : 2.56
# iteration : 987  cost function : 0.1417031410478035 step : 2.56
# iteration : 990  cost function : 0.14170041402299421 step : 2.56
# iteration : 993  cost function : 0.14169813578869342 step : 1.28
# iteration : 996  cost function : 0.14169498825195195 step : 2.56
# iteration : 999  cost function : 0.14169213003892353 step : 2.56

# %%
fig, ax = plt.subplots(2,3)
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()
