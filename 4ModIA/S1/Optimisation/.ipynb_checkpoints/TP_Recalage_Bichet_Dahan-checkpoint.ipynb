# %% [markdown]
# TP1 - Recalage d'images
# =============

# %%
import numpy as np
from scipy import signal
from scipy import interpolate
from PIL import Image
import matplotlib.pyplot as plt
import numpy.linalg as npl

# %% [markdown]
# Un problème fréquemment rencontré dans le domaine du traitement d’images est celui du recalage. On dispose de plusieurs images prises à des temps différents, ou par des appareils différents, et on aimerait les mettre en correspondence, c’est-à-dire trouver une déformation du plan, qui assure une correspondence point à point des objets sous-jacents. Donnons quelques exemples d’applications :
# * Traitements/retouches d’images. Par exemple, on peut vouloir construire un panoramique à partir d’images de petite taille. Il faut les recaler préalablement.
# * Evaluation des déplacements d’objets dans des séquences vidéos (e.g. trouver un défaut de fonctionnement d’un organe, caméras de surveillance, design de robots intelligents ou de systèmes de navigation automatiques ...)
# * Couplage d’informations. Par exemple, en imagerie médicale, on obtient une information plus riche en utilisant à la fois une radio et une angiographie. L’une apporte des informations structurelles, l’autre des informations fonctionnelles. Le couplage des deux images donne plus d’information au praticien.
# * Beaucoup d’autres applications...
#
# Dans ce TP, nous allons proposer un modèle de recalage assez élémentaire. Les idées constitutives se retrouvent cependant dans presque toutes les techniques récentes.

# %%
def get_images() :
    n=21
    sigma=0.3
    [X,Y]=np.meshgrid(np.linspace(-1,1,n),np.linspace(-1,1,n), indexing='xy')
    Z=np.sqrt(X*X+Y*Y)
    im1=np.zeros((n,n))
    im1[Z<=.7]=1.
    im1[Z<=.3]=.5
    im1[Z<=.1]=.7
    im2=np.zeros((n,n));
    Z=np.sqrt((X-.3)**2+(Y+.2)**2)
    im2[Z<=.7]=1
    im2[Z<=.3]=.5
    im2[Z<=.1]=.7
    G=np.fft.fftshift(np.exp(-(X**2+Y**2)/sigma**2))
    f=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im1)))
    g=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im2))) 
    f=f/np.max(f)
    g=g/np.max(g)
    return f,g

# %%
f,g=get_images()

# %% [markdown]
# # 1. Formalisation du problème
# -----------------------------

# %% [markdown]
# 1.1 Formalisme continu
# ---------------------
#
# On modélise les images en niveaux de gris comme des fonctions d’un ensemble borné $\Omega\subset \mathbb{R}$ (typiquement un carré) dans $\mathbb{R}$. La valeur de la fonction en chaque point représente l’intensité lumineuse de l’image.
#
# Soient $f$ et $g$ deux images. On a donc :
# $$
# f:\Omega\subset \mathbb{R}^2 \to \mathbb{R},  g:\Omega\subset \mathbb{R}^2 \to \mathbb{R}
# $$
# En supposant que les images $f$ et $g$ dépendent seulement d’une transformation géométrique qui conserve la luminosité, le problème de recalage peut être formulé comme suit:
#
# > Problème inverse $(P_1)$ :
#
# > Etant donnés $f$ et $g$ dans $H_1(\Omega)$ (les images ont une amplitude bornée et une énergie finie), trouver un champ de vecteurs $u = (u_1, u_2) \in H_1(\Omega)^2$ tel que:
# $$f(x + u(x)) = g(x), \forall x\in \Omega.$$
#
#
# Le problème inverse est mal posé: tout d'abord, l'existence d'une solution n'est pas garantie, et dans le cas où il existe une solution, on n'a pas nécessairement unicité de cette solution. Par exemple, si $f$ et $g$ sont des fonctions constantes, n'importe quel déplacement $u$ est solution
#
# Pour le résoudre, on se propose de le reformuler comme un problème d'optimisation:
#
# > $(P_2)$ On cherche une déformation $u$ du plan qui minimise:
# $$
# E(u)=\displaystyle\frac{1}{2}\int_\Omega (f(x+u(x))-g(x))^2 dx=\frac{1}{2}\|f\circ (id+u)-g\|^2.
# $$
#
# Sans hypothèse supplémentaire, le problème $\displaystyle \min_{u \in H^1(\Omega)^2} E(u)$ n'est a priori pas convexe, toujours mal posé et même éventuellement non différentiable si $u$ et $f$ ne sont pas assez régulières. On pourrait facilement rendre $f$ différentiable (en ajoutant du bruit par exemple à l'image, ce qui revient à convoler $f$ avec une gaussienne) mais il faut également "forcer" $u$ à être différentiable. Pour cela on propose de régulariser le problème de façon à assurer la convexité du problème d'optimisation considéré ainsi que l'existence et l'unicité des solutions.

# %% [markdown]
# Pour régulariser le problème inverse, nous allons faire une analogie avec l’élasticité linéaire. La fonction $u = (u_x,u_y)$ représente un champ de déformations. En notant $\partial x$ et $\partial y$ les opérateurs de dérivation partielle par rapport à chacun des axes du plan, on peut définir un potentiel élastique linéarisé :
# $$
# R(u)= \frac{\mu}{2}\int_{\Omega} \underbrace{ (\partial_x u_y + \partial_y u_x)^2(x,y) dxdy}_{R_1(u)=\textrm{cisaillement}} +\frac{\lambda+\mu}{2}\int_{\Omega} \underbrace{(\partial_x u_x + \partial_y u_y)^2(x,y) dxdy}_{R_2(u)=\textrm{variations \ de \ volume}}.
# $$
# En mécanique des structures, $\mu$ et $\lambda$ sont appelées constantes de Lamé. Le paramètre $\lambda$ n’a pas d’interprétation directe, tandis que le paramètre $\mu$ est appelé module de cisaillement.
#
# Le problème d'optimisation à résoudre dans ce TP est le suivant:
# > $$(P)\qquad \min_{u} E(u)+R(u).$$

# %% [markdown]
# Q1. A l'aide d'un développement de Taylor, vérifier que le gradient de $E$ s'écrit:
#
# $$\nabla E(u) = \left(f\circ (id+u) -g\right)\nabla f\circ (id+u)$$
#
# au sens où la différentielle de $E$ est définie par:
#
# $$\langle \nabla E(u),h\rangle = \displaystyle\int_\Omega \langle (f(x+u(x))-g(x))\nabla f(x+u(x)),h(x)\rangle dx.$$

# %% [markdown]
# $$\begin{align}
# E(u+h) &= \frac{1}{2}\int_{\Omega} \left[ f(x+u(x)+h(x)) - g(x)\right]^2 dx \\
# &= \frac{1}{2} \int_{\Omega} \left[f(x+u(x)) + \langle \nabla f(x+u(x)), h(x) \rangle + o(\|h\|) - g(x) \right]^2 dx \\
# &= \frac{1}{2} \int_{\Omega} \left( \left[f(x+u(x)) - g(x)\right]^2 + 2 \langle \nabla f(x+u(x)), h(x) \rangle \left( f(x+u(x)) - g(x) \right) + o(\|h\|) \right) dx \\
# &= E(u) + \int_{\Omega} \langle \left( f(x + u(x) - g(x) \right) \nabla f(x + u(x)), h(x) \rangle dx + o(\|h\|)
# \end{align}$$
#
#
# On trouve donc $\nabla E(u) = \left( f(id + u) -g \right) \nabla f(id +u)$.

# %% [markdown]
# # 2. Discrétisation
#
# Pour pouvoir résoudre numériquement le problème $(P)$ (dont les variables de l'optimisation sont des fonctions !), on propose de le discrétiser au préalable.
#
# Soit $1\le i \le n$ and $1\le j\le m$. Notons $(x_i,y_j)$ le point de la grille $(i,j)$ et $f_{i,j}$ la valeur de $f$ au point $(x_i,y_j)$. Le produit scalaire sur $V=\mathbb{R}^n\times \mathbb{R}^m$ est défini par:
# $$\langle f,g\rangle_V=\sum_{i=1}^n\sum_{j=1}^m f_{i,j}g_{i,j},$$
# défini sur $\mathbb{R}^n\times \mathbb{R}^m$.

# %% [markdown]
# 2.1. Calcul du $E$ et de son gradient
# -----------------------------------

# %% [markdown]
# Pour pouvoir calculer $E$ et son gradient, on va avoir besoin d'évaluer $f\circ (Id+u)$ et $\nabla f\circ(id+u)$. C'est ce que fait la fonciton interpol ci-dessous.

# %%
def interpol(f,ux,uy) :
    # function that computes f \circ Id+u and interpolates it on a mesh
    nx,ny=f.shape
    ip=interpolate.RectBivariateSpline(np.arange(nx),np.arange(ny),f)
    [X,Y]=np.meshgrid(np.arange(nx),np.arange(ny), indexing='ij')
    X=X+ux
    Y=Y+uy
    return np.reshape(ip.ev(X.ravel(),Y.ravel()),(nx,ny))

# %% [markdown]
# 2.2. Calcul de $R$ et de son gradient
# -------------------------------------
# On discrétise également les opérateurs de dérivation partielles par différences finies ; par exemple la dérivée partielle par rapport à $x$ est donnée par:
# $$\begin{cases}(\partial_x f)_{i,j}=f_{i+1,j}-f_{i,j} \text{ si } i<n \\
# (\partial_x f)_{n,j}=0 \end{cases} $$
#
# On peut alors écrire :
# $$
# R(u)= \frac{\mu}{2}\sum_{i}(\partial_x u_y + \partial_y u_x)^2(i) + \frac{\lambda+\mu}{2} \sum_i(\partial_x u_x + \partial_y u_y)^2(i).
# $$
# où:
# * $u_x\in\mathbb{R}^n$ et $u_y\in\mathbb{R}^n$ sont les discrétisations des composantes du champ de vecteurs $u$ sur la grille choisie et $\partial_x:\mathbb{R}^n\rightarrow\mathbb{R}^n$
# * $\partial_y:\mathbb{R}^n\rightarrow\mathbb{R}^n$ représentent des opérateurs de différences finies.
#
# On peut ré-écrire $R(u)=\frac{1}{2}R_1(u)+ \frac{1}{2} R_2(u)$ avec :
# $$
# R_1(u)=\langle A_1 u , A_1 u\rangle,\qquad R_2(u)=\langle A_2 u , A_2 u\rangle.
# $$

# %% [markdown]
# Q2. Donner les formules de discrétisation des opérateurs $\partial_y$, $\partial_x^\top$ et $\partial_y^\top$. Implémenter ces opérateurs ci-après.

# %% [markdown]
# $$\begin{align}
# \langle \partial _x u, v \rangle &= \sum_{i=1}^{n-1}\sum_{j=1}^{n}(u_{i+1,j}-u_{ij})v_{ij}\\
# &=\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{i+1,j}v_{ij}-\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij}\\
# &=\sum_{i=2}^{n}\sum_{j=1}^{n}u_{i,j}v_{i-1,j}-\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij}\\
# &=\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{i,j}v_{i-1,j}-\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij} - \sum_{j=1}^{n} u_{1j}v_{1j} + \sum_{j=1}^{n} u_{nj}v_{n-1,j}\\
# &=\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{i,j}(v_{i-1,j}-v_{ij}) + \sum_{j=1}^{n} u_{nj}v_{n-1,j}-u_{1j}v_{1j}\\ \\ \\
# \end{align}$$

# %% [markdown]
# Par identification :
# $$\partial _x ^T=\begin{cases}f_{i-1,j}-f_{ij} \text{ si } i\geq 2  \text{ et } i \leq n-1 \\
#         f_{n-1,j} \text{ si } i=n \\
#         -f_{1,j} \text{ si } i=1 \end{cases} $$

# %% [markdown]
# $$\partial _y ^T=\begin{cases}f_{i,j-1}-f_{ij} \text{ si } j\in[2;n-1] \\
#         f_{i,n-1} \text{ si } j=n \\
#         -f_{i,1} \text{ si } j=1 \end{cases} $$

# %%
def dx(im) :
    d=np.zeros(im.shape)
    d[:-1,:]=im[1:,:]-im[:-1,:]
    return d
def dy(im) :
    d=np.zeros(im.shape)
    d[:,:-1]=im[:,1:]-im[:,:-1]
    return d
def dyT(im) :
    d=np.zeros(im.shape)
    d[:,0]=-im[:,0]
    d[:,-1]=im[:,-2]
    d[:,1:-1]=im[:,0:-2]-im[:,1:-1]   
    return d  
def dxT(im) :
    d=np.zeros(im.shape)
    d[0,:]=-im[0,:]
    d[-1,:]=im[-2,:]
    d[1:-1,:]=im[0:-2,:]-im[1:-1,:]    
    return d

# %% [markdown]
# Q3. On écrit $R(u)$ comme un opérateur de $V^2$ dans $\mathbb{R}$. Montrer que $R(u)$ peut s'écrire sous la forme:
# $$R(u)=\frac{1}{2} \langle A\left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right),\left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right)\rangle_{V^2},$$
# et donnez l'expression des matrices $A_1$ et $A_2$ en fonction des opérateurs $\partial_x$, $\partial_x^\top$, $\partial_y$ et $\partial_y^\top$.

# %% [markdown]
# Partons de $R(u)$ :
# $$R(u) = \frac{1}{2} R_1(u) + \frac{1}{2} R_2(u) = \frac{1}{2} \langle A_1u,A_1u \rangle + \frac{1}{2} \langle A_2u,A_2u \rangle$$
#
# A partir de l'expression de $R(u)$, nous pouvons retrouver l'expression de $A_1$ et de $A_2$ de la manière suivante :
# Pour $A_1$ :
#
# $$R_1(u) = \|A_1u\|^2 = \left\|A_1 \left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right)\right\|^2 = \mu \|\partial_x u_y + \partial_y u_x \|^2$$
# Donc, $$A_1 = \sqrt{\mu} \left( \partial_y \text{ } \partial_x \right)$$
#
# Pour $A_2$ :
#
# $$R_2(u) = \|A_2u\|^2 = \left\|A_2 \left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right)\right\|^2 = (\lambda + \mu) \|\partial_x u_x + \partial_y u_y \|^2 $$
# Donc, $$A_2 = \sqrt{\lambda + \mu} \left( \partial_x \text{ } \partial_y \right)$$

# %% [markdown]
# Q4. Donner l'expression du gradient de $R$.

# %% [markdown]
# Comme $R(u) = \frac{1}{2} R_1(u) + \frac{1}{2} R_2(u)$, on a $\nabla R(u) = \frac{1}{2} \nabla R_1(u) + \frac{1}{2} \nabla R_2(u)$.
#
#
# Par conséquent, nous allons calculer séparément $\nabla R_1$ et $\nabla R_2$ :
#
#
# Pour $\nabla R_1(u)$ :
#
# $$\begin{align}
# \nabla R_1(u) &= 2 A_1^T A_1 u \\
# &= 2\mu \left(\begin{array}{c}
# \partial_y^T\\
# \partial_x^T
# \end{array}\right) (\partial_y \text{ } \partial_x) \left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right) \\
# &= 2\mu \begin{pmatrix}\partial_y^T\partial_y & \partial_y^T\partial_x \\ \partial_x^T\partial_y & \partial_x^T\partial_x \end{pmatrix} \left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right) \\
# &= 2\mu \left(\begin{array}{c}\partial_y^T\partial_yu_x + \partial_y^T\partial_xu_y\\ \partial_x^T\partial_yu_x +  \partial_x^T\partial_xu_y\end{array}\right)
# \end{align}$$
#
# Pour $\nabla R_2(u)$ :
#
# $$\begin{align}
# \nabla R_2(u) &= 2 A_2^T A_2 u \\
# &= 2(\lambda +\mu) \left(\begin{array}{c}
# \partial_x^T\\
# \partial_y^T
# \end{array}\right) (\partial_x \text{ } \partial_y) \left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right) \\
# &= 2(\lambda +\mu) \begin{pmatrix}\partial_x^T\partial_x & \partial_x^T\partial_y \\ \partial_y^T\partial_x & \partial_y^T\partial_y \end{pmatrix} \left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right) \\
# &= 2(\lambda +\mu) \left(\begin{array}{c}\partial_x^T\partial_x u_x + \partial_x^T\partial_y u_y\\ \partial_y^T\partial_x u_x +  \partial_y^T\partial_y u_y\end{array}\right)
# \end{align}$$
#
# On retrouve donc
# $$ \nabla R(u) = \frac{1}{2} \nabla R_1(u) + \frac{1}{2} \nabla R_2(u) = \mu \left(\begin{array}{c}\partial_y^T\partial_yu_x + \partial_y^T\partial_xu_y\\ \partial_x^T\partial_yu_x +  \partial_x^T\partial_xu_y\end{array}\right) + (\lambda +\mu) \left(\begin{array}{c}\partial_x^T\partial_x u_x + \partial_x^T\partial_y u_y\\ \partial_y^T\partial_x u_x +  \partial_y^T\partial_y u_y\end{array}\right)
# $$

# %% [markdown]
# 2.3. Implémentation de la fonction objectif $E+R$
# ----------------------------------------------------------------

# %%
def objective_function(f,g,ux,uy,lamb,mu) :   
    
    #implementation de E(u)+R(u)
    fu=interpol(f,ux,uy)
    
    #Calcul de R
    R= mu/2 * npl.norm(dx(uy)+dy(ux))**2 + (lamb+mu)/2 * npl.norm(dx(ux)+dy(uy))**2
    
    #Calcul de E
    E=1/2*npl.norm(fu-g)**2        
    
    return R+E,fu

# %% [markdown]
# # 3. Algorithme de gradient à pas fixe

# %% [markdown]
# Une itération de la méthode de descente de gradient est de la forme:
#
# $$
# u_{k+1}=u_k-s_k(\nabla E(u) + \nabla R(u))
# $$

# %% [markdown]
# Q5. Compléter la fonction RecalageDG implémentant la descente de gradient et utilisant l'algorithme de recherche linéaire proposé ci-dessous.

# %%
def linesearch(ux,uy,step,descentx,descenty,obj_old,f,g,lamb,mu) :
    step=2*step
    tmpx=ux-step*descentx
    tmpy=uy-step*descenty
    obj,fu=objective_function(f,g,tmpx,tmpy,lamb,mu)
    while obj >obj_old and step > 1.e-8:
        step=0.5*step
        tmpx=ux-step*descentx
        tmpy=uy-step*descenty
        obj,fu=objective_function(f,g,tmpx,tmpy,lamb,mu)
    return tmpx,tmpy,step

# %%
def RecalageDG(f,g,lamb,mu,nitermax,stepini) : 
    ux=np.zeros(f.shape)
    uy=np.zeros(f.shape)  
    CF=[]
    step_list=[]
    niter=0
    step=stepini
        
    dfx = dx(f)
    dfy = dy(f)
    while niter < nitermax and step > 1.e-8 : 
        niter+=1
        obj,fu=objective_function(f,g,ux,uy,lamb,mu)
        CF.append(obj)   
        # Gradient of E at point u
        gradEx=(fu-g)*(interpol(dfx,ux,uy))
        gradEy=(fu-g)*(interpol(dfy,ux,uy))
        
        # Gradient of R at point u
        gradRx = mu*dyT(dy(ux)) + (lamb+mu)*dxT(dx(ux)) + mu*dyT(dx(uy)) + (lamb+mu)*dxT(dy(uy))
        gradRy = mu*dxT(dy(ux)) + (mu+lamb)*dyT(dx(ux)) + mu*dxT(dx(uy)) + (lamb+mu)*dyT(dy(uy))
        
        
        # Gradient of E+R at point u
        gradx=gradEx+gradRx
        grady=gradEy+gradRy
       
    
        ux,uy,step=linesearch(ux,uy,step,gradx,grady,obj,f,g,lamb,mu)
        step_list.append(step)
        if (niter % 3 ==0) :
            print('iteration :',niter,' cost function :',obj,'step :',step)
    return ux,uy,np.array(CF),np.array(step_list),niter

# %% [markdown]
# <font color='blue'>
# Nous recherchons un $\lambda$ et un $\mu$ optimaux qui permettent de faire converger l'algorithme en le moins d'itérations possible. Pour cela, nous allons tester la fonction RecalageDG avec plusieurs valeurs de $\lambda$ et conserver celle qui nous permet d'avoir le $niter$ le plus petit possible.
# </font>

# %%
v_lamb0 = np.linspace(-1,1.5,10)
v_mu0 = np.copy(0.1*v_lamb0)
niter0 = np.zeros(10)
step0=0.1

for i in range(10) :
    ux,uy,CF,step,niter0[i]=RecalageDG(f,g,v_lamb0[i],v_mu0[i],5000,step0)
# Out:
# iteration : 3  cost function : 18.53141566008521 step : 0.8
# iteration : 6  cost function : -324.44830313467656 step : 6.4
# iteration : 9  cost function : -1883674384904.5825 step : 51.2
# iteration : 12  cost function : -1.3387703798139054e+28 step : 409.6
# iteration : 15  cost function : -1.0809136425994618e+50 step : 3276.8
# iteration : 18  cost function : -1.6330452125724037e+78 step : 26214.4
# iteration : 21  cost function : -1.2102010729983564e+112 step : 209715.2
# iteration : 24  cost function : -3.0084284686468276e+151 step : 1677721.6
# iteration : 27  cost function : -2.2865475924597566e+196 step : 13421772.8
# iteration : 30  cost function : -5.02978963724009e+246 step : 107374182.4
# iteration : 33  cost function : -3.089672814077165e+302 step : 858993459.2
# iteration : 36  cost function : -inf step : 6871947673.6
# iteration : 39  cost function : -inf step : 54975581388.8
# iteration : 42  cost function : -inf step : 439804651110.4
# iteration : 45  cost function : -inf step : 3518437208883.2
# iteration : 48  cost function : nan step : 28147497671065.6
# iteration : 51  cost function : nan step : 225179981368524.8
# iteration : 54  cost function : nan step : 1801439850948198.5
# iteration : 57  cost function : nan step : 1.4411518807585588e+16
# iteration : 60  cost function : nan step : 1.152921504606847e+17
# iteration : 63  cost function : nan step : 9.223372036854776e+17
# iteration : 66  cost function : nan step : 7.378697629483821e+18
# iteration : 69  cost function : nan step : 5.902958103587057e+19
# iteration : 72  cost function : nan step : 4.7223664828696455e+20
# iteration : 75  cost function : nan step : 3.7778931862957164e+21
# iteration : 78  cost function : nan step : 3.022314549036573e+22
# iteration : 81  cost function : nan step : 2.4178516392292585e+23
# iteration : 84  cost function : nan step : 1.9342813113834068e+24
# iteration : 87  cost function : nan step : 1.5474250491067254e+25
# iteration : 90  cost function : nan step : 1.2379400392853803e+26
# iteration : 93  cost function : nan step : 9.903520314283043e+26
# iteration : 96  cost function : nan step : 7.922816251426434e+27
# iteration : 99  cost function : nan step : 6.338253001141147e+28
# iteration : 102  cost function : nan step : 5.070602400912918e+29
# iteration : 105  cost function : nan step : 4.0564819207303343e+30
# iteration : 108  cost function : nan step : 3.2451855365842674e+31
# iteration : 111  cost function : nan step : 2.596148429267414e+32
# iteration : 114  cost function : nan step : 2.0769187434139312e+33
# iteration : 117  cost function : nan step : 1.661534994731145e+34
# iteration : 120  cost function : nan step : 1.329227995784916e+35
# iteration : 123  cost function : nan step : 1.0633823966279328e+36
# iteration : 126  cost function : nan step : 8.507059173023462e+36
# iteration : 129  cost function : nan step : 6.80564733841877e+37
# iteration : 132  cost function : nan step : 5.444517870735016e+38
# iteration : 135  cost function : nan step : 4.3556142965880126e+39
# iteration : 138  cost function : nan step : 3.48449143727041e+40
# iteration : 141  cost function : nan step : 2.787593149816328e+41
# iteration : 144  cost function : nan step : 2.2300745198530624e+42
# iteration : 147  cost function : nan step : 1.78405961588245e+43
# iteration : 150  cost function : nan step : 1.42724769270596e+44
# iteration : 153  cost function : nan step : 1.141798154164768e+45
# iteration : 156  cost function : nan step : 9.134385233318144e+45
# iteration : 159  cost function : nan step : 7.307508186654515e+46
# iteration : 162  cost function : nan step : 5.846006549323612e+47
# iteration : 165  cost function : nan step : 4.6768052394588896e+48
# iteration : 168  cost function : nan step : 3.7414441915671117e+49
# iteration : 171  cost function : nan step : 2.9931553532536893e+50
# iteration : 174  cost function : nan step : 2.3945242826029515e+51
# iteration : 177  cost function : nan step : 1.9156194260823612e+52
# iteration : 180  cost function : nan step : 1.532495540865889e+53
# iteration : 183  cost function : nan step : 1.2259964326927112e+54
# iteration : 186  cost function : nan step : 9.807971461541689e+54
# /usr/local/insa/anaconda/envs/GPU/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in multiply
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/insa/anaconda/envs/GPU/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# /usr/local/insa/anaconda/envs/GPU/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in subtract
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/insa/anaconda/envs/GPU/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in subtract
#   import sys
# /usr/local/insa/anaconda/envs/GPU/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in add
#   import sys
# /usr/local/insa/anaconda/envs/GPU/lib/python3.6/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in subtract
#   del sys.path[0]
# /usr/local/insa/anaconda/envs/GPU/lib/python3.6/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in subtract
# iteration : 189  cost function : nan step : 7.846377169233351e+55
# iteration : 192  cost function : nan step : 6.277101735386681e+56
# iteration : 195  cost function : nan step : 5.021681388309345e+57
# iteration : 198  cost function : nan step : 4.017345110647476e+58
# iteration : 201  cost function : nan step : 3.2138760885179807e+59
# iteration : 204  cost function : nan step : 2.5711008708143846e+60
# iteration : 207  cost function : nan step : 2.0568806966515077e+61
# iteration : 210  cost function : nan step : 1.6455045573212061e+62
# iteration : 213  cost function : nan step : 1.3164036458569649e+63
# iteration : 216  cost function : nan step : 1.0531229166855719e+64
# iteration : 219  cost function : nan step : 8.424983333484575e+64
# iteration : 222  cost function : nan step : 6.73998666678766e+65
# iteration : 225  cost function : nan step : 5.391989333430128e+66
# iteration : 228  cost function : nan step : 4.3135914667441026e+67
# iteration : 231  cost function : nan step : 3.450873173395282e+68
# iteration : 234  cost function : nan step : 2.7606985387162257e+69
# iteration : 237  cost function : nan step : 2.2085588309729805e+70
# iteration : 240  cost function : nan step : 1.7668470647783844e+71
# iteration : 243  cost function : nan step : 1.4134776518227075e+72
# iteration : 246  cost function : nan step : 1.130782121458166e+73
# iteration : 249  cost function : nan step : 9.046256971665328e+73
# iteration : 252  cost function : nan step : 7.237005577332263e+74
# iteration : 255  cost function : nan step : 5.78960446186581e+75
# iteration : 258  cost function : nan step : 4.631683569492648e+76
# iteration : 261  cost function : nan step : 3.7053468555941185e+77
# iteration : 264  cost function : nan step : 2.9642774844752948e+78
# iteration : 267  cost function : nan step : 2.3714219875802358e+79
# iteration : 270  cost function : nan step : 1.8971375900641887e+80
# iteration : 273  cost function : nan step : 1.517710072051351e+81
# iteration : 276  cost function : nan step : 1.2141680576410807e+82
# iteration : 279  cost function : nan step : 9.713344461128646e+82
# iteration : 282  cost function : nan step : 7.770675568902917e+83
# iteration : 285  cost function : nan step : 6.216540455122333e+84
# iteration : 288  cost function : nan step : 4.973232364097867e+85
# iteration : 291  cost function : nan step : 3.9785858912782934e+86
# iteration : 294  cost function : nan step : 3.1828687130226347e+87
# iteration : 297  cost function : nan step : 2.5462949704181077e+88
# iteration : 300  cost function : nan step : 2.0370359763344862e+89
# iteration : 303  cost function : nan step : 1.629628781067589e+90
# iteration : 306  cost function : nan step : 1.3037030248540712e+91
# iteration : 309  cost function : nan step : 1.042962419883257e+92
# iteration : 312  cost function : nan step : 8.343699359066055e+92
# iteration : 315  cost function : nan step : 6.674959487252844e+93
# iteration : 318  cost function : nan step : 5.3399675898022755e+94
# iteration : 321  cost function : nan step : 4.2719740718418204e+95
# iteration : 324  cost function : nan step : 3.4175792574734563e+96
# iteration : 327  cost function : nan step : 2.734063405978765e+97
# iteration : 330  cost function : nan step : 2.187250724783012e+98
# iteration : 333  cost function : nan step : 1.7498005798264096e+99
# iteration : 336  cost function : nan step : 1.3998404638611277e+100
# iteration : 339  cost function : nan step : 1.1198723710889022e+101
# iteration : 342  cost function : nan step : 8.958978968711217e+101
# iteration : 345  cost function : nan step : 7.167183174968974e+102
# iteration : 348  cost function : nan step : 5.733746539975179e+103
# iteration : 351  cost function : nan step : 4.586997231980143e+104
# iteration : 354  cost function : nan step : 3.6695977855841146e+105
# iteration : 357  cost function : nan step : 2.9356782284672917e+106
# iteration : 360  cost function : nan step : 2.3485425827738334e+107
# iteration : 363  cost function : nan step : 1.8788340662190667e+108
# iteration : 366  cost function : nan step : 1.5030672529752533e+109
# iteration : 369  cost function : nan step : 1.2024538023802027e+110
# iteration : 372  cost function : nan step : 9.619630419041621e+110
# iteration : 375  cost function : nan step : 7.695704335233297e+111
# iteration : 378  cost function : nan step : 6.156563468186638e+112
# iteration : 381  cost function : nan step : 4.92525077454931e+113
# iteration : 384  cost function : nan step : 3.940200619639448e+114
# iteration : 387  cost function : nan step : 3.1521604957115585e+115
# iteration : 390  cost function : nan step : 2.5217283965692468e+116
# iteration : 393  cost function : nan step : 2.0173827172553974e+117
# iteration : 396  cost function : nan step : 1.613906173804318e+118
# iteration : 399  cost function : nan step : 1.2911249390434544e+119
# iteration : 402  cost function : nan step : 1.0328999512347635e+120
# iteration : 405  cost function : nan step : 8.263199609878108e+120
# iteration : 408  cost function : nan step : 6.610559687902486e+121
# iteration : 411  cost function : nan step : 5.288447750321989e+122
# iteration : 414  cost function : nan step : 4.230758200257591e+123
# iteration : 417  cost function : nan step : 3.384606560206073e+124
# iteration : 420  cost function : nan step : 2.7076852481648584e+125
# iteration : 423  cost function : nan step : 2.1661481985318867e+126
# iteration : 426  cost function : nan step : 1.7329185588255094e+127
# iteration : 429  cost function : nan step : 1.3863348470604075e+128
# iteration : 432  cost function : nan step : 1.109067877648326e+129
# iteration : 435  cost function : nan step : 8.872543021186608e+129
# iteration : 438  cost function : nan step : 7.098034416949286e+130
# iteration : 441  cost function : nan step : 5.678427533559429e+131
# iteration : 444  cost function : nan step : 4.5427420268475433e+132
# iteration : 447  cost function : nan step : 3.6341936214780347e+133
# iteration : 450  cost function : nan step : 2.9073548971824277e+134
# iteration : 453  cost function : nan step : 2.3258839177459422e+135
# iteration : 456  cost function : nan step : 1.8607071341967537e+136
# iteration : 459  cost function : nan step : 1.488565707357403e+137
# iteration : 462  cost function : nan step : 1.1908525658859224e+138
# iteration : 465  cost function : nan step : 9.526820527087379e+138
# iteration : 468  cost function : nan step : 7.621456421669903e+139
# iteration : 471  cost function : nan step : 6.097165137335923e+140
# iteration : 474  cost function : nan step : 4.877732109868738e+141
# iteration : 477  cost function : nan step : 3.9021856878949905e+142
# iteration : 480  cost function : nan step : 3.1217485503159924e+143
# iteration : 483  cost function : nan step : 2.497398840252794e+144
# iteration : 486  cost function : nan step : 1.9979190722022351e+145
# iteration : 489  cost function : nan step : 1.5983352577617881e+146
# iteration : 492  cost function : nan step : 1.2786682062094305e+147
# iteration : 495  cost function : nan step : 1.0229345649675444e+148
# iteration : 498  cost function : nan step : 8.183476519740355e+148
# iteration : 501  cost function : nan step : 6.546781215792284e+149
# iteration : 504  cost function : nan step : 5.237424972633827e+150
# iteration : 507  cost function : nan step : 4.189939978107062e+151
# iteration : 510  cost function : nan step : 3.3519519824856495e+152
# iteration : 513  cost function : nan step : 2.6815615859885196e+153
# iteration : 516  cost function : nan step : 2.1452492687908157e+154
# iteration : 519  cost function : nan step : 1.7161994150326525e+155
# iteration : 522  cost function : nan step : 1.372959532026122e+156
# iteration : 525  cost function : nan step : 1.0983676256208976e+157
# iteration : 528  cost function : nan step : 8.786941004967181e+157
# iteration : 531  cost function : nan step : 7.029552803973745e+158
# iteration : 534  cost function : nan step : 5.623642243178996e+159
# iteration : 537  cost function : nan step : 4.4989137945431966e+160
# iteration : 540  cost function : nan step : 3.5991310356345573e+161
# iteration : 543  cost function : nan step : 2.879304828507646e+162
# iteration : 546  cost function : nan step : 2.3034438628061167e+163
# iteration : 549  cost function : nan step : 1.8427550902448933e+164
# iteration : 552  cost function : nan step : 1.4742040721959147e+165
# iteration : 555  cost function : nan step : 1.1793632577567317e+166
# iteration : 558  cost function : nan step : 9.434906062053854e+166
# iteration : 561  cost function : nan step : 7.547924849643083e+167
# iteration : 564  cost function : nan step : 6.0383398797144665e+168
# iteration : 567  cost function : nan step : 4.830671903771573e+169
# iteration : 570  cost function : nan step : 3.8645375230172586e+170
# iteration : 573  cost function : nan step : 3.091630018413807e+171
# iteration : 576  cost function : nan step : 2.4733040147310455e+172
# iteration : 579  cost function : nan step : 1.9786432117848364e+173
# iteration : 582  cost function : nan step : 1.582914569427869e+174
# iteration : 585  cost function : nan step : 1.2663316555422953e+175
# iteration : 588  cost function : nan step : 1.0130653244338362e+176
# iteration : 591  cost function : nan step : 8.10452259547069e+176
# iteration : 594  cost function : nan step : 6.483618076376552e+177
# iteration : 597  cost function : nan step : 5.1868944611012415e+178
# iteration : 600  cost function : nan step : 4.149515568880993e+179
# iteration : 603  cost function : nan step : 3.3196124551047946e+180
# iteration : 606  cost function : nan step : 2.6556899640838356e+181
# iteration : 609  cost function : nan step : 2.1245519712670685e+182
# iteration : 612  cost function : nan step : 1.6996415770136548e+183
# iteration : 615  cost function : nan step : 1.3597132616109238e+184
# iteration : 618  cost function : nan step : 1.0877706092887391e+185
# iteration : 621  cost function : nan step : 8.702164874309913e+185
# iteration : 624  cost function : nan step : 6.96173189944793e+186
# iteration : 627  cost function : nan step : 5.569385519558344e+187
# iteration : 630  cost function : nan step : 4.455508415646675e+188
# iteration : 633  cost function : nan step : 3.56440673251734e+189
# iteration : 636  cost function : nan step : 2.851525386013872e+190
# iteration : 639  cost function : nan step : 2.2812203088110977e+191
# iteration : 642  cost function : nan step : 1.8249762470488782e+192
# iteration : 645  cost function : nan step : 1.4599809976391026e+193
# iteration : 648  cost function : nan step : 1.167984798111282e+194
# iteration : 651  cost function : nan step : 9.343878384890256e+194
# iteration : 654  cost function : nan step : 7.475102707912205e+195
# iteration : 657  cost function : nan step : 5.980082166329764e+196
# iteration : 660  cost function : nan step : 4.784065733063811e+197
# iteration : 663  cost function : nan step : 3.827252586451049e+198
# iteration : 666  cost function : nan step : 3.061802069160839e+199
# iteration : 669  cost function : nan step : 2.4494416553286714e+200
# iteration : 672  cost function : nan step : 1.959553324262937e+201
# iteration : 675  cost function : nan step : 1.5676426594103497e+202
# iteration : 678  cost function : nan step : 1.2541141275282797e+203
# iteration : 681  cost function : nan step : 1.0032913020226238e+204
# iteration : 684  cost function : nan step : 8.02633041618099e+204
# iteration : 687  cost function : nan step : 6.421064332944792e+205
# iteration : 690  cost function : nan step : 5.136851466355834e+206
# iteration : 693  cost function : nan step : 4.109481173084667e+207
# iteration : 696  cost function : nan step : 3.2875849384677336e+208
# iteration : 699  cost function : nan step : 2.630067950774187e+209
# iteration : 702  cost function : nan step : 2.1040543606193495e+210
# iteration : 705  cost function : nan step : 1.6832434884954796e+211
# iteration : 708  cost function : nan step : 1.3465947907963837e+212
# iteration : 711  cost function : nan step : 1.077275832637107e+213
# iteration : 714  cost function : nan step : 8.618206661096856e+213
# iteration : 717  cost function : nan step : 6.8945653288774845e+214
# iteration : 720  cost function : nan step : 5.5156522631019876e+215
# iteration : 723  cost function : nan step : 4.41252181048159e+216
# iteration : 726  cost function : nan step : 3.530017448385272e+217
# iteration : 729  cost function : nan step : 2.8240139587082177e+218
# iteration : 732  cost function : nan step : 2.259211166966574e+219
# iteration : 735  cost function : nan step : 1.8073689335732593e+220
# iteration : 738  cost function : nan step : 1.4458951468586074e+221
# iteration : 741  cost function : nan step : 1.156716117486886e+222
# iteration : 744  cost function : nan step : 9.253728939895088e+222
# iteration : 747  cost function : nan step : 7.40298315191607e+223
# iteration : 750  cost function : nan step : 5.922386521532856e+224
# iteration : 753  cost function : nan step : 4.737909217226285e+225
# iteration : 756  cost function : nan step : 3.790327373781028e+226
# iteration : 759  cost function : nan step : 3.0322618990248223e+227
# iteration : 762  cost function : nan step : 2.425809519219858e+228
# iteration : 765  cost function : nan step : 1.9406476153758863e+229
# iteration : 768  cost function : nan step : 1.552518092300709e+230
# iteration : 771  cost function : nan step : 1.2420144738405672e+231
# iteration : 774  cost function : nan step : 9.936115790724538e+231
# iteration : 777  cost function : nan step : 7.94889263257963e+232
# iteration : 780  cost function : nan step : 6.359114106063704e+233
# iteration : 783  cost function : nan step : 5.087291284850963e+234
# iteration : 786  cost function : nan step : 4.0698330278807707e+235
# iteration : 789  cost function : nan step : 3.2558664223046165e+236
# iteration : 792  cost function : nan step : 2.6046931378436932e+237
# iteration : 795  cost function : nan step : 2.0837545102749546e+238
# iteration : 798  cost function : nan step : 1.6670036082199637e+239
# iteration : 801  cost function : nan step : 1.333602886575971e+240
# iteration : 804  cost function : nan step : 1.0668823092607767e+241
# iteration : 807  cost function : nan step : 8.535058474086214e+241
# iteration : 810  cost function : nan step : 6.828046779268971e+242
# iteration : 813  cost function : nan step : 5.462437423415177e+243
# iteration : 816  cost function : nan step : 4.3699499387321415e+244
# iteration : 819  cost function : nan step : 3.495959950985713e+245
# iteration : 822  cost function : nan step : 2.7967679607885706e+246
# iteration : 825  cost function : nan step : 2.2374143686308565e+247
# iteration : 828  cost function : nan step : 1.7899314949046852e+248
# iteration : 831  cost function : nan step : 1.4319451959237481e+249
# iteration : 834  cost function : nan step : 1.1455561567389985e+250
# iteration : 837  cost function : nan step : 9.164449253911988e+250
# iteration : 840  cost function : nan step : 7.33155940312959e+251
# iteration : 843  cost function : nan step : 5.865247522503672e+252
# iteration : 846  cost function : nan step : 4.692198018002938e+253
# iteration : 849  cost function : nan step : 3.7537584144023503e+254
# iteration : 852  cost function : nan step : 3.0030067315218803e+255
# iteration : 855  cost function : nan step : 2.4024053852175042e+256
# iteration : 858  cost function : nan step : 1.9219243081740034e+257
# iteration : 861  cost function : nan step : 1.5375394465392027e+258
# iteration : 864  cost function : nan step : 1.2300315572313622e+259
# iteration : 867  cost function : nan step : 9.840252457850897e+259
# iteration : 870  cost function : nan step : 7.872201966280718e+260
# iteration : 873  cost function : nan step : 6.297761573024574e+261
# iteration : 876  cost function : nan step : 5.0382092584196594e+262
# iteration : 879  cost function : nan step : 4.0305674067357275e+263
# iteration : 882  cost function : nan step : 3.224453925388582e+264
# iteration : 885  cost function : nan step : 2.5795631403108656e+265
# iteration : 888  cost function : nan step : 2.0636505122486925e+266
# iteration : 891  cost function : nan step : 1.650920409798954e+267
# iteration : 894  cost function : nan step : 1.3207363278391632e+268
# iteration : 897  cost function : nan step : 1.0565890622713306e+269
# iteration : 900  cost function : nan step : 8.452712498170644e+269
# iteration : 903  cost function : nan step : 6.7621699985365155e+270
# iteration : 906  cost function : nan step : 5.4097359988292124e+271
# iteration : 909  cost function : nan step : 4.32778879906337e+272
# iteration : 912  cost function : nan step : 3.462231039250696e+273
# iteration : 915  cost function : nan step : 2.7697848314005568e+274
# iteration : 918  cost function : nan step : 2.2158278651204454e+275
# iteration : 921  cost function : nan step : 1.7726622920963563e+276
# iteration : 924  cost function : nan step : 1.418129833677085e+277
# iteration : 927  cost function : nan step : 1.134503866941668e+278
# iteration : 930  cost function : nan step : 9.076030935533344e+278
# iteration : 933  cost function : nan step : 7.260824748426676e+279
# iteration : 936  cost function : nan step : 5.8086597987413404e+280
# iteration : 939  cost function : nan step : 4.6469278389930723e+281
# iteration : 942  cost function : nan step : 3.717542271194458e+282
# iteration : 945  cost function : nan step : 2.9740338169555663e+283
# iteration : 948  cost function : nan step : 2.379227053564453e+284
# iteration : 951  cost function : nan step : 1.9033816428515624e+285
# iteration : 954  cost function : nan step : 1.52270531428125e+286
# iteration : 957  cost function : nan step : 1.218164251425e+287
# iteration : 960  cost function : nan step : 9.7453140114e+287
# iteration : 963  cost function : nan step : 7.79625120912e+288
# iteration : 966  cost function : nan step : 6.237000967296e+289
# iteration : 969  cost function : nan step : 4.9896007738368e+290
# iteration : 972  cost function : nan step : 3.99168061906944e+291
# iteration : 975  cost function : nan step : 3.193344495255552e+292
# iteration : 978  cost function : nan step : 2.5546755962044415e+293
# iteration : 981  cost function : nan step : 2.0437404769635532e+294
# iteration : 984  cost function : nan step : 1.6349923815708426e+295
# iteration : 987  cost function : nan step : 1.307993905256674e+296
# iteration : 990  cost function : nan step : 1.0463951242053392e+297
# iteration : 993  cost function : nan step : 8.371160993642714e+297
# iteration : 996  cost function : nan step : 6.696928794914171e+298
# iteration : 999  cost function : nan step : 5.357543035931337e+299
# iteration : 1002  cost function : nan step : 4.2860344287450695e+300
# iteration : 1005  cost function : nan step : 3.4288275429960556e+301
# iteration : 1008  cost function : nan step : 2.7430620343968445e+302
# iteration : 1011  cost function : nan step : 2.1944496275174756e+303
# iteration : 1014  cost function : nan step : 1.7555597020139805e+304
# iteration : 1017  cost function : nan step : 1.4044477616111844e+305
# iteration : 1020  cost function : nan step : 1.1235582092889475e+306
# iteration : 1023  cost function : nan step : 8.98846567431158e+306
# iteration : 1026  cost function : nan step : 7.190772539449264e+307
# iteration : 1029  cost function : nan step : inf
# iteration : 1032  cost function : nan step : inf
# iteration : 1035  cost function : nan step : inf
# iteration : 1038  cost function : nan step : inf
# iteration : 1041  cost function : nan step : inf
# iteration : 1044  cost function : nan step : inf
# iteration : 1047  cost function : nan step : inf
# iteration : 1050  cost function : nan step : inf
# iteration : 1053  cost function : nan step : inf
# iteration : 1056  cost function : nan step : inf
# iteration : 1059  cost function : nan step : inf
# iteration : 1062  cost function : nan step : inf
# iteration : 1065  cost function : nan step : inf
# iteration : 1068  cost function : nan step : inf
# iteration : 1071  cost function : nan step : inf
# iteration : 1074  cost function : nan step : inf
# iteration : 1077  cost function : nan step : inf
# iteration : 1080  cost function : nan step : inf
# iteration : 1083  cost function : nan step : inf
# iteration : 1086  cost function : nan step : inf
# iteration : 1089  cost function : nan step : inf
# iteration : 1092  cost function : nan step : inf
# iteration : 1095  cost function : nan step : inf
# iteration : 1098  cost function : nan step : inf
# iteration : 1101  cost function : nan step : inf
# iteration : 1104  cost function : nan step : inf
# iteration : 1107  cost function : nan step : inf
# iteration : 1110  cost function : nan step : inf
# iteration : 1113  cost function : nan step : inf
# iteration : 1116  cost function : nan step : inf
# iteration : 1119  cost function : nan step : inf
# iteration : 1122  cost function : nan step : inf
# iteration : 1125  cost function : nan step : inf
# iteration : 1128  cost function : nan step : inf
# iteration : 1131  cost function : nan step : inf
# iteration : 1134  cost function : nan step : inf
# iteration : 1137  cost function : nan step : inf
# iteration : 1140  cost function : nan step : inf
# iteration : 1143  cost function : nan step : inf
# iteration : 1146  cost function : nan step : inf
# iteration : 1149  cost function : nan step : inf
# iteration : 1152  cost function : nan step : inf
# iteration : 1155  cost function : nan step : inf
# iteration : 1158  cost function : nan step : inf
# iteration : 1161  cost function : nan step : inf
# iteration : 1164  cost function : nan step : inf
# iteration : 1167  cost function : nan step : inf
# iteration : 1170  cost function : nan step : inf
# iteration : 1173  cost function : nan step : inf
# iteration : 1176  cost function : nan step : inf
# iteration : 1179  cost function : nan step : inf
# iteration : 1182  cost function : nan step : inf
# iteration : 1185  cost function : nan step : inf
# iteration : 1188  cost function : nan step : inf
# iteration : 1191  cost function : nan step : inf
# iteration : 1194  cost function : nan step : inf
# iteration : 1197  cost function : nan step : inf
# iteration : 1200  cost function : nan step : inf
# iteration : 1203  cost function : nan step : inf
# iteration : 1206  cost function : nan step : inf
# iteration : 1209  cost function : nan step : inf
# iteration : 1212  cost function : nan step : inf
# iteration : 1215  cost function : nan step : inf
# iteration : 1218  cost function : nan step : inf
# iteration : 1221  cost function : nan step : inf
# iteration : 1224  cost function : nan step : inf
# iteration : 1227  cost function : nan step : inf
# iteration : 1230  cost function : nan step : inf
# iteration : 1233  cost function : nan step : inf
# iteration : 1236  cost function : nan step : inf
# iteration : 1239  cost function : nan step : inf
# iteration : 1242  cost function : nan step : inf
# iteration : 1245  cost function : nan step : inf
# iteration : 1248  cost function : nan step : inf
# iteration : 1251  cost function : nan step : inf
# iteration : 1254  cost function : nan step : inf
# iteration : 1257  cost function : nan step : inf
# iteration : 1260  cost function : nan step : inf
# iteration : 1263  cost function : nan step : inf
# iteration : 1266  cost function : nan step : inf
# iteration : 1269  cost function : nan step : inf
# iteration : 1272  cost function : nan step : inf
# iteration : 1275  cost function : nan step : inf
# iteration : 1278  cost function : nan step : inf
# iteration : 1281  cost function : nan step : inf
# iteration : 1284  cost function : nan step : inf
# iteration : 1287  cost function : nan step : inf
# iteration : 1290  cost function : nan step : inf
# iteration : 1293  cost function : nan step : inf
# iteration : 1296  cost function : nan step : inf
# iteration : 1299  cost function : nan step : inf
# iteration : 1302  cost function : nan step : inf
# iteration : 1305  cost function : nan step : inf
# iteration : 1308  cost function : nan step : inf
# iteration : 1311  cost function : nan step : inf
# iteration : 1314  cost function : nan step : inf
# iteration : 1317  cost function : nan step : inf
# iteration : 1320  cost function : nan step : inf
# iteration : 1323  cost function : nan step : inf
# iteration : 1326  cost function : nan step : inf
# iteration : 1329  cost function : nan step : inf
# iteration : 1332  cost function : nan step : inf
# iteration : 1335  cost function : nan step : inf
# iteration : 1338  cost function : nan step : inf
# iteration : 1341  cost function : nan step : inf
# iteration : 1344  cost function : nan step : inf
# iteration : 1347  cost function : nan step : inf
# iteration : 1350  cost function : nan step : inf
# iteration : 1353  cost function : nan step : inf
# iteration : 1356  cost function : nan step : inf
# iteration : 1359  cost function : nan step : inf
# iteration : 1362  cost function : nan step : inf
# iteration : 1365  cost function : nan step : inf
# iteration : 1368  cost function : nan step : inf
# iteration : 1371  cost function : nan step : inf
# iteration : 1374  cost function : nan step : inf
# iteration : 1377  cost function : nan step : inf
# iteration : 1380  cost function : nan step : inf
# iteration : 1383  cost function : nan step : inf
# iteration : 1386  cost function : nan step : inf
# iteration : 1389  cost function : nan step : inf
# iteration : 1392  cost function : nan step : inf
# iteration : 1395  cost function : nan step : inf
# iteration : 1398  cost function : nan step : inf
# iteration : 1401  cost function : nan step : inf
# iteration : 1404  cost function : nan step : inf
# iteration : 1407  cost function : nan step : inf
# iteration : 1410  cost function : nan step : inf
# iteration : 1413  cost function : nan step : inf
# iteration : 1416  cost function : nan step : inf
# iteration : 1419  cost function : nan step : inf
# iteration : 1422  cost function : nan step : inf
# iteration : 1425  cost function : nan step : inf
# iteration : 1428  cost function : nan step : inf
# iteration : 1431  cost function : nan step : inf
# iteration : 1434  cost function : nan step : inf
# iteration : 1437  cost function : nan step : inf
# iteration : 1440  cost function : nan step : inf
# iteration : 1443  cost function : nan step : inf
# iteration : 1446  cost function : nan step : inf
# iteration : 1449  cost function : nan step : inf
# iteration : 1452  cost function : nan step : inf
# iteration : 1455  cost function : nan step : inf
# iteration : 1458  cost function : nan step : inf
# iteration : 1461  cost function : nan step : inf
# iteration : 1464  cost function : nan step : inf
# iteration : 1467  cost function : nan step : inf
# iteration : 1470  cost function : nan step : inf
# iteration : 1473  cost function : nan step : inf
# iteration : 1476  cost function : nan step : inf
# iteration : 1479  cost function : nan step : inf
# iteration : 1482  cost function : nan step : inf
# iteration : 1485  cost function : nan step : inf
# iteration : 1488  cost function : nan step : inf
# iteration : 1491  cost function : nan step : inf
# iteration : 1494  cost function : nan step : inf
# iteration : 1497  cost function : nan step : inf
# iteration : 1500  cost function : nan step : inf
# iteration : 1503  cost function : nan step : inf
# iteration : 1506  cost function : nan step : inf
# iteration : 1509  cost function : nan step : inf
# iteration : 1512  cost function : nan step : inf
# iteration : 1515  cost function : nan step : inf
# iteration : 1518  cost function : nan step : inf
# iteration : 1521  cost function : nan step : inf
# iteration : 1524  cost function : nan step : inf
# iteration : 1527  cost function : nan step : inf
# iteration : 1530  cost function : nan step : inf
# iteration : 1533  cost function : nan step : inf
# iteration : 1536  cost function : nan step : inf
# iteration : 1539  cost function : nan step : inf
# iteration : 1542  cost function : nan step : inf
# iteration : 1545  cost function : nan step : inf
# iteration : 1548  cost function : nan step : inf
# iteration : 1551  cost function : nan step : inf
# iteration : 1554  cost function : nan step : inf
# iteration : 1557  cost function : nan step : inf
# iteration : 1560  cost function : nan step : inf
# iteration : 1563  cost function : nan step : inf
# iteration : 1566  cost function : nan step : inf
# iteration : 1569  cost function : nan step : inf
# iteration : 1572  cost function : nan step : inf
# iteration : 1575  cost function : nan step : inf
# iteration : 1578  cost function : nan step : inf
# iteration : 1581  cost function : nan step : inf
# iteration : 1584  cost function : nan step : inf
# iteration : 1587  cost function : nan step : inf
# iteration : 1590  cost function : nan step : inf
# iteration : 1593  cost function : nan step : inf
# iteration : 1596  cost function : nan step : inf
# iteration : 1599  cost function : nan step : inf
# iteration : 1602  cost function : nan step : inf
# iteration : 1605  cost function : nan step : inf
# iteration : 1608  cost function : nan step : inf
# iteration : 1611  cost function : nan step : inf
# iteration : 1614  cost function : nan step : inf
# iteration : 1617  cost function : nan step : inf
# iteration : 1620  cost function : nan step : inf
# iteration : 1623  cost function : nan step : inf
# iteration : 1626  cost function : nan step : inf
# iteration : 1629  cost function : nan step : inf
# iteration : 1632  cost function : nan step : inf
# iteration : 1635  cost function : nan step : inf
# iteration : 1638  cost function : nan step : inf
# iteration : 1641  cost function : nan step : inf
# iteration : 1644  cost function : nan step : inf
# iteration : 1647  cost function : nan step : inf
# iteration : 1650  cost function : nan step : inf
# iteration : 1653  cost function : nan step : inf
# iteration : 1656  cost function : nan step : inf
# iteration : 1659  cost function : nan step : inf
# iteration : 1662  cost function : nan step : inf
# iteration : 1665  cost function : nan step : inf
# iteration : 1668  cost function : nan step : inf
# iteration : 1671  cost function : nan step : inf
# iteration : 1674  cost function : nan step : inf
# iteration : 1677  cost function : nan step : inf
# iteration : 1680  cost function : nan step : inf
# iteration : 1683  cost function : nan step : inf
# iteration : 1686  cost function : nan step : inf
# iteration : 1689  cost function : nan step : inf
# iteration : 1692  cost function : nan step : inf
# iteration : 1695  cost function : nan step : inf
# iteration : 1698  cost function : nan step : inf
# iteration : 1701  cost function : nan step : inf
# iteration : 1704  cost function : nan step : inf
# iteration : 1707  cost function : nan step : inf
# iteration : 1710  cost function : nan step : inf
# iteration : 1713  cost function : nan step : inf
# iteration : 1716  cost function : nan step : inf
# iteration : 1719  cost function : nan step : inf
# iteration : 1722  cost function : nan step : inf
# iteration : 1725  cost function : nan step : inf
# iteration : 1728  cost function : nan step : inf
# iteration : 1731  cost function : nan step : inf
# iteration : 1734  cost function : nan step : inf
# iteration : 1737  cost function : nan step : inf
# iteration : 1740  cost function : nan step : inf
# iteration : 1743  cost function : nan step : inf
# iteration : 1746  cost function : nan step : inf
# iteration : 1749  cost function : nan step : inf
# iteration : 1752  cost function : nan step : inf
# iteration : 1755  cost function : nan step : inf
# iteration : 1758  cost function : nan step : inf
# iteration : 1761  cost function : nan step : inf
# iteration : 1764  cost function : nan step : inf
# iteration : 1767  cost function : nan step : inf
# iteration : 1770  cost function : nan step : inf
# iteration : 1773  cost function : nan step : inf
# iteration : 1776  cost function : nan step : inf
# iteration : 1779  cost function : nan step : inf
# iteration : 1782  cost function : nan step : inf
# iteration : 1785  cost function : nan step : inf
# iteration : 1788  cost function : nan step : inf
# iteration : 1791  cost function : nan step : inf
# iteration : 1794  cost function : nan step : inf
# iteration : 1797  cost function : nan step : inf
# iteration : 1800  cost function : nan step : inf
# iteration : 1803  cost function : nan step : inf
# iteration : 1806  cost function : nan step : inf
# iteration : 1809  cost function : nan step : inf
# iteration : 1812  cost function : nan step : inf
# iteration : 1815  cost function : nan step : inf
# iteration : 1818  cost function : nan step : inf
# iteration : 1821  cost function : nan step : inf
# iteration : 1824  cost function : nan step : inf
# iteration : 1827  cost function : nan step : inf
# iteration : 1830  cost function : nan step : inf
# iteration : 1833  cost function : nan step : inf
# iteration : 1836  cost function : nan step : inf
# iteration : 1839  cost function : nan step : inf
# iteration : 1842  cost function : nan step : inf
# iteration : 1845  cost function : nan step : inf
# iteration : 1848  cost function : nan step : inf
# iteration : 1851  cost function : nan step : inf
# iteration : 1854  cost function : nan step : inf
# iteration : 1857  cost function : nan step : inf
# iteration : 1860  cost function : nan step : inf
# iteration : 1863  cost function : nan step : inf
# iteration : 1866  cost function : nan step : inf
# iteration : 1869  cost function : nan step : inf
# iteration : 1872  cost function : nan step : inf
# iteration : 1875  cost function : nan step : inf
# iteration : 1878  cost function : nan step : inf
# iteration : 1881  cost function : nan step : inf
# iteration : 1884  cost function : nan step : inf
# iteration : 1887  cost function : nan step : inf
# iteration : 1890  cost function : nan step : inf
# iteration : 1893  cost function : nan step : inf
# iteration : 1896  cost function : nan step : inf
# iteration : 1899  cost function : nan step : inf
# iteration : 1902  cost function : nan step : inf
# iteration : 1905  cost function : nan step : inf
# iteration : 1908  cost function : nan step : inf
# iteration : 1911  cost function : nan step : inf
# iteration : 1914  cost function : nan step : inf
# iteration : 1917  cost function : nan step : inf
# iteration : 1920  cost function : nan step : inf
# iteration : 1923  cost function : nan step : inf
# iteration : 1926  cost function : nan step : inf
# iteration : 1929  cost function : nan step : inf
# iteration : 1932  cost function : nan step : inf
# iteration : 1935  cost function : nan step : inf
# iteration : 1938  cost function : nan step : inf
# iteration : 1941  cost function : nan step : inf
# iteration : 1944  cost function : nan step : inf
# iteration : 1947  cost function : nan step : inf
# iteration : 1950  cost function : nan step : inf
# iteration : 1953  cost function : nan step : inf
# iteration : 1956  cost function : nan step : inf
# iteration : 1959  cost function : nan step : inf
# iteration : 1962  cost function : nan step : inf
# iteration : 1965  cost function : nan step : inf
# iteration : 1968  cost function : nan step : inf
# iteration : 1971  cost function : nan step : inf
# iteration : 1974  cost function : nan step : inf
# iteration : 1977  cost function : nan step : inf
# iteration : 1980  cost function : nan step : inf
# iteration : 1983  cost function : nan step : inf
# iteration : 1986  cost function : nan step : inf
# iteration : 1989  cost function : nan step : inf
# iteration : 1992  cost function : nan step : inf
# iteration : 1995  cost function : nan step : inf
# iteration : 1998  cost function : nan step : inf
# iteration : 2001  cost function : nan step : inf
# iteration : 2004  cost function : nan step : inf
# iteration : 2007  cost function : nan step : inf
# iteration : 2010  cost function : nan step : inf
# iteration : 2013  cost function : nan step : inf
# iteration : 2016  cost function : nan step : inf
# iteration : 2019  cost function : nan step : inf
# iteration : 2022  cost function : nan step : inf
# iteration : 2025  cost function : nan step : inf
# iteration : 2028  cost function : nan step : inf
# iteration : 2031  cost function : nan step : inf
# iteration : 2034  cost function : nan step : inf
# iteration : 2037  cost function : nan step : inf
# iteration : 2040  cost function : nan step : inf
# iteration : 2043  cost function : nan step : inf
# iteration : 2046  cost function : nan step : inf
# iteration : 2049  cost function : nan step : inf
# iteration : 2052  cost function : nan step : inf
# iteration : 2055  cost function : nan step : inf
# iteration : 2058  cost function : nan step : inf
# iteration : 2061  cost function : nan step : inf
# iteration : 2064  cost function : nan step : inf
# iteration : 2067  cost function : nan step : inf
# iteration : 2070  cost function : nan step : inf
# iteration : 2073  cost function : nan step : inf
# iteration : 2076  cost function : nan step : inf
# iteration : 2079  cost function : nan step : inf
# iteration : 2082  cost function : nan step : inf
# iteration : 2085  cost function : nan step : inf
# iteration : 2088  cost function : nan step : inf
# iteration : 2091  cost function : nan step : inf
# iteration : 2094  cost function : nan step : inf
# iteration : 2097  cost function : nan step : inf
# iteration : 2100  cost function : nan step : inf
# iteration : 2103  cost function : nan step : inf
# iteration : 2106  cost function : nan step : inf
# iteration : 2109  cost function : nan step : inf
# iteration : 2112  cost function : nan step : inf
# iteration : 2115  cost function : nan step : inf
# iteration : 2118  cost function : nan step : inf
# iteration : 2121  cost function : nan step : inf
# iteration : 2124  cost function : nan step : inf
# iteration : 2127  cost function : nan step : inf
# iteration : 2130  cost function : nan step : inf
# iteration : 2133  cost function : nan step : inf
# iteration : 2136  cost function : nan step : inf
# iteration : 2139  cost function : nan step : inf
# iteration : 2142  cost function : nan step : inf
# iteration : 2145  cost function : nan step : inf
# iteration : 2148  cost function : nan step : inf
# iteration : 2151  cost function : nan step : inf
# iteration : 2154  cost function : nan step : inf
# iteration : 2157  cost function : nan step : inf
# iteration : 2160  cost function : nan step : inf
# iteration : 2163  cost function : nan step : inf
# iteration : 2166  cost function : nan step : inf
# iteration : 2169  cost function : nan step : inf
# iteration : 2172  cost function : nan step : inf
# iteration : 2175  cost function : nan step : inf
# iteration : 2178  cost function : nan step : inf
# iteration : 2181  cost function : nan step : inf
# iteration : 2184  cost function : nan step : inf
# iteration : 2187  cost function : nan step : inf
# iteration : 2190  cost function : nan step : inf
# iteration : 2193  cost function : nan step : inf
# iteration : 2196  cost function : nan step : inf
# iteration : 2199  cost function : nan step : inf
# iteration : 2202  cost function : nan step : inf
# iteration : 2205  cost function : nan step : inf
# iteration : 2208  cost function : nan step : inf
# iteration : 2211  cost function : nan step : inf
# iteration : 2214  cost function : nan step : inf
# iteration : 2217  cost function : nan step : inf
# iteration : 2220  cost function : nan step : inf
# iteration : 2223  cost function : nan step : inf
# iteration : 2226  cost function : nan step : inf
# iteration : 2229  cost function : nan step : inf
# iteration : 2232  cost function : nan step : inf
# iteration : 2235  cost function : nan step : inf
# iteration : 2238  cost function : nan step : inf
# iteration : 2241  cost function : nan step : inf
# iteration : 2244  cost function : nan step : inf
# iteration : 2247  cost function : nan step : inf
# iteration : 2250  cost function : nan step : inf
# iteration : 2253  cost function : nan step : inf
# iteration : 2256  cost function : nan step : inf
# iteration : 2259  cost function : nan step : inf
# iteration : 2262  cost function : nan step : inf
# iteration : 2265  cost function : nan step : inf
# iteration : 2268  cost function : nan step : inf
# iteration : 2271  cost function : nan step : inf
# iteration : 2274  cost function : nan step : inf
# iteration : 2277  cost function : nan step : inf
# iteration : 2280  cost function : nan step : inf
# iteration : 2283  cost function : nan step : inf
# iteration : 2286  cost function : nan step : inf
# iteration : 2289  cost function : nan step : inf
# iteration : 2292  cost function : nan step : inf
# iteration : 2295  cost function : nan step : inf
# iteration : 2298  cost function : nan step : inf
# iteration : 2301  cost function : nan step : inf
# iteration : 2304  cost function : nan step : inf
# iteration : 2307  cost function : nan step : inf
# iteration : 2310  cost function : nan step : inf
# iteration : 2313  cost function : nan step : inf
# iteration : 2316  cost function : nan step : inf
# iteration : 2319  cost function : nan step : inf
# iteration : 2322  cost function : nan step : inf
# iteration : 2325  cost function : nan step : inf
# iteration : 2328  cost function : nan step : inf
# iteration : 2331  cost function : nan step : inf
# iteration : 2334  cost function : nan step : inf
# iteration : 2337  cost function : nan step : inf
# iteration : 2340  cost function : nan step : inf
# iteration : 2343  cost function : nan step : inf
# iteration : 2346  cost function : nan step : inf
# iteration : 2349  cost function : nan step : inf
# iteration : 2352  cost function : nan step : inf
# iteration : 2355  cost function : nan step : inf
# iteration : 2358  cost function : nan step : inf
# iteration : 2361  cost function : nan step : inf
# iteration : 2364  cost function : nan step : inf
# iteration : 2367  cost function : nan step : inf
# iteration : 2370  cost function : nan step : inf
# iteration : 2373  cost function : nan step : inf
# iteration : 2376  cost function : nan step : inf
# iteration : 2379  cost function : nan step : inf
# iteration : 2382  cost function : nan step : inf
# iteration : 2385  cost function : nan step : inf
# iteration : 2388  cost function : nan step : inf
# iteration : 2391  cost function : nan step : inf
# iteration : 2394  cost function : nan step : inf
# iteration : 2397  cost function : nan step : inf
# iteration : 2400  cost function : nan step : inf
# iteration : 2403  cost function : nan step : inf
# iteration : 2406  cost function : nan step : inf
# iteration : 2409  cost function : nan step : inf
# iteration : 2412  cost function : nan step : inf
# iteration : 2415  cost function : nan step : inf
# iteration : 2418  cost function : nan step : inf
# iteration : 2421  cost function : nan step : inf
# iteration : 2424  cost function : nan step : inf
# iteration : 2427  cost function : nan step : inf
# iteration : 2430  cost function : nan step : inf
# iteration : 2433  cost function : nan step : inf
# iteration : 2436  cost function : nan step : inf
# iteration : 2439  cost function : nan step : inf
# iteration : 2442  cost function : nan step : inf
# iteration : 2445  cost function : nan step : inf
# iteration : 2448  cost function : nan step : inf
# iteration : 2451  cost function : nan step : inf
# iteration : 2454  cost function : nan step : inf
# iteration : 2457  cost function : nan step : inf
# iteration : 2460  cost function : nan step : inf
# iteration : 2463  cost function : nan step : inf
# iteration : 2466  cost function : nan step : inf
# iteration : 2469  cost function : nan step : inf
# iteration : 2472  cost function : nan step : inf
# iteration : 2475  cost function : nan step : inf
# iteration : 2478  cost function : nan step : inf
# iteration : 2481  cost function : nan step : inf
# iteration : 2484  cost function : nan step : inf
# ...
# iteration : 4257  cost function : 0.37774620333743697 step : 0.2
# iteration : 4260  cost function : 0.3775588401553909 step : 0.1
# iteration : 4263  cost function : 0.37739599118946826 step : 0.1
# iteration : 4266  cost function : 0.3771646419481197 step : 0.2
# iteration : 4269  cost function : 0.37697165179528924 step : 0.2
# iteration : 4272  cost function : 0.376792873579736 step : 0.1
# iteration : 4275  cost function : 0.3766471595721421 step : 0.1
# iteration : 4278  cost function : 0.3763930291554165 step : 0.2
# iteration : 4281  cost function : 0.3762060074871514 step : 0.2
# iteration : 4284  cost function : 0.376038235716995 step : 0.1
# iteration : 4287  cost function : 0.3758216880469192 step : 0.2
# iteration : 4290  cost function : 0.3756294806153748 step : 0.2
# iteration : 4293  cost function : 0.37544989705778997 step : 0.1
# iteration : 4296  cost function : 0.375296436534898 step : 0.1
# iteration : 4299  cost function : 0.37506140297536467 step : 0.2
# iteration : 4302  cost function : 0.3748743432593075 step : 0.2
# iteration : 4305  cost function : 0.374704204859795 step : 0.1
# iteration : 4308  cost function : 0.3744992811772385 step : 0.2
# iteration : 4311  cost function : 0.3743088330213316 step : 0.2
# iteration : 4314  cost function : 0.374128120629701 step : 0.2
# iteration : 4935  cost function : 0.34274042264526944 step : 0.1
# iteration : 4938  cost function : 0.3425869655628117 step : 0.2
# iteration : 4941  cost function : 0.34246564376418226 step : 0.2
# iteration : 4944  cost function : 0.3423546584277658 step : 0.1
# iteration : 4947  cost function : 0.3422215184903272 step : 0.2
# iteration : 4950  cost function : 0.3420973677105895 step : 0.2
# iteration : 4953  cost function : 0.34198004886630184 step : 0.2
# iteration : 4956  cost function : 0.3418767628561383 step : 0.1
# iteration : 4959  cost function : 0.34173366917045267 step : 0.2
# iteration : 4962  cost function : 0.34161228586006814 step : 0.2
# iteration : 4965  cost function : 0.3415000510052613 step : 0.1
# iteration : 4968  cost function : 0.3414068889995847 step : 0.1
# iteration : 4971  cost function : 0.3412499661209646 step : 0.2
# iteration : 4974  cost function : 0.34113199670363115 step : 0.2
# iteration : 4977  cost function : 0.34102631937391026 step : 0.1
# iteration : 4980  cost function : 0.34089128896482257 step : 0.2
# iteration : 4983  cost function : 0.34077056280792317 step : 0.2
# iteration : 4986  cost function : 0.3406568908598143 step : 0.1
# iteration : 4989  cost function : 0.34055977831815576 step : 0.1
# iteration : 4992  cost function : 0.34041340949351107 step : 0.2
# iteration : 4995  cost function : 0.3402956820101237 step : 0.2
# iteration : 4998  cost function : 0.3401875165132925 step : 0.1

# %%
plt.plot(v_lamb0, np.log(niter0), label='nombre itérations en log')
plt.legend()
plt.show
print(niter0)
# Out:
# [5000. 5000. 5000. 5000. 2589. 5000. 5000. 5000. 5000. 5000.]

# %% [markdown]
# <font color='blue'>
#    On remarque que la fonction converge pour une seule valeur de $\lambda$. En effet, pour toutes les valeurs sauf une, elle s'arrête car $niter$ atteint $nitermax$.
#
# </font>

# %%
k=np.argmin(niter0)
print(v_lamb0[k])
# Out:
# 0.11111111111111116

# %% [markdown]
# <font color='blue'>
#     Nous allons donc utiliser $\lambda =0.11$
#      pour la suite. Nous prendrons aussi $\mu =0.1 \times \lambda = 0.011$ car on a remarqué (par la suite) que lorsque $\mu=0.011$, la fonction finale correspond bien à la fonction cible.
#
# </font>

# %% [markdown]
# Q5. Ecrire un compte-rendu des expériences réalisées et des résultats obtenus. Commentez.

# %%
lamb=0.11
mu=0.1*lamb
nitermax=5000

step0 = 0.1
ux,uy,CF,step, niter=RecalageDG(f,g,lamb,mu,nitermax,step0)
# Out:
# iteration : 3  cost function : 18.61882375905814 step : 0.8
# iteration : 6  cost function : 14.983726416222842 step : 6.4
# iteration : 9  cost function : 6.241548230918888 step : 3.2
# iteration : 12  cost function : 5.629344744727004 step : 1.6
# iteration : 15  cost function : 5.024703155229496 step : 1.6
# iteration : 18  cost function : 4.6434080526807815 step : 1.6
# iteration : 21  cost function : 4.31319700497589 step : 1.6
# iteration : 24  cost function : 4.021616833324863 step : 1.6
# iteration : 27  cost function : 3.7642429173432577 step : 1.6
# iteration : 30  cost function : 3.539138402644698 step : 1.6
# iteration : 33  cost function : 3.260636464739863 step : 3.2
# iteration : 36  cost function : 3.0514977594615447 step : 3.2
# iteration : 39  cost function : 2.8626956774156973 step : 1.6
# iteration : 2547  cost function : 0.2938785741646994 step : 3.2
# iteration : 2550  cost function : 0.29387711697652713 step : 1.6
# iteration : 2553  cost function : 0.29387653725470464 step : 1.6

# %%
fig, ax = plt.subplots(2,3)
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %%
plt.quiver(ux, uy)
plt.show()

# %% [markdown]
# <font color='blue'>
#     On remarque que l'angle en bas à gauche ne change pas d'une image à l'autre. On retrouve cette caractéristique sur le graphe représentant les vecteurs. Les vecteurs sont nuls en bas à gauche. Sur le reste de l'image les flèches représentent le déplacement de la fonction.
#     On remarque aussi que notre "final function" est très proche de la "target function".
# </font>

# %% [markdown]
# # 4. Algorithme de moindres carrés.
#
# On souhaite maintenant implémenter un algorithme de second ordre pour résoudre le problème
#
# $$(P)\quad\min_u E(u)+R(u)$$
#
# afin d'accélérer la convergence de l'algorithme. Pour cela, on va reformuler le problème $(P)$ en un problème de moindres carrés et appliquer l'algorithme de Levenberg-Marquardt.
#
# Soit:
# $$\Psi(u)=\begin{pmatrix}
# f\circ(Id+u)-g \\
# \sqrt{\mu}(\partial_xu_y+\partial_yu_x) \\
# \sqrt{\mu+\lambda}(\partial_xu_x+\partial_yu_y) \end{pmatrix},$$
# où $f\circ(id+u)$ est l'interpolation de $x\mapsto f(x+u(x))$ sur la grille. Minimiser $E(u)+R(u)$ est équivalent à résoudre le problème suivant:
#
# >$$\min_u \|\Psi(u)\|_2^2.$$
#
# Il s'agit maintenant d'un problème de moindres carrés que l'on va résoudre à l'aide de l'algorithme de Levenberg Marquardt :
#
# $$
# u_{k+1}=u_k- H_k^{-1} J_{\Psi}(u_k)^\top \Psi(u_k) \quad\mbox{ avec }\quad H_k=J_{\Psi}(u_k)^\top J_{\Psi}(u_k) +\varepsilon Id
# $$

# %% [markdown]
# Q6. Calculer la matrice jacobienne de $\Psi$, notée $J_\Psi(u)$.

# %% [markdown]
# $$J_{\psi}(u)=\begin{pmatrix}
# \nabla _{\psi_1}(u)^T \\
# \nabla _{\psi_2}(u)^T \\
# \nabla _{\psi_3}(u)^T \
#  \end{pmatrix}$$
#
# On calcule chaque $ \nabla _{\psi_i}(u)^T $ individuellement :
# $$\begin{align}
# \nabla _{\psi_2}(u)&=\sqrt{\mu} \nabla (\partial _x u_y + \partial _y u_x)\\
# &=\sqrt{\mu} \begin{pmatrix}
# \partial _x  \\
# \partial _y  \\
# \end{pmatrix}
# \end{align}$$
#
# $$\begin{align}
# \nabla _{\psi_3}(u)&=\sqrt{\lambda +\mu} \nabla (\partial _x u_x + \partial _y u_y)\\
# &=\sqrt{\lambda + \mu} \begin{pmatrix}
# \partial _x  \\
# \partial _y  \\
# \end{pmatrix}
# \end{align}$$
#
# $$\begin{align}
# \nabla _{\psi_1}(u)=(J_{\psi_1}(u))^T \\
# J_{\psi_1}(u)&=J_f(h(u)) \times J_h(u) \\
# &=\nabla^Tf(h(u)) \times Id \\
# &=\nabla^Tf(h(u))  \text{ avec } h(u)=Id+u
# \end{align}$$
#
# Donc,
# $$\begin{align}
# J_{\psi}(u) \begin{pmatrix}
# v_x \\
# v_y\\
# \end{pmatrix} = \begin{pmatrix}
# df_x(Id+u)v_x + df_y(Id+u)v_y \\
# \sqrt{\mu}\partial _x v_x +\sqrt{\mu}\partial _y v_y \\
# \sqrt{\lambda + \mu}\partial _x v_x + \sqrt{\lambda +\mu}\partial _y v_y \\
# \end{pmatrix}
# \end{align}$$

# %% [markdown]
# Q7. Implémenter les fonctions JPsi, JTPsi et JTJ qui calculent respectivement:
# - le produit de $J_\psi(u)$ par une direction $v=(v_x,v_y)\in V^2$,
#
# - le produit de $J_\Psi(u)^\top$ par $\phi=(\phi_1,\phi_2,\phi_3)\in V^3$,
#
# - le produit de $(J_\Psi(u)^\top J_\Psi(u)+\epsilon I)$ par une direction $v=(v_x,v_y)\in V^2$.

# %%
def Psi(ux,uy,fu,g,mu,lamb):
    psi1=fu-g
    psi2=np.sqrt(mu)*(dy(ux)+dx(uy))
    psi3=np.sqrt(lamb+mu)*(dx(ux)+dy(uy))
    return [psi1,psi2,psi3]


def JPsi(vx,vy,df,lamb,mu) :
    JPsi0=df[0]*vx+df[1]*vy
    JPsi1=np.sqrt(mu)*dy(vx)+np.sqrt(mu)*dx(vy)
    JPsi2=np.sqrt(lamb+mu)*dx(vx)+np.sqrt(lamb+mu)*dy(vy)
    return [JPsi0,JPsi1,JPsi2]
    
def JTPsi(phi,df,lamb,mu) :
    ux=phi[0]*df[0]+np.sqrt(mu)*dyT(phi[1])+np.sqrt(lamb+mu)*dxT(phi[2])
    uy=phi[0]*df[1]+np.sqrt(mu)*dxT(phi[1])+np.sqrt(lamb+mu)*dyT(phi[2])
    return [ux,uy]

def JTJ(vx,vy,df,lamb,mu,epsilon) :
    uxs, uys = JTPsi(JPsi(vx,vy,df,lamb,mu),df,lamb,mu)
    uxs = uxs + epsilon*vx
    uys = uys + epsilon*vy
    
    return uxs,uys

# %% [markdown]
# Calculons maintenant la direction de recherche $d_k$ comme solution du système linéaire:
# $$(J_\Psi(u_k)^\top J_\Psi(u_k) +\epsilon I)\left(\begin{array}{c}
# d_x\\
# d_y
# \end{array}\right) = -J_\Psi(u_k)^\top \Psi(u_k)$$
# Pour cela, on vous donne l'algorithme suivant qui par la méthode du gradient conjugué calcule une solution $d=(d_x,d_y)\in V^2$ du problème:
# $$(J_\Psi(u_k)^\top J_\Psi(u_k) +\epsilon I)\left(\begin{array}{c}
# d_x\\
# d_y
# \end{array}\right) = b$$

# %%
def CGSolve(u0x,u0y,lamb,mu,b,epsilon,df) :
    
    nitmax=100;
    ux=u0x; uy=u0y; #point de départ de l'algorithme
    # Computes JTJu
    Ax,Ay=JTJ(ux,uy,df,lamb,mu,epsilon);
    rx=b[0]-Ax
    ry=b[1]-Ay
    px=rx
    py=ry
    rsold=np.linalg.norm(rx)**2+np.linalg.norm(ry)**2
    for i in range(nitmax) :
        Apx,Apy=JTJ(px,py,df,lamb,mu,epsilon);
        alpha=rsold/(np.vdot(rx[:],Apx[:])+np.vdot(ry[:],Apy[:]))
        ux=ux+alpha*px
        uy=uy+alpha*py
        rx=rx-alpha*Apx
        ry=ry-alpha*Apy
        rsnew=np.linalg.norm(rx)**2+np.linalg.norm(ry)**2
        if np.sqrt(rsnew)<1e-10 :
            return [ux,uy]
        px=rx+rsnew/rsold*px
        py=ry+rsnew/rsold*py
        rsold=rsnew
    return [ux,uy]

# %% [markdown]
# Q8. Compléter l'algorithme RecalageGN implémentant la méthode de Levenberg-Marquardt.

# %%
def RecalageGN(f,g,lamb,mu,nitermax,stepini,epsi) : 
    ux=np.zeros(f.shape)
    uy=np.zeros(f.shape)  
    descentx=np.zeros(f.shape)
    descenty=np.zeros(f.shape)  
    #raise ValueError('To complete if necessary')
    CF=[]
    step_list=[]
    niter=0
    step=stepini
    dfx = dx(f)
    dfy = dy(f)
    while niter < nitermax and step > 1.e-8 : 
        niter+=1
        obj,fu=objective_function(f,g,ux,uy,lamb,mu)
        CF.append(obj)
        # Gradient of F at point u
        #raise ValueError('Compute -b here')
    
        #raise ValueError('Compute dfx,dfy here') 
        #dfx = dx(f)
        #dfy = dy(f)
        dfx1 = interpol(dfx,ux,uy)
        dfy1 = interpol(dfy,ux,uy)
        df=[dfx1,dfy1]
        psy=Psi(ux,uy,fu,g,mu,lamb)
        b=JTPsi(psy,df,lamb,mu)
        [descentx,descenty]=CGSolve(descentx,descenty,lamb,mu,b,epsi,df)
        ux,uy,step=linesearch(ux,uy,step,descentx,descenty,obj,f,g,lamb,mu)
        step_list.append(step)
        # Display
        if (niter % 3 ==0) :
            print('iteration :',niter,' cost function :',obj,'step :',step)
    return ux,uy,np.array(CF),np.array(step_list), niter

# %% [markdown]
# <font color='blue'>
#     Comme pour la partie précédente, nous recherchons un $\lambda$ et un $\mu$ optimaux qui permettent de faire converger l'algorithme en le moins d'itérations possible. Nous allons encore tester la fonction RecalageGN avec plusieurs valeurs de $\lambda$ et conserver celle qui nous permet d'avoir le $niter$ le plus petit possible.
# </font>

# %%
v_lamb1 = np.linspace(0,50,20)
v_mu1 = np.copy(v_lamb1)
niter1 = np.zeros(20)
step1=0.01
eps1=0.1
nitermax=5000

for i in range(20) :
    ux,uy,CF,step,niter1[i]=RecalageGN(f,g,v_lamb1[i],v_mu1[i],nitermax,step1,eps1)
# Out:
# iteration : 3  cost function : 18.733248917873894 step : 0.08
# iteration : 6  cost function : 15.390488694830237 step : 0.64
# iteration : 9  cost function : 3.5818522715280565 step : 5.12
# iteration : 12  cost function : 1.6262697498641487 step : 5.12
# iteration : 15  cost function : 1.291069312350729 step : 10.24
# iteration : 18  cost function : 1.2220570540253033 step : 5.12
# iteration : 21  cost function : 1.156019983316258 step : 10.24
# iteration : 24  cost function : 1.129399108665922 step : 10.24
# iteration : 27  cost function : 1.1108166754201187 step : 10.24
# iteration : 30  cost function : 1.0962568942912685 step : 10.24
# iteration : 33  cost function : 1.0864950351597418 step : 5.12
# iteration : 36  cost function : 1.0730801953354119 step : 5.12
# iteration : 39  cost function : 1.063532865099978 step : 5.12
# iteration : 42  cost function : 1.0552463888102424 step : 10.24
# iteration : 45  cost function : 1.050322878697209 step : 10.24
# iteration : 48  cost function : 1.0460991171425083 step : 10.24
# iteration : 51  cost function : 1.042464648170851 step : 10.24
# iteration : 54  cost function : 1.0393617573366598 step : 10.24
# iteration : 57  cost function : 1.0367334809515503 step : 10.24
# iteration : 60  cost function : 1.0345153040774917 step : 10.24
# iteration : 63  cost function : 1.0326223486929798 step : 10.24
# iteration : 66  cost function : 1.0309370087727059 step : 10.24
# iteration : 69  cost function : 1.0293495964514532 step : 10.24
# iteration : 72  cost function : 1.0278581861223395 step : 10.24
# iteration : 75  cost function : 1.0265405315431917 step : 10.24
# iteration : 78  cost function : 1.0254159341325406 step : 10.24
# iteration : 81  cost function : 1.0244427360732504 step : 10.24
# iteration : 84  cost function : 1.0235734567025363 step : 10.24
# iteration : 87  cost function : 1.02277257390287 step : 10.24
# iteration : 90  cost function : 1.022015382833483 step : 10.24
# iteration : 93  cost function : 1.0212857949473049 step : 10.24
# iteration : 96  cost function : 1.0205747779169396 step : 10.24
# iteration : 99  cost function : 1.0198789357374254 step : 10.24
# iteration : 102  cost function : 1.0191983273498688 step : 10.24
# iteration : 105  cost function : 1.0185344290964191 step : 10.24
# iteration : 108  cost function : 1.0178897400695375 step : 10.24
# iteration : 111  cost function : 1.0172674593800188 step : 10.24
# iteration : 114  cost function : 1.0166710560495138 step : 10.24
# iteration : 117  cost function : 1.016274442602827 step : 5.12
# iteration : 120  cost function : 1.015724620094517 step : 5.12
# iteration : 123  cost function : 1.015214915160299 step : 5.12
# iteration : 126  cost function : 1.0147444388603986 step : 5.12
# iteration : 129  cost function : 1.0143142649034034 step : 5.12
# iteration : 132  cost function : 1.0139205230232744 step : 5.12
# iteration : 135  cost function : 1.0135615890826128 step : 5.12
# iteration : 138  cost function : 1.013232397121366 step : 5.12
# iteration : 141  cost function : 1.012839096511206 step : 10.24
# iteration : 144  cost function : 1.012566238537182 step : 10.24
# iteration : 147  cost function : 1.012389349930522 step : 5.12
# iteration : 150  cost function : 1.0121438021768208 step : 5.12
# iteration : 153  cost function : 1.0119118022089646 step : 5.12
# iteration : 156  cost function : 1.0116907702027285 step : 5.12
# iteration : 159  cost function : 1.0114799428253665 step : 5.12
# iteration : 162  cost function : 1.011278029601484 step : 5.12
# iteration : 165  cost function : 1.0110850475999076 step : 5.12
# iteration : 168  cost function : 1.010900518881243 step : 5.12
# iteration : 171  cost function : 1.010724846741996 step : 5.12
# iteration : 174  cost function : 1.010557860927567 step : 5.12
# iteration : 177  cost function : 1.0103999272142854 step : 5.12
# iteration : 180  cost function : 1.010250755370583 step : 5.12
# iteration : 183  cost function : 1.0101100686592739 step : 5.12
# iteration : 186  cost function : 1.0099767299053264 step : 5.12
# iteration : 189  cost function : 1.0098494733438808 step : 5.12
# iteration : 192  cost function : 1.0097264327847968 step : 5.12
# iteration : 195  cost function : 1.0096059999692306 step : 5.12
# iteration : 198  cost function : 1.0094868048269363 step : 5.12
# iteration : 201  cost function : 1.0093685198962137 step : 5.12
# iteration : 204  cost function : 1.0092517418945577 step : 5.12
# iteration : 207  cost function : 1.0091380672234402 step : 5.12
# iteration : 210  cost function : 1.0090292379829795 step : 5.12
# iteration : 213  cost function : 1.0089268330869827 step : 5.12
# iteration : 216  cost function : 1.0088316860516318 step : 5.12
# iteration : 219  cost function : 1.0087439152059863 step : 5.12
# iteration : 222  cost function : 1.008663084418586 step : 5.12
# iteration : 225  cost function : 1.0085885168647923 step : 5.12
# iteration : 228  cost function : 1.0085193342321925 step : 5.12
# iteration : 231  cost function : 1.0084547044232113 step : 5.12
# iteration : 234  cost function : 1.008393795163786 step : 5.12
# iteration : 237  cost function : 1.0083359086981944 step : 5.12
# iteration : 240  cost function : 1.008280397434963 step : 5.12
# iteration : 243  cost function : 1.0082267870647252 step : 5.12
# iteration : 246  cost function : 1.0081746199943526 step : 5.12
# iteration : 249  cost function : 1.0081236156612108 step : 5.12
# iteration : 252  cost function : 1.0080735249714234 step : 5.12
# iteration : 255  cost function : 1.0080242513906688 step : 5.12
# iteration : 258  cost function : 1.007975727453359 step : 5.12
# iteration : 261  cost function : 1.0079279969669672 step : 5.12
# iteration : 264  cost function : 1.0078811064003168 step : 5.12
# iteration : 267  cost function : 1.007835159175028 step : 5.12
# iteration : 270  cost function : 1.0077902249725779 step : 5.12
# iteration : 273  cost function : 1.0077463823798076 step : 5.12
# iteration : 276  cost function : 1.0077036533695405 step : 5.12
# iteration : 279  cost function : 1.0076620449794256 step : 5.12
# iteration : 282  cost function : 1.0076215072762091 step : 5.12
# iteration : 285  cost function : 1.0075819738894687 step : 10.24
# iteration : 288  cost function : 1.0075433365680135 step : 10.24
# iteration : 291  cost function : 1.0075054750901815 step : 10.24
# iteration : 294  cost function : 1.0074682526939613 step : 10.24
# iteration : 297  cost function : 1.0074315242196719 step : 10.24
# iteration : 300  cost function : 1.0073951405597505 step : 10.24
# iteration : 303  cost function : 1.0073589526964728 step : 10.24
# iteration : 306  cost function : 1.0073228138587211 step : 10.24
# iteration : 309  cost function : 1.0072865813413288 step : 10.24
# iteration : 312  cost function : 1.007250117971759 step : 10.24
# iteration : 315  cost function : 1.0072132939824678 step : 10.24
# iteration : 318  cost function : 1.0071759852124402 step : 10.24
# iteration : 321  cost function : 1.007148710599489 step : 5.12
# iteration : 324  cost function : 1.007108393580049 step : 5.12
# iteration : 327  cost function : 1.0070673460554338 step : 5.12
# iteration : 330  cost function : 1.007025435788949 step : 5.12
# iteration : 333  cost function : 1.0069825723480077 step : 5.12
# iteration : 336  cost function : 1.0069386339622386 step : 5.12
# iteration : 339  cost function : 1.0068935320915204 step : 5.12
# iteration : 342  cost function : 1.0068471551739557 step : 5.12
# iteration : 345  cost function : 1.0067994212665408 step : 5.12
# iteration : 348  cost function : 1.0067502235329098 step : 5.12
# iteration : 351  cost function : 1.006699505934827 step : 5.12
# iteration : 354  cost function : 1.006647178419355 step : 5.12
# iteration : 357  cost function : 1.0065932099119135 step : 5.12
# iteration : 360  cost function : 1.0065375806416474 step : 5.12
# iteration : 363  cost function : 1.0064803391973283 step : 5.12
# iteration : 366  cost function : 1.0064215407029016 step : 5.12
# iteration : 369  cost function : 1.0063613019956754 step : 10.24
# iteration : 372  cost function : 1.0062997620664824 step : 10.24
# iteration : 375  cost function : 1.0062371141489397 step : 10.24
# iteration : 378  cost function : 1.0061735918940988 step : 10.24
# iteration : 381  cost function : 1.0061094721078352 step : 10.24
# iteration : 384  cost function : 1.0060450706333424 step : 10.24
# iteration : 387  cost function : 1.0059807372435565 step : 10.24
# iteration : 390  cost function : 1.005916859640635 step : 10.24
# iteration : 393  cost function : 1.0058538812377487 step : 10.24
# iteration : 396  cost function : 1.005792246893851 step : 10.24
# iteration : 399  cost function : 1.005732377547459 step : 10.24
# iteration : 402  cost function : 1.0056746553790192 step : 10.24
# iteration : 405  cost function : 1.0056358011156954 step : 5.12
# iteration : 408  cost function : 1.005581819529603 step : 5.12
# iteration : 411  cost function : 1.0055310155934558 step : 5.12
# iteration : 414  cost function : 1.005483472657535 step : 5.12
# iteration : 417  cost function : 1.0054392619029784 step : 5.12
# iteration : 420  cost function : 1.0053983516503688 step : 5.12
# iteration : 423  cost function : 1.0053607060049523 step : 5.12
# iteration : 426  cost function : 1.0053262110090146 step : 5.12
# iteration : 429  cost function : 1.0052947439445679 step : 5.12
# iteration : 432  cost function : 1.005266126342806 step : 5.12
# iteration : 435  cost function : 1.0052323330657864 step : 10.24
# iteration : 438  cost function : 1.005209298996345 step : 10.24
# iteration : 441  cost function : 1.0051885137053176 step : 10.24
# iteration : 444  cost function : 1.0051697847308085 step : 10.24
# iteration : 447  cost function : 1.0051529244120234 step : 10.24
# iteration : 450  cost function : 1.0051377531577337 step : 10.24
# iteration : 453  cost function : 1.0051241017470511 step : 10.24
# iteration : 456  cost function : 1.0051118126600582 step : 10.24
# iteration : 459  cost function : 1.0051007407927919 step : 10.24
# iteration : 462  cost function : 1.0050907535697662 step : 10.24
# iteration : 465  cost function : 1.0050817307318596 step : 10.24
# iteration : 468  cost function : 1.005073563797042 step : 10.24
# iteration : 471  cost function : 1.0050661553952507 step : 10.24
# iteration : 474  cost function : 1.0050594184554382 step : 10.24
# iteration : 477  cost function : 1.0050532753864299 step : 10.24
# iteration : 480  cost function : 1.0050476572327882 step : 10.24
# iteration : 483  cost function : 1.005042502837884 step : 10.24
# iteration : 486  cost function : 1.0050377580254133 step : 10.24
# iteration : 489  cost function : 1.0050333748786608 step : 10.24
# iteration : 492  cost function : 1.0050293110689807 step : 10.24
# iteration : 495  cost function : 1.0050255293578174 step : 10.24
# iteration : 498  cost function : 1.0050219969543333 step : 10.24
# iteration : 501  cost function : 1.0050186849487879 step : 10.24
# iteration : 504  cost function : 1.0050155678544355 step : 10.24
# iteration : 507  cost function : 1.0050126232088885 step : 10.24
# iteration : 510  cost function : 1.0050098312090194 step : 10.24
# iteration : 513  cost function : 1.0050071743967646 step : 10.24
# iteration : 516  cost function : 1.0050046373735204 step : 10.24
# iteration : 519  cost function : 1.0050022065555666 step : 10.24
# iteration : 522  cost function : 1.0049998699524376 step : 10.24
# iteration : 525  cost function : 1.004997616977791 step : 10.24
# iteration : 528  cost function : 1.0049954382782993 step : 10.24
# iteration : 531  cost function : 1.0049933255879995 step : 10.24
# iteration : 534  cost function : 1.004991891094373 step : 5.12
# iteration : 537  cost function : 1.0049898191448952 step : 5.12
# iteration : 540  cost function : 1.0049877983627913 step : 5.12
# iteration : 543  cost function : 1.0049858234805595 step : 5.12
# iteration : 546  cost function : 1.0049838896578482 step : 5.12
# iteration : 549  cost function : 1.0049819927267314 step : 5.12
# iteration : 552  cost function : 1.0049801288631885 step : 5.12
# iteration : 555  cost function : 1.00497829476848 step : 5.12
# iteration : 558  cost function : 1.0049764874233318 step : 5.12
# iteration : 561  cost function : 1.0049747042213042 step : 5.12
# iteration : 564  cost function : 1.004972942785645 step : 5.12
# iteration : 567  cost function : 1.0049712010667498 step : 5.12
# iteration : 570  cost function : 1.0049694772064228 step : 5.12
# iteration : 573  cost function : 1.004967769608632 step : 5.12
# iteration : 576  cost function : 1.004966076837684 step : 5.12
# iteration : 579  cost function : 1.0049643976833291 step : 5.12
# iteration : 582  cost function : 1.0049627310497307 step : 5.12
# iteration : 585  cost function : 1.0049610760578211 step : 5.12
# iteration : 588  cost function : 1.0049594319566355 step : 5.12
# iteration : 591  cost function : 1.0049577981684283 step : 5.12
# iteration : 594  cost function : 1.0049561742126651 step : 5.12
# iteration : 597  cost function : 1.0049545597534961 step : 5.12
# iteration : 600  cost function : 1.0049529545517006 step : 5.12
# iteration : 603  cost function : 1.0049513584966017 step : 5.12
# iteration : 606  cost function : 1.0049497715753997 step : 5.12
# iteration : 609  cost function : 1.0049481938942495 step : 10.24
# iteration : 612  cost function : 1.0049466256628912 step : 10.24
# iteration : 615  cost function : 1.0049450671852307 step : 10.24
# iteration : 618  cost function : 1.004943518840974 step : 10.24
# iteration : 621  cost function : 1.0049419811135083 step : 10.24
# iteration : 624  cost function : 1.0049404545938692 step : 10.24
# iteration : 627  cost function : 1.0049389399856183 step : 10.24
# iteration : 630  cost function : 1.0049374381059106 step : 10.24
# iteration : 633  cost function : 1.0049359498908654 step : 10.24
# iteration : 636  cost function : 1.0049344763979287 step : 10.24
# iteration : 639  cost function : 1.0049330233847067 step : 10.24
# iteration : 642  cost function : 1.0049315927387812 step : 10.24
# iteration : 645  cost function : 1.0049301806413478 step : 10.24
# iteration : 648  cost function : 1.004928788685283 step : 10.24
# iteration : 651  cost function : 1.0049278076421282 step : 5.12
# iteration : 654  cost function : 1.0049264143176984 step : 5.12
# iteration : 657  cost function : 1.0049250512364374 step : 5.12
# iteration : 660  cost function : 1.0049237203594767 step : 5.12
# iteration : 663  cost function : 1.0049224236938101 step : 5.12
# iteration : 666  cost function : 1.0049211631703956 step : 5.12
# iteration : 669  cost function : 1.0049199408190228 step : 5.12
# iteration : 672  cost function : 1.0049187588398811 step : 5.12
# iteration : 675  cost function : 1.0049176195586358 step : 5.12
# iteration : 678  cost function : 1.0049165254561494 step : 5.12
# iteration : 681  cost function : 1.0049154791210408 step : 5.12
# iteration : 684  cost function : 1.0049144832713273 step : 5.12
# iteration : 687  cost function : 1.004913540703426 step : 5.12
# iteration : 690  cost function : 1.0049126543032574 step : 5.12
# iteration : 693  cost function : 1.0049118269899817 step : 5.12
# iteration : 696  cost function : 1.0049110617141896 step : 5.12
# iteration : 699  cost function : 1.0049103613942463 step : 5.12
# iteration : 702  cost function : 1.0049097288993605 step : 5.12
# iteration : 705  cost function : 1.0049091669763304 step : 5.12
# iteration : 708  cost function : 1.0049086782157208 step : 5.12
# iteration : 711  cost function : 1.004908264979595 step : 5.12
# iteration : 714  cost function : 1.00490792939647 step : 5.12
# iteration : 717  cost function : 1.0049075882144558 step : 10.24
# iteration : 720  cost function : 1.0049074025397915 step : 10.24
# iteration : 723  cost function : 1.0049072974466253 step : 5.12
# iteration : 726  cost function : 1.0049072599400424 step : 2.56
# iteration : 729  cost function : 1.004907258298434 step : 0.08
# iteration : 732  cost function : 1.004907258298094 step : 7.8125e-05
# iteration : 735  cost function : 1.004907258298094 step : 1.953125e-05
# iteration : 738  cost function : 1.004907258298094 step : 4.8828125e-06
# iteration : 741  cost function : 1.004907258298094 step : 3.0517578125e-07
# iteration : 744  cost function : 1.004907258298094 step : 3.0517578125e-07
# iteration : 3  cost function : 18.957948198769987 step : 0.08
# iteration : 6  cost function : 17.591824114600858 step : 0.64
# iteration : 9  cost function : 10.052510783343878 step : 5.12
# iteration : 12  cost function : 1.269462461058661 step : 2.56
# iteration : 15  cost function : 0.9247797784744466 step : 1.28
# iteration : 18  cost function : 0.6152800279734627 step : 2.56
# iteration : 21  cost function : 0.47250564166504183 step : 2.56
# iteration : 24  cost function : 0.39593936201551455 step : 2.56
# iteration : 27  cost function : 0.3481916291647198 step : 2.56
# iteration : 30  cost function : 0.3232759137738036 step : 1.28
# iteration : 33  cost function : 0.2963805664010878 step : 2.56
# iteration : 36  cost function : 0.2811023872850976 step : 2.56
# iteration : 39  cost function : 0.27083330286679 step : 2.56
# iteration : 42  cost function : 0.26417345593820757 step : 2.56
# iteration : 45  cost function : 0.2605428513790629 step : 1.28
# iteration : 48  cost function : 0.2568326263668516 step : 2.56
# iteration : 51  cost function : 0.25439526067173224 step : 2.56
# iteration : 54  cost function : 0.2531154640677165 step : 2.56
# iteration : 57  cost function : 0.25229112895833916 step : 2.56
# iteration : 60  cost function : 0.2519450595150506 step : 2.56
# iteration : 63  cost function : 0.25183584735339093 step : 9.5367431640625e-09
# iteration : 3  cost function : 18.9711186611862 step : 0.08
# iteration : 6  cost function : 17.700646893039135 step : 0.64
# iteration : 9  cost function : 10.322241627090223 step : 5.12
# iteration : 12  cost function : 1.2548375811401722 step : 2.56
# iteration : 15  cost function : 0.9264733713381381 step : 1.28
# iteration : 18  cost function : 0.5943711558431111 step : 1.28
# iteration : 42  cost function : 0.2505960519401971 step : 1.28
# iteration : 45  cost function : 0.25021812670670707 step : 1.28
# iteration : 48  cost function : 0.25004774567774474 step : 1.28
# iteration : 51  cost function : 0.2499763673483174 step : 0.64
# iteration : 3  cost function : 18.994698254026396 step : 0.08
# iteration : 6  cost function : 17.883579209425335 step : 0.64
# iteration : 9  cost function : 10.636503601576859 step : 5.12
# iteration : 12  cost function : 1.2219329586308765 step : 2.56
# iteration : 15  cost function : 0.6752228218603914 step : 2.56
# iteration : 18  cost function : 0.43431216749304774 step : 2.56
# iteration : 21  cost function : 0.3314199605207402 step : 2.56
# iteration : 24  cost function : 0.2875539802434167 step : 2.56
# iteration : 27  cost function : 0.26768764615201857 step : 2.56
# iteration : 30  cost function : 0.25874285460534646 step : 2.56
# iteration : 33  cost function : 0.2543748659830289 step : 2.56
# iteration : 36  cost function : 0.2528847351079745 step : 1.28
# iteration : 39  cost function : 0.2513609075936149 step : 1.28
# iteration : 42  cost function : 0.2506469106378326 step : 1.28
# iteration : 45  cost function : 0.2502728926447462 step : 1.28
# iteration : 48  cost function : 0.2500979227377172 step : 1.28
# iteration : 51  cost function : 0.25002093886355586 step : 0.64
# iteration : 3  cost function : 18.995080919805595 step : 0.08
# iteration : 6  cost function : 17.885833990932824 step : 0.64
# iteration : 9  cost function : 10.638612770660773 step : 5.12
# iteration : 12  cost function : 1.2197467508718418 step : 2.56
# iteration : 15  cost function : 0.6643405283290917 step : 2.56
# iteration : 18  cost function : 0.42662798836419485 step : 2.56
# iteration : 21  cost function : 0.3273924219359794 step : 2.56
# iteration : 24  cost function : 0.2858039780257924 step : 2.56
# iteration : 27  cost function : 0.26693242350010443 step : 2.56
# iteration : 30  cost function : 0.25842574184407907 step : 2.56
# iteration : 33  cost function : 0.2542465426541356 step : 2.56
# iteration : 36  cost function : 0.2522030126672114 step : 2.56
# iteration : 39  cost function : 0.25145408775980993 step : 1.28
# iteration : 42  cost function : 0.25071309522742014 step : 1.28
# iteration : 45  cost function : 0.2503187663568448 step : 1.28
# iteration : 48  cost function : 0.25013494100060596 step : 1.28
# iteration : 51  cost function : 0.2500510758677691 step : 1.28

# %%
plt.plot(v_lamb1, np.log(niter1), label='nombre itérations en log')
plt.legend()
plt.show()

# %% [markdown]
# <font color='blue'>
#    On remarque que la fonction a le nombre d'itérations le plus petit lorsque $\lambda$ est entre 8 et 15 (à peu près grâce au graphe).
#
# </font>

# %%
k=np.argmin(niter1)
print(v_lamb1[k])
# Out:
# 10.526315789473685

# %% [markdown]
# <font color='blue'>
#    On prendra donc pour la suite $\lambda = 10,5$. Nous allons cette fois ci prendre $\mu = \lambda = 10,5$.
#
# </font>

# %% [markdown]
# Q9. Tester le nouvel algorithme et comparer sa vitesse de convergence avec celle de l'algorithme de gradient.

# %%
epsi=0.1
stepini=0.01
lamb = 10.5
mu = np.copy(lamb)
ux,uy,CF,step, niter=RecalageGN(f,g,lamb,mu,nitermax,stepini,epsi)
# Out:
# iteration : 3  cost function : 18.980920607789177 step : 0.08
# iteration : 6  cost function : 17.781443575171593 step : 0.64
# iteration : 9  cost function : 10.490218427919281 step : 5.12
# iteration : 12  cost function : 1.257935372481139 step : 2.56
# iteration : 15  cost function : 0.8719055558278974 step : 1.28
# iteration : 18  cost function : 0.5504923743676869 step : 1.28
# iteration : 21  cost function : 0.39875379629302166 step : 2.56
# iteration : 24  cost function : 0.32580812557251493 step : 2.56
# iteration : 27  cost function : 0.2883370275752083 step : 2.56
# iteration : 30  cost function : 0.26945365463104304 step : 2.56
# iteration : 33  cost function : 0.2594123141017895 step : 2.56
# iteration : 36  cost function : 0.254345995534033 step : 2.56
# iteration : 39  cost function : 0.2516802273018822 step : 2.56
# iteration : 42  cost function : 0.2504241843509691 step : 2.56
# iteration : 45  cost function : 0.25006452040645466 step : 1.28
# iteration : 48  cost function : 0.24962997477226978 step : 0.32

# %%
fig, ax = plt.subplots(2,3)
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %%
plt.quiver(ux, uy)
plt.show()

# %% [markdown]
# <font color='blue'>
#         Cette fois ci, on remarque que l'algorithme converge de manière BEAUCOUP plus rapide : seulement 48 itérations contre 2553. Pour ce qui est de l'interprétation des graphes, c'est la même que pour la partie précédente.
# </font>

# %%
epsi=0.1
stepini=0.01
nitermax = 1000
lamb = 0.5
mu = 0.5
ux,uy,CF,step, niter=RecalageGN(f,g,lamb,mu,nitermax,stepini,epsi)
# Out:
# iteration : 3  cost function : 18.905638360440744 step : 0.08
# iteration : 6  cost function : 17.160662503885092 step : 0.64
# iteration : 9  cost function : 9.052851672502477 step : 5.12
# iteration : 12  cost function : 1.635012871224907 step : 1.28
# iteration : 15  cost function : 1.0740764893405959 step : 1.28
# iteration : 18  cost function : 0.7006241320055545 step : 2.56
# iteration : 21  cost function : 0.5568685473209518 step : 2.56
# iteration : 24  cost function : 0.4774337732737609 step : 2.56
# iteration : 27  cost function : 0.42994260024928665 step : 1.28
# iteration : 30  cost function : 0.3933245285945175 step : 1.28
# iteration : 33  cost function : 0.3506623986884273 step : 2.56
# iteration : 36  cost function : 0.32811428668807496 step : 2.56
# iteration : 39  cost function : 0.3127152443833812 step : 2.56
# iteration : 42  cost function : 0.30317846725923175 step : 1.28
# iteration : 45  cost function : 0.29163631992850464 step : 2.56
# iteration : 48  cost function : 0.2842479982934759 step : 2.56
# iteration : 51  cost function : 0.2808986351930368 step : 1.28
# iteration : 54  cost function : 0.27442850906079047 step : 2.56
# iteration : 57  cost function : 0.2704199669917376 step : 2.56
# iteration : 60  cost function : 0.2674544031953258 step : 2.56
# iteration : 63  cost function : 0.26562210752839105 step : 1.28
# iteration : 66  cost function : 0.2632489040020362 step : 2.56
# iteration : 69  cost function : 0.26169950399960684 step : 2.56
# iteration : 72  cost function : 0.26051607235407603 step : 2.56
# iteration : 75  cost function : 0.25977494202537466 step : 1.28
# iteration : 78  cost function : 0.2589151267475053 step : 2.56
# iteration : 81  cost function : 0.2583722424628707 step : 2.56
# iteration : 84  cost function : 0.2579975182653852 step : 2.56
# iteration : 87  cost function : 0.2577765854242667 step : 2.56
# iteration : 90  cost function : 0.25770597716394994 step : 1.28

# %%
fig, ax = plt.subplots(2,3)
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Jeu des différences
#
# Maintenant que vous avez implémenté et testé les deux algorithmes sur l'image-jouet proposée, voyons que cela donne sur une image IRM d'un cerveau. Saurez-vous détecter les différences entre les deux images ?

# %%
im1=Image.open('IRM1.png')
im2=Image.open("IRM2.png")
plt.imshow(plt.imread('IRM1.png'))
plt.show()
plt.imshow(plt.imread('IRM2.png'))
plt.show()

# %%
[n,m]=im1.size
sigma=0.01
[X,Y]=np.meshgrid(np.linspace(-1,1,n),np.linspace(-1,1,m), indexing='xy')
Z=np.sqrt(X*X+Y*Y)
G=np.fft.fftshift(np.exp(-(X**2+Y**2)/sigma**2))
f=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im1)))
g=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im2))) 
f=f/np.max(f)
g=g/np.max(g)

# %% [markdown]
# <font color='blue'>
#         Pour commencer, nous n'allons pas lancer l'algorithme RecalageDG sur ce jeu de données. Cela serait bien trop long.
# </font>

# %%
epsi=0.01
stepini=0.01
nitermax = 5000
lamb = 0.0001
mu = 0.0001
ux,uy,CF,step, niter=RecalageGN(f,g,lamb,mu,nitermax,stepini,epsi)
# Out:
# iteration : 3  cost function : 2.683946246507373 step : 0.08
# iteration : 6  cost function : 2.0284033105059223 step : 0.64
# iteration : 9  cost function : 0.48697301602007814 step : 5.12
# iteration : 12  cost function : 0.1408524940732737 step : 2.56
# iteration : 15  cost function : 0.11114494222166144 step : 2.56
# iteration : 18  cost function : 0.09599077292089828 step : 2.56
# iteration : 21  cost function : 0.0852406763447795 step : 1.28
# iteration : 24  cost function : 0.07494773125313012 step : 2.56
# iteration : 27  cost function : 0.06839865099991252 step : 5.12
# iteration : 30  cost function : 0.06304705331108 step : 2.56
# iteration : 33  cost function : 0.05992059327459373 step : 2.56
# iteration : 36  cost function : 0.05680617009908834 step : 2.56
# iteration : 39  cost function : 0.05453130162142211 step : 2.56
# iteration : 42  cost function : 0.052196981765035906 step : 2.56
# iteration : 45  cost function : 0.05047648774577738 step : 2.56
# iteration : 48  cost function : 0.04862204217896035 step : 2.56
# iteration : 51  cost function : 0.04728506057268867 step : 2.56
# iteration : 54  cost function : 0.04575826568068064 step : 5.12
# iteration : 57  cost function : 0.04423446555082454 step : 5.12
# iteration : 60  cost function : 0.042896610900428414 step : 5.12
# iteration : 63  cost function : 0.041722321289130185 step : 5.12
# iteration : 66  cost function : 0.04066738244991705 step : 5.12
# iteration : 69  cost function : 0.03971780042407943 step : 5.12
# iteration : 72  cost function : 0.03885101466909187 step : 5.12
# iteration : 75  cost function : 0.03806318672784558 step : 5.12
# iteration : 78  cost function : 0.03733721874817264 step : 5.12
# iteration : 81  cost function : 0.036670722697689354 step : 5.12
# iteration : 84  cost function : 0.036053189023878704 step : 5.12
# iteration : 87  cost function : 0.03548599695581898 step : 5.12
# iteration : 90  cost function : 0.03496226132906069 step : 5.12
# iteration : 93  cost function : 0.0344820186259482 step : 5.12
# iteration : 96  cost function : 0.03403724999502862 step : 5.12
# iteration : 99  cost function : 0.03362648586991923 step : 5.12
# iteration : 102  cost function : 0.03324312104181905 step : 5.12
# iteration : 105  cost function : 0.03288664675695136 step : 5.12
# iteration : 108  cost function : 0.03255323565632927 step : 5.12
# iteration : 111  cost function : 0.032249810395733575 step : 5.12
# iteration : 114  cost function : 0.03199553309905564 step : 5.12
# iteration : 117  cost function : 0.031769568159417734 step : 5.12
# iteration : 120  cost function : 0.03164208707547667 step : 1.28

# %%
fig, ax = plt.subplots(2,3)
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <font color='blue'>
#     Nous avons remarqué que pour des $\lambda$ et $\mu$ relativement grands (10 par exemple), l'algorithme met énormément de temps à s'exécuter. C'est pour cela que nous avons choisi de les réduire pour avoir $\lambda=0.0001$ et $\mu=0.0001$ aussi.
# Par rapport à l'image test des parties précédentes, celle ci doit être affichée avec plus de précision pour ne pas être trop pixélisée ou floue. Avec $\sigma = 0.3$, on observe une "tâche" de couleur recouvrant le crâne entier. On ne peut donc pas déterminer avec précision où a lieu le changement. C'est pour cela que nous allons réduire la valeur de $\sigma$ pour l'abaisser à $0,01$.
#     De plus, $\epsilon$ représente le pas de descente. En réduisant celui ci, on peut bien mieux observer les différents résultats. C'est pour cela que nous définissons $\epsilon=0.01$. Nous remarquons cependant que lorsque $\epsilon$ diminue, le nombre d'itérations diminue aussi, donc il faut faire attention à ne pas avoir un nombre d'ittérations insufisant pour ne pas avoir un résultat faux.
#     De plus, on observe sur le graphe en haut à droite que l'erreur dimunie bien en fonction du temps.
#     Enfin, les taches noires représentent les endroits où on a du changement. C'est comme pour les parties d'avant, les parties noires mettent en évidence les différences entre la fonction initiale et la fonction finale.
# </font>

# %%
plt.quiver(np.flip(ux,0), np.flip(uy,0))
plt.show()
