# %% [markdown]
# TP- Recalage d'images
# =============

# %%
import numpy as np
from scipy import signal
from scipy import interpolate
from PIL import Image
import matplotlib.pyplot as plt
import time
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# Un problème fréquemment rencontré dans le domaine du traitement d’images est celui du recalage. On dispose de plusieurs images prises à des temps différents, ou par des appareils différents, et on aimerait les mettre en correspondence, c’est-à-dire trouver une déformation du plan, qui assure une correspondence point à point des objets sous-jacents. Donnons quelques exemples d’applications :
# * Traitements/retouches d’images. Par exemple, on peut vouloir construire un panoramique à partir d’images de petite taille. Il faut les recaler préalablement.
# * Evaluation des déplacements d’objets dans des séquences vidéos (e.g. trouver un défaut de fonctionnement d’un organe, caméras de surveillance, design de robots intelligents ou de systèmes de navigation automatiques ...)
# * Couplage d’informations. Par exemple, en imagerie médicale, on obtient une information plus riche en utilisant à la fois une radio et une angiographie. L’une apporte des informations structurelles, l’autre des informations fonctionnelles. Le couplage des deux images donne plus d’information au praticien.
# * Beaucoup d’autres applications...
#
# Dans ce TP, nous allons proposer un modèle de recalage assez élémentaire. Les idées constitutives se retrouvent cependant dans presque toutes les techniques récentes.

# %%
def get_images() :
    n=21
    sigma=0.3
    [X,Y]=np.meshgrid(np.linspace(-1,1,n),np.linspace(-1,1,n), indexing='xy')
    Z=np.sqrt(X*X+Y*Y)
    im1=np.zeros((n,n))
    im1[Z<=.7]=1.
    im1[Z<=.3]=.5
    im1[Z<=.1]=.7
    im2=np.zeros((n,n));
    Z=np.sqrt((X-.3)**2+(Y+.2)**2)
    im2[Z<=.7]=1
    im2[Z<=.3]=.5
    im2[Z<=.1]=.7
    G=np.fft.fftshift(np.exp(-(X**2+Y**2)/sigma**2))
    f=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im1)))
    g=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im2))) 
    f=f/np.max(f)
    g=g/np.max(g)
    return f,g,im1,im2

# %%
f,g,im1,im2=get_images()
fig, axarr = plt.subplots(2, 2, figsize=(10,10))
axarr[0,0].imshow(im1)
axarr[0,0].set_title('Image im1')
axarr[1,0].imshow(f)
axarr[1,0].set_title('function f ( blurry version of im1)')
axarr[0,1].imshow(im2)
axarr[0,1].set_title('Image im2')
axarr[1,1].imshow(g)
axarr[1,1].set_title('function g ( blurry version of im2)')
plt.show()

# %% [markdown]
# # 1. Formalisation du problème
# ## 1.1 Formalisme continu
#
# On modélise les images en niveaux de gris comme des fonctions d’un ensemble borné $\Omega\subset \mathbb{R}$ (typiquement un carré) dans $\mathbb{R}$. La valeur de la fonction en chaque point représente l’intensité lumineuse de l’image.
#
# Soient $f$ et $g$ deux images. On a donc :
# $$
# f:\Omega\subset \mathbb{R}^2 \to \mathbb{R},  g:\Omega\subset \mathbb{R}^2 \to \mathbb{R}
# $$
# En supposant que les images $f$ et $g$ dépendent seulement d’une transformation géométrique qui conserve la luminosité, le problème de recalage peut être formulé comme suit:
#
# <div style="background-color:rgba(0, 0, 255, 0.1); padding:15px;margin:5px">
# Problème $(P_1)$ : <br>
# Etant donnés $f$ et $g$ dans $H_1(\Omega)$ (les images ont une amplitude bornée et une énergie finie), trouver un champ de vecteurs $u = (u_1, u_2) \in H_1(\Omega)^2$ tel que:
# $$f(x + u(x)) = g(x), \forall x\in \Omega.$$
# </div>
#
# Le problème inverse est mal posé: tout d'abord, l'existence d'une solution n'est pas garantie, et dans le cas où il existe une solution, on n'a pas nécessairement unicité de cette solution. Par exemple, si $f$ et $g$ sont des fonctions constantes, n'importe quel déplacement $u$ est solution. Si $f$ est la constante $1$ et si $g$ est la constante $0$, il n'existe pas de solutions.
#
# Pour le résoudre, on se propose de le reformuler comme un problème d'optimisation:
#
# <div style="background-color:rgba(0, 0, 255, 0.1); padding:15px;margin:5px">
# Problème $(P_2)$ : <br>
# On cherche une déformation $u$ du plan qui minimise:
# $$
# E(u)=\displaystyle\frac{1}{2}\int_\Omega (f(x+u(x))-g(x))^2 dx=\frac{1}{2}\|f\circ (id+u)-g\|^2.
# $$
# </div>
#
# Sans hypothèse supplémentaire, le problème $\displaystyle \min_{u \in H^1(\Omega)^2} E(u)$ n'est a priori pas convexe, toujours mal posé et même éventuellement non différentiable si $u$ et $f$ ne sont pas assez régulières. On pourrait facilement rendre $f$ différentiable (en ajoutant du flou (on dit aussi du "bruit") par exemple à l'image, ce qui revient à convoler $f$ avec une gaussienne) mais il faut également "forcer" $u$ à être différentiable. Pour cela on propose de régulariser le problème de façon à assurer la convexité du problème d'optimisation considéré ainsi que l'existence et l'unicité des solutions.
#
# Pour régulariser le problème inverse, nous allons faire une analogie avec l’élasticité linéaire. La fonction $u = (u_x,u_y)$ représente un champ de déformations. En notant $\partial x$ et $\partial y$ les opérateurs de dérivation partielle par rapport à chacun des axes du plan, on peut définir un potentiel élastique linéarisé :
# $$
# R(u)= \frac{\mu}{2}\int_{\Omega} \underbrace{ (\partial_x u_y + \partial_y u_x)^2(x,y) dxdy}_{R_1(u)=\textrm{cisaillement}} +\frac{\lambda+\mu}{2}\int_{\Omega} \underbrace{(\partial_x u_x + \partial_y u_y)^2(x,y) dxdy}_{R_2(u)=\textrm{variations  de  volume}}.
# $$
# En mécanique des structures, $\mu$ et $\lambda$ sont appelées constantes de Lamé. Le paramètre $\lambda$ n’a pas d’interprétation directe, tandis que le paramètre $\mu$ est appelé module de cisaillement.
#
# Le problème d'optimisation à résoudre dans ce TP est le suivant:
# <div style="background-color:rgba(0, 0, 255, 0.1); padding:15px;margin:5px">
#
# $$(P)\qquad \min_{u} E(u)+R(u).$$
# $$
# E(u)=\displaystyle\frac{1}{2}\int_\Omega (f(x+u(x))-g(x))^2 dx=\frac{1}{2}\|f\circ (id+u)-g\|^2.
# $$
# $$
# R(u)= \frac{\mu}{2}\int_{\Omega} \underbrace{ (\partial_x u_y + \partial_y u_x)^2(x,y) dxdy}_{R_1(u)=\textrm{cisaillement}} +\frac{\lambda+\mu}{2}\int_{\Omega} \underbrace{(\partial_x u_x + \partial_y u_y)^2(x,y) dxdy}_{R_2(u)=\textrm{variations  de  volume}}.
# $$
# </div>
#
# **Q1.** A l'aide d'un développement de Taylor, vérifier que le gradient de $E$ s'écrit:
#
# $$\nabla E(u) = \left(f\circ (id+u) -g\right)\nabla f\circ (id+u)$$
#
# au sens où la différentielle de $E$ est définie par:
#
# $$dE(u)\cdot h= \displaystyle\int_\Omega \langle (f(x+u(x))-g(x))\nabla f(x+u(x)),h(x)\rangle dx.$$
#
# Puis par définition, on a $$ dE(u)\cdot h =\langle \nabla E(u),h\rangle \quad \forall h$$
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# On a $\forall (u,h) \in (H_1(\Omega)^2)^2 : \\$
# $$
# \begin{align*}
# E(u+h)
# &= \frac{1}{2}\int_{\Omega} \left[ f(x+u(x)+h(x)) - g(x)\right]^2 \, dx \\
# &= \frac{1}{2} \int_{\Omega} \left[f(x+u(x)) + \langle \nabla f(x+u(x)), h(x) \rangle + o(\|h\|) - g(x) \right]^2 \, dx  &\text{car on suppose que } f \text{ est différentiable} \\
# &= \frac{1}{2} \int_{\Omega} \left( \left[f(x+u(x)) - g(x)\right]^2 + 2 \langle \nabla f(x+u(x)), h(x) \rangle \left( f(x+u(x)) - g(x) \right) + o(\|h\|) \right) \, dx \\
# &= E(u) + \int_{\Omega} \langle \left( f(x + u(x) - g(x) \right) \nabla f(x + u(x)), h(x) \rangle \, dx + o(\|h\|) \\
# &= E(u) + dE(u)\cdot h + o(\|h\|) \\
# &= E(u) + \langle \nabla E(u),h\rangle + o(\|h\|) \\
# \end{align*}
# $$
#
# D'où $\nabla E(u) = \displaystyle\int_\Omega  (f(x+u(x))-g(x))\nabla f(x+u(x)) dx = \left(f\circ (id+u) -g\right)\nabla f\circ (id+u).$
#
#
# </div>

# %% [markdown]
# # 2. Discrétisation
#
# Pour pouvoir résoudre numériquement le problème $(P)$ (dont les variables de l'optimisation sont des fonctions !), on propose de le discrétiser au préalable.
#
# Soit $1\le i \le n$ and $1\le j\le m$. Notons $(x_i,y_j)$ le point de la grille $(i,j)$ et $f_{i,j}$ la valeur de $f$ au point $(x_i,y_j)$. Le produit scalaire sur $V=\mathcal M_{n,m}(\mathbb{R})$ est défini par:
# $$\langle f,g\rangle_V=\sum_{i=1}^n\sum_{j=1}^m f_{i,j}g_{i,j},$$
#
# ## 2.1. Calcul du $E$ et de son gradient
# Pour pouvoir calculer $E$ et son gradient, on va avoir besoin d'évaluer $f\circ (Id+u)$ et $\nabla f\circ(id+u)$. Pour cela, vous aurez besoin de la fonction `interpol` ci-dessous.

# %%
def interpol(function,ux,uy) :
    # function that computes f \circ Id+u and interpolates it on a mesh
    nx,ny=f.shape
    ip=interpolate.RectBivariateSpline(np.arange(nx),np.arange(ny),function)
    [X,Y]=np.meshgrid(np.arange(nx),np.arange(ny), indexing='ij')
    X=X+ux
    Y=Y+uy
    return np.reshape(ip.ev(X.ravel(),Y.ravel()),(nx,ny))

# %% [markdown]
# **Q2.** Lisez la documentation de la fonction `RectBivariateSpline` afin de comprendre ce que fait la fonction `interpol`.
#
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Le code effectue une interpolation bidimensionnelle d'une fonction sur une grille. La fonction prend en entrée un tableau bidimensionnel et deux paramètres de décalage ux et uy. La fonction (RectBivariateSpline) crée un objet d'interpolation. Ensuite, elle déplace les coordonnées de la grille en ajoutant les décalages ux et uy. Pour finir, les valeurs interpolées sont évaluées aux nouvelles coordonnées, les remodelant en un tableau 2D avec la forme initiale de la fonction.
# En résumé, la fonction effectue une interpolation spatiale d'une fonction sur une grille, avec la possibilité de spécifier des décalages.
# </div>
#
#
# ## 2.2. Calcul de $R$ et de son gradient
# On discrétise également les opérateurs de dérivation partielles par différences finies ; par exemple la dérivée partielle par rapport à $x$ est donnée par, pour tout $f\in V$ par
# $$\begin{cases}(\partial_x f)_{i,j}=f_{i+1,j}-f_{i,j} \text{ si } i<n \\
# (\partial_x f)_{n,j}=0 \end{cases}.$$
# On a ainsi $\partial_x f\in V$.
#
# On définit les opérateurs $\partial_x^T$ et $\partial_y^T$ comme les uniques opérateurs qui vérifient
#
# $$ \langle \partial_x^T f, g\rangle_V = \langle f,\partial_x  g\rangle_V \quad \forall f,g\in V$$
# $$ \langle \partial_y^T f, g\rangle_V = \langle f,\partial_y  g\rangle_V \quad \forall f,g\in V$$
#
# **Q2.** Donner les formules de discrétisation des opérateurs $\partial_y$, $\partial_x^\top$ et $\partial_y^\top$. Implémenter ces opérateurs ci-après. On donne un test de vérification.

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Pour $\partial _y$ :
# $$\begin{cases}(\partial_y f)_{i,j}=f_{i,j+1}-f_{i,j} \text{ si } j<n \\
# (\partial_y f)_{i,n}=0 \end{cases} $$
#
# Pour $\partial _x ^T$ :
# $$\begin{align}
# \langle \partial _x u, v \rangle_V &= \sum_{i=1}^{n-1}\sum_{j=1}^{n}(u_{i+1,j}-u_{ij})v_{ij}\\
# &=\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{i+1,j}v_{ij}-\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij}\\
# &=\sum_{i=2}^{n}\sum_{j=1}^{n}u_{ij}v_{i-1,j}-\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij}\\
# &=\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{ij}v_{i-1,j}-\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij} - \sum_{j=1}^{n} u_{1j}v_{1j} + \sum_{j=1}^{n} u_{nj}v_{n-1,j}\\
# &=\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{ij}(v_{i-1,j}-v_{ij}) + \sum_{j=1}^{n} u_{nj}v_{n-1,j}-u_{1j}v_{1j}\\ \\ \\
# \end{align}$$
#
# Par identification :
# $$\partial _x ^T=\begin{cases}f_{i-1,j}-f_{ij} \text{ si } i\in[2;n-1] \\
#         f_{n-1,j} \text{ si } i=n \\
#         -f_{1j} \text{ si } i=1 \end{cases} $$
#
# Pour $\partial _y ^T$ :
# $$\begin{align}
# \langle \partial _y u, v \rangle_V &= \sum_{i=1}^{n}\sum_{j=1}^{n-1}(u_{i,j+1}-u_{ij})v_{ij}\\
# &=\sum_{i=1}^{n}\sum_{j=1}^{n-1}u_{i,j+1}v_{ij}-\sum_{i=1}^{n}\sum_{j=1}^{n-1}u_{ij}v_{ij}\\
# &=\sum_{i=1}^{n}\sum_{j=2}^{n}u_{ij}v_{i,j-1}-\sum_{i=1}^{n}\sum_{j=1}^{n-1}u_{ij}v_{ij}\\
# &=\sum_{i=1}^{n}\sum_{j=2}^{n-1}u_{ij}v_{i,j-1}-\sum_{i=1}^{n}\sum_{j=2}^{n-1}u_{ij}v_{ij} - \sum_{i=1}^{n} u_{i1}v_{i1} + \sum_{i=1}^{n} u_{in}v_{i,n-1}\\
# &=\sum_{i=1}^{n}\sum_{j=2}^{n-1}u_{ij}(v_{i,j-1}-v_{ij}) + \sum_{i=1}^{n} u_{in}v_{i,n-1}-u_{i1}v_{i1}\\ \\ \\
# \end{align}$$
#
# Par identification:
# $$\partial _y ^T=\begin{cases}f_{i,j-1}-f_{ij} \text{ si } j\in[2;n-1] \\
#         f_{i,n-1} \text{ si } j=n \\
#         -f_{i1} \text{ si } j=1 \end{cases} $$
#
# </div>

# %%
def dx(im) :
    d=np.zeros(im.shape)
    d[:-1,:]=im[1:,:]-im[:-1,:]
    return d
def dy(im) :
    d=np.zeros(im.shape)
    d[:,:-1]=im[:,1:]-im[:,:-1]
    return d
def dyT(im) :
    d=np.zeros(im.shape)
    d[:,0]=-im[:,0]
    d[:,-1]=im[:,-2]
    d[:,1:-1]=im[:,0:-2]-im[:,1:-1]  
    return d  
def dxT(im) :
    d=np.zeros(im.shape)
    d[0,:]=-im[0,:]
    d[-1,:]=im[-2,:]
    d[1:-1,:]=im[0:-2,:]-im[1:-1,:]   
    return d

def scal(a,b) :
    assert a.shape==b.shape
    return np.sum(a*b)

np.random.seed(42)
im1=np.random.randn(12,15)
im2=np.random.randn(12,15)
print(scal(dx(im1),im2),'=',scal(im1,dxT(im2)))
# Out:
# -17.489408391382973 = -17.489408391382973

# %% [markdown]
# **Q3.**  On peut alors écrire :
# $$
# R(u)= \frac{\mu}{2}\underbrace{\sum_{i}(\partial_x u_y + \partial_y u_x)^2(i)}_{=R_1(u)} + \frac{\lambda+\mu}{2} \underbrace{\sum_i(\partial_x u_x + \partial_y u_y)^2(i)}_{=R_2(u)}.
# $$
# où:
# * $u_x\in V$ et $u_y\in V$ sont les discrétisations des composantes du champ de vecteurs $u$ sur la grille choisie
# * $\partial_x:V \rightarrow V$ et $\partial_y:V\rightarrow V$ représentent les opérateurs de différences finies.
#
# On peut ré-écrire $R(u)=\frac{\mu}{2}R_1(u)+ \frac{\lambda+\mu}{2} R_2(u)$ avec :
# $$
# R_1(u)=\langle A_1 u , A_1 u\rangle_V,\qquad R_2(u)=\langle A_2 u , A_2 u\rangle_V.
# $$
# Où $A_i$ est un opérateur de $V^2$ dans $V$.
# Donnez l'expression des matrices $A_1$ et $A_2$ en fonction des opérateurs $\partial_x$ et $\partial_y$.
#
#
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Pour $A_1$ :
# $$R_1(u) = \langle A_1 u , A_1 u\rangle_V = \|A_1u\|^2_V = \|A_1 \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}\|^2_V =  \|\partial_x u_y + \partial_y u_x \|^2_V = \|
# \begin{bmatrix}
#     dy \\
#     dx
# \end{bmatrix}^T \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}
#  \
#  \|^2_V$$
# D'où, $$A_1 = \begin{bmatrix}
#     dy &  dx
# \end{bmatrix}$$
#
# Pour $A_2$ :
# $$R_2(u) = \langle A_2 u , A_2 u\rangle_V = \|A_2u\|^2_V = \|A_2 \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}\|^2_V =  \|\partial_x u_x + \partial_y u_y \|^2_V = \|
# \begin{bmatrix}
#     dx \\
#     dy
# \end{bmatrix}^T \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}
#  \
#  \|^2_V$$
# D'où, $$A_2 = \begin{bmatrix}
#     dx &  dy
# \end{bmatrix}$$
# </div>
#
#
# **Q3b.**
# Pour tout $u=(u_x,u_y)$ et $v=(v_x,v_y)$ dans $V^2$, on définit le produit scalaire dans $V^2$ par
# $$\langle u,v\rangle_{V^2}=\langle u_x,v_x\rangle_{V}+\langle u_y,v_y\rangle_{V}$$
#
# Montrer que $R(u)$ peut s'écrire sous la forme:
# $$R(u)=\frac{1}{2} \langle A\left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right),\left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right)\rangle_{V^2},$$
#
# Avec $$A=\mu A_1^TA_1 +(\lambda+\mu) A_2^TA_2$$ et $A_i^T$ un opérateur de $V^2$ dans $V$.
#
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# \[
# \begin{align*}
# R(u) &= \frac{\mu}{2}\langle A_1 u, A_1 u\rangle_{V^2} + \frac{\lambda + \mu}{2}\langle A_2 u, A_2 u\rangle_{V^2} \\
# &= \frac{\mu}{2}\left(\langle \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &\quad+ \frac{\lambda + \mu}{2}\left(\langle \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\left(\mu \langle \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &\quad+ \frac{1}{2}\left((\lambda + \mu) \langle \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\left(\langle \mu \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} + (\lambda + \mu) \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \mu \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} + (\lambda + \mu) \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\left(\langle \mu A_1^TA_1 \begin{bmatrix} u_x \\ u_y \end{bmatrix} + (\lambda + \mu) A_2^TA_2 \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\langle A\begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V^2},
# \end{align*}
# \]
#
# où $$A = \mu A_1^TA_1 + (\lambda + \mu) A_2^TA_2$$
#
# </div>
#
# **Q4.** Donner l'expression du gradient de $R$.
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Comme $R(u)=\frac{\mu}{2}R_1(u)+ \frac{\lambda+\mu}{2} R_2(u)$, on a $\nabla R(u) = \frac{\mu}{2} \nabla R_1(u) + \frac{\lambda+\mu}{2} \nabla R_2(u)$.
#
# Pour $\nabla R_1(u)$ :
#
# On a $\forall (u,h) \in V^2$ :
# $$
# \begin{align*}
# R_1(u+h)
# &= R_1(u) + 2 \langle A_1^T A_1 u,h\rangle + o(\|h\|) \\
# \end{align*}
# $$
# Ainsi :
#
# $$
# \begin{align}
# \nabla R_1(u) &= 2 A_1^T A_1 u \\
# &= 2 \begin{bmatrix}
# \partial_y^T \\
# \partial_x^T
# \end{bmatrix} \begin{bmatrix}
# \partial_y & \partial_x
# \end{bmatrix} \begin{bmatrix}
# u_x \\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}
# \partial_y^T \partial_y & \partial_y^T \partial_x \\
# \partial_x^T \partial_y & \partial_x^T \partial_x
# \end{bmatrix} \begin{bmatrix}
# u_x \\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}
# \partial_y^T \partial_y u_x + \partial_y^T \partial_x u_y \\
# \partial_x^T \partial_y u_x + \partial_x^T \partial_x u_y
# \end{bmatrix}
# \end{align}
# $$
#
# Pour $\nabla R_2(u)$ :
#
# On a $\forall (u,h) \in V^2$ :
# $$
# \begin{align*}
# R_2(u+h)
# &= R_2(u) + 2 \langle A_2^T A_2 u,h\rangle + o(\|h\|) \\
# \end{align*}
# $$
# Ainsi :
# $$\begin{align}
# \nabla R_2(u) &= 2 A_2^T A_2 u \\
# &= 2 \begin{bmatrix}
# \partial_x^T\\
# \partial_y^T
# \end{bmatrix} (\partial_x \text{ } \partial_y) \begin{bmatrix}
# u_x\\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}\partial_x^T\partial_x & \partial_x^T\partial_y \\ \partial_y^T\partial_x & \partial_y^T\partial_y \end{bmatrix} \begin{bmatrix}
# u_x\\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}\partial_x^T\partial_x u_x + \partial_x^T\partial_y u_y\\ \partial_y^T\partial_x u_x +  \partial_y^T\partial_y u_y\end{bmatrix}
# \end{align}$$
#
# Finalement, on a :
# $$ \nabla R(u) = \mu \begin{bmatrix}\partial_y^T\partial_yu_x + \partial_y^T\partial_xu_y\\ \partial_x^T\partial_yu_x +  \partial_x^T\partial_xu_y\end{bmatrix} + (\lambda +\mu) \begin{bmatrix}\partial_x^T\partial_x u_x + \partial_x^T\partial_y u_y\\ \partial_y^T\partial_x u_x +  \partial_y^T\partial_y u_y\end{bmatrix}
# $$
# </div>
#
# ## 2.3. Implémentation de la fonction objectif $E+R$
#
# Créez une fonction `objective_function` qui calcul $E(u)+R(u)$.
#
# Cette fonction prend en variable d'entrée
# * `f`,`g` et `ux` et `uy` qui sont nécessaires au calcul de $E(u)$
# * `ux`,`uy` ,`lamb` et `mu` qui sont nécessaires au calcul de $R(u)$. Ici `lamb` et `mu` sont deux variables réelles positives qui représentent $\lambda$ et $\mu$.
#
#
# Cette fonction doit rendre deux arguments :
# * `obj` qui est la valeur de $E(u)+R(u)$
# * `fu` qui est un tableau qui représente le résultat du calcul de $f\circ(Id +u)$. On rend ce tableau car il sera utile pour les prochains calculs.

# %%
def objective_function(f,g,ux,uy,lamb,mu) :
    #implementation de E(u)+R(u)
    fu=interpol(f, ux, uy)
    
    #Calcul de R
    R= mu/2 * np.linalg.norm(dx(uy)+dy(ux))**2 + (lamb+mu)/2 * np.linalg.norm(dx(ux)+dy(uy))**2
    
    #Calcul de E
    E=1/2*np.linalg.norm(fu-g)**2  
    
    obj = R+E
    return obj,fu

np.random.seed(12)
ux=np.random.randn(f.shape[0],f.shape[1])
uy=np.random.randn(f.shape[0],f.shape[1])
obj,fu=objective_function(2*f,3*g,ux,uy,10,5)
print(obj,fu.shape,np.linalg.norm(fu)) #18215.406074781582 (21, 21) 22.047265562734097
# Out:
# 18215.406074781582 (21, 21) 22.047265562734097

# %% [markdown]
# ## 2.4 Implémentation des gradients
# Créez une fonction `gradE` et `gradR` qui calcule $\nabla E(u)$ et $\nabla R(u)$. On garde les conventions de noms de variable de la section précédente et on notera `gradxE,gradyE` les deux composantes de  $\nabla E(u)$ et `gradxR,gradyR` les deux composantes de $\nabla R(u)$. Les variables `dfx` et `dfy`contiennent les dérivées selon `x` et `y` de `f`, elles seront initalisées par `dfx=dx(f)` et `dfy=dy(f)`

# %%
def gradE(dfx,dfy,g,fu,ux,uy) :
    gradxE=(fu-g)*(interpol(dfx,ux,uy))
    gradyE=(fu-g)*(interpol(dfy,ux,uy))
    return gradxE,gradyE

def gradR(lamb,mu,ux,uy) :
    gradxR = mu*dyT(dy(ux)) + (lamb+mu)*dxT(dx(ux)) + mu*dyT(dx(uy)) + (lamb+mu)*dxT(dy(uy))
    gradyR = mu*dxT(dy(ux)) + (mu+lamb)*dyT(dx(ux)) + mu*dxT(dx(uy)) + (lamb+mu)*dyT(dy(uy))
    return gradxR,gradyR

# %%
dfx=dx(f)
dfy=dy(f)  
np.random.seed(12)
ux=np.random.randn(f.shape[0],f.shape[1])
uy=np.random.randn(f.shape[0],f.shape[1])
obj,fu=objective_function(f,g,ux,uy,10,5)
gradxE,gradyE=gradE(dfx,dfy,g,fu,ux,uy)
print(gradxE.shape,gradyE.shape) #(21, 21) (21, 21)
print(np.linalg.norm(gradxE),np.linalg.norm(gradyE)) #0.6513993385167333 0.6040320505869908
gradxR,gradyR=gradR(10.,5.,ux,uy) 
print(gradxR.shape,gradyR.shape)  #(21, 21) (21, 21)
print(np.linalg.norm(gradxR),np.linalg.norm(gradyR)) #1180.7792368512296 1239.1880693357143
# Out:
# (21, 21) (21, 21)
# 0.6513993385167333 0.6040320505869909
# (21, 21) (21, 21)
# 1180.7792368512296 1239.1880693357143

# %% [markdown]
# # 3. Un algorithme de gradient
#
# Une itération de la méthode de descente de gradient est de la forme:
#
# $$
# u_{k+1}=u_k-s_k(\nabla E(u) + \nabla R(u))
# $$
#
# **Q5.** Compléter la fonction RecalageDG implémentant la descente de gradient et utilisant l'algorithme de recherche linéaire par rebroussement proposé ci-dessous.

# %%
def linesearch(ux,uy,step,descentx,descenty,obj_old,f,g,lamb,mu) :
    step=2*step
    tmpx=ux-step*descentx
    tmpy=uy-step*descenty
    obj,fu=objective_function(f,g,tmpx,tmpy,lamb,mu)
    while obj >obj_old and step > 1.e-8:
        step=0.5*step
        tmpx=ux-step*descentx
        tmpy=uy-step*descenty
        obj,fu=objective_function(f,g,tmpx,tmpy,lamb,mu)
    return tmpx,tmpy,step


def RecalageDG(f,g,lamb,mu,nitermax,stepini) : 
    ux=np.zeros(f.shape)
    uy=np.zeros(f.shape)  
    CF=[]
    step_list=[]
    niter=0
    step=stepini
    dfx = dx(f)
    dfy = dy(f)
    # raise ValueError('Compute dfx and dfy here')
    while niter < nitermax and step > 1.e-8 : 
        niter+=1
        obj,fu=objective_function(f,g,ux,uy,lamb,mu)
        CF.append(obj) 
        gradiE = gradE(dfx,dfy,g,fu,ux,uy)
        gradiR = gradR(lamb,mu,ux,uy)
        # raise ValueError('Compute gradxE and gradyE here')
        # raise ValueError('Compute gradRx and gradRy here')
        # raise ValueError('Compute gradx and grady here')

        gradx = gradiE[0] + gradiR[0]
        grady = gradiE[1] + gradiR[1]
        
        ux,uy,step=linesearch(ux,uy,step,gradx,grady,obj,f,g,lamb,mu)
        step_list.append(step)
        if (niter % 3 ==0) :
            print('iteration :',niter,' cost function :',obj,'step :',step, 'lambda :', lamb, 'mu :', mu)
    return ux,uy,np.array(CF),np.array(step_list), niter

# %% [markdown]
# **Q5.** Ecrire un compte-rendu des expériences réalisées et des résultats obtenus. Commentez.

# %%
lamb=10
mu=20
nitermax=500
step0 = 0.01
start_time = time.time()
ux,uy,CF,step, niter=RecalageDG(f,g,lamb,mu,nitermax,step0)
print("Execution time: %s seconds" % (time.time() - start_time))
# la premiere ligne est 
# iteration : 3  cost function : 19.08125492560699 step : 0.08
# Out:
# iteration : 3  cost function : 19.08125492560699 step : 0.08 lambda : 10 mu : 20
# iteration : 6  cost function : 19.04274372706119 step : 0.02 lambda : 10 mu : 20
# iteration : 9  cost function : 19.031367910404175 step : 0.01 lambda : 10 mu : 20
# iteration : 12  cost function : 19.02412383888724 step : 0.01 lambda : 10 mu : 20
# iteration : 15  cost function : 19.01806210880887 step : 0.01 lambda : 10 mu : 20
# iteration : 18  cost function : 19.01253459257596 step : 0.005 lambda : 10 mu : 20
# iteration : 21  cost function : 19.008553844127363 step : 0.005 lambda : 10 mu : 20
# iteration : 24  cost function : 19.003094849027036 step : 0.005 lambda : 10 mu : 20
# iteration : 27  cost function : 18.998331455413695 step : 0.005 lambda : 10 mu : 20
# iteration : 30  cost function : 18.993817208909224 step : 0.005 lambda : 10 mu : 20
# iteration : 33  cost function : 18.98942613970379 step : 0.005 lambda : 10 mu : 20
# iteration : 36  cost function : 18.985108875837884 step : 0.01 lambda : 10 mu : 20
# iteration : 39  cost function : 18.98193380064393 step : 0.005 lambda : 10 mu : 20
# iteration : 42  cost function : 18.977325922524685 step : 0.005 lambda : 10 mu : 20
# iteration : 45  cost function : 18.972843826776202 step : 0.005 lambda : 10 mu : 20
# iteration : 48  cost function : 18.968449166662687 step : 0.005 lambda : 10 mu : 20
# iteration : 51  cost function : 18.96411855651942 step : 0.005 lambda : 10 mu : 20
# iteration : 54  cost function : 18.95983736149077 step : 0.005 lambda : 10 mu : 20
# iteration : 57  cost function : 18.955596083666894 step : 0.005 lambda : 10 mu : 20
# iteration : 60  cost function : 18.951388393440915 step : 0.005 lambda : 10 mu : 20
# iteration : 63  cost function : 18.947209860284694 step : 0.005 lambda : 10 mu : 20
# iteration : 66  cost function : 18.943057295592574 step : 0.005 lambda : 10 mu : 20
# iteration : 69  cost function : 18.938928261804136 step : 0.005 lambda : 10 mu : 20
# iteration : 72  cost function : 18.934820860061198 step : 0.005 lambda : 10 mu : 20
# iteration : 75  cost function : 18.930733516401435 step : 0.005 lambda : 10 mu : 20
# iteration : 78  cost function : 18.926664925350405 step : 0.005 lambda : 10 mu : 20
# iteration : 81  cost function : 18.922613939873933 step : 0.005 lambda : 10 mu : 20
# iteration : 84  cost function : 18.91857956998594 step : 0.005 lambda : 10 mu : 20
# iteration : 87  cost function : 18.914560914210174 step : 0.005 lambda : 10 mu : 20
# iteration : 90  cost function : 18.91055717712617 step : 0.005 lambda : 10 mu : 20
# iteration : 93  cost function : 18.906567619263814 step : 0.005 lambda : 10 mu : 20
# iteration : 96  cost function : 18.902591580487112 step : 0.005 lambda : 10 mu : 20
# iteration : 99  cost function : 18.899894101344827 step : 0.005 lambda : 10 mu : 20
# iteration : 102  cost function : 18.8957089693087 step : 0.005 lambda : 10 mu : 20
# iteration : 105  cost function : 18.891557546987066 step : 0.005 lambda : 10 mu : 20
# iteration : 108  cost function : 18.88743731390891 step : 0.005 lambda : 10 mu : 20
# iteration : 111  cost function : 18.883345944010326 step : 0.005 lambda : 10 mu : 20
# iteration : 114  cost function : 18.87928135837361 step : 0.005 lambda : 10 mu : 20
# iteration : 117  cost function : 18.87524163026441 step : 0.005 lambda : 10 mu : 20
# iteration : 120  cost function : 18.87122503689638 step : 0.005 lambda : 10 mu : 20
# iteration : 123  cost function : 18.867229975793556 step : 0.005 lambda : 10 mu : 20
# iteration : 126  cost function : 18.863255014332086 step : 0.005 lambda : 10 mu : 20
# iteration : 129  cost function : 18.85929881540263 step : 0.005 lambda : 10 mu : 20
# iteration : 132  cost function : 18.855360184228275 step : 0.005 lambda : 10 mu : 20
# iteration : 135  cost function : 18.851438001924986 step : 0.005 lambda : 10 mu : 20
# iteration : 138  cost function : 18.847531269431908 step : 0.005 lambda : 10 mu : 20
# iteration : 141  cost function : 18.843639047906684 step : 0.005 lambda : 10 mu : 20
# iteration : 144  cost function : 18.839760499765575 step : 0.005 lambda : 10 mu : 20
# iteration : 147  cost function : 18.83589483505894 step : 0.005 lambda : 10 mu : 20
# iteration : 150  cost function : 18.832041349699008 step : 0.005 lambda : 10 mu : 20
# iteration : 153  cost function : 18.828199377103992 step : 0.005 lambda : 10 mu : 20
# iteration : 156  cost function : 18.824368323732774 step : 0.005 lambda : 10 mu : 20
# iteration : 159  cost function : 18.820547625392724 step : 0.005 lambda : 10 mu : 20
# iteration : 162  cost function : 18.816736780220754 step : 0.005 lambda : 10 mu : 20
# iteration : 165  cost function : 18.8129353091347 step : 0.005 lambda : 10 mu : 20
# iteration : 168  cost function : 18.809142786408767 step : 0.01 lambda : 10 mu : 20
# iteration : 171  cost function : 18.806415920417116 step : 0.005 lambda : 10 mu : 20
# iteration : 174  cost function : 18.80242967645001 step : 0.005 lambda : 10 mu : 20
# iteration : 177  cost function : 18.79847074716217 step : 0.005 lambda : 10 mu : 20
# iteration : 180  cost function : 18.79453704120644 step : 0.005 lambda : 10 mu : 20
# iteration : 183  cost function : 18.79062661534632 step : 0.005 lambda : 10 mu : 20
# iteration : 186  cost function : 18.786737736537987 step : 0.005 lambda : 10 mu : 20
# iteration : 189  cost function : 18.782868790308378 step : 0.005 lambda : 10 mu : 20
# iteration : 192  cost function : 18.779018317081064 step : 0.005 lambda : 10 mu : 20
# iteration : 195  cost function : 18.775184920900042 step : 0.005 lambda : 10 mu : 20
# iteration : 198  cost function : 18.77136754344816 step : 0.005 lambda : 10 mu : 20
# iteration : 201  cost function : 18.767564948704205 step : 0.005 lambda : 10 mu : 20
# iteration : 204  cost function : 18.76377625716318 step : 0.005 lambda : 10 mu : 20
# iteration : 207  cost function : 18.760000429467713 step : 0.005 lambda : 10 mu : 20
# iteration : 210  cost function : 18.756236742170803 step : 0.005 lambda : 10 mu : 20
# iteration : 213  cost function : 18.75248431948168 step : 0.005 lambda : 10 mu : 20
# iteration : 216  cost function : 18.748742566075222 step : 0.005 lambda : 10 mu : 20
# iteration : 219  cost function : 18.745010742330013 step : 0.005 lambda : 10 mu : 20
# iteration : 222  cost function : 18.741288358077217 step : 0.005 lambda : 10 mu : 20
# iteration : 225  cost function : 18.73757478717401 step : 0.005 lambda : 10 mu : 20
# iteration : 228  cost function : 18.73386962573169 step : 0.005 lambda : 10 mu : 20
# iteration : 231  cost function : 18.730172342283 step : 0.005 lambda : 10 mu : 20
# iteration : 234  cost function : 18.7264826037078 step : 0.005 lambda : 10 mu : 20
# iteration : 237  cost function : 18.722799957623913 step : 0.01 lambda : 10 mu : 20
# iteration : 240  cost function : 18.72019188852294 step : 0.005 lambda : 10 mu : 20
# iteration : 243  cost function : 18.716313787875784 step : 0.005 lambda : 10 mu : 20
# iteration : 246  cost function : 18.71246124515657 step : 0.005 lambda : 10 mu : 20
# iteration : 249  cost function : 18.70863202954588 step : 0.005 lambda : 10 mu : 20
# iteration : 252  cost function : 18.704824459577715 step : 0.005 lambda : 10 mu : 20
# iteration : 255  cost function : 18.70103667379766 step : 0.005 lambda : 10 mu : 20
# iteration : 258  cost function : 18.697267294763815 step : 0.005 lambda : 10 mu : 20
# iteration : 261  cost function : 18.693514767251177 step : 0.005 lambda : 10 mu : 20
# iteration : 264  cost function : 18.689777963397116 step : 0.005 lambda : 10 mu : 20
# iteration : 267  cost function : 18.68605558200882 step : 0.005 lambda : 10 mu : 20
# iteration : 270  cost function : 18.682346700020624 step : 0.005 lambda : 10 mu : 20
# iteration : 273  cost function : 18.678650227105376 step : 0.005 lambda : 10 mu : 20
# iteration : 276  cost function : 18.674965408168344 step : 0.005 lambda : 10 mu : 20
# iteration : 279  cost function : 18.671291328038365 step : 0.005 lambda : 10 mu : 20
# iteration : 282  cost function : 18.667627369316232 step : 0.005 lambda : 10 mu : 20
# iteration : 285  cost function : 18.663972762435474 step : 0.005 lambda : 10 mu : 20
# iteration : 288  cost function : 18.660327002809627 step : 0.005 lambda : 10 mu : 20
# iteration : 291  cost function : 18.65668944201258 step : 0.005 lambda : 10 mu : 20
# iteration : 294  cost function : 18.653059667826536 step : 0.005 lambda : 10 mu : 20
# iteration : 297  cost function : 18.649437132704207 step : 0.005 lambda : 10 mu : 20
# iteration : 300  cost function : 18.64582150000522 step : 0.005 lambda : 10 mu : 20
# iteration : 303  cost function : 18.642212306272743 step : 0.005 lambda : 10 mu : 20
# iteration : 306  cost function : 18.638609276658222 step : 0.005 lambda : 10 mu : 20
# iteration : 309  cost function : 18.636081125720096 step : 0.005 lambda : 10 mu : 20
# iteration : 312  cost function : 18.63228273291909 step : 0.005 lambda : 10 mu : 20
# iteration : 315  cost function : 18.628508576067027 step : 0.005 lambda : 10 mu : 20
# iteration : 318  cost function : 18.624756842767926 step : 0.005 lambda : 10 mu : 20
# iteration : 321  cost function : 18.62102553158656 step : 0.005 lambda : 10 mu : 20
# iteration : 324  cost function : 18.617313160513664 step : 0.005 lambda : 10 mu : 20
# iteration : 327  cost function : 18.613618059908873 step : 0.005 lambda : 10 mu : 20
# iteration : 330  cost function : 18.60993901886787 step : 0.005 lambda : 10 mu : 20
# iteration : 333  cost function : 18.606274642845097 step : 0.005 lambda : 10 mu : 20
# iteration : 336  cost function : 18.602623943284307 step : 0.005 lambda : 10 mu : 20
# iteration : 339  cost function : 18.59898575385332 step : 0.005 lambda : 10 mu : 20
# iteration : 342  cost function : 18.595359268253905 step : 0.005 lambda : 10 mu : 20
# iteration : 345  cost function : 18.591743509593144 step : 0.005 lambda : 10 mu : 20
# iteration : 348  cost function : 18.588137820876614 step : 0.005 lambda : 10 mu : 20
# iteration : 351  cost function : 18.5845413825717 step : 0.005 lambda : 10 mu : 20
# iteration : 354  cost function : 18.580953659907923 step : 0.005 lambda : 10 mu : 20
# iteration : 357  cost function : 18.57737396416397 step : 0.005 lambda : 10 mu : 20
# iteration : 360  cost function : 18.57380186054859 step : 0.005 lambda : 10 mu : 20
# iteration : 363  cost function : 18.57023676917109 step : 0.005 lambda : 10 mu : 20
# iteration : 366  cost function : 18.566678336953768 step : 0.005 lambda : 10 mu : 20
# iteration : 369  cost function : 18.563126074630482 step : 0.005 lambda : 10 mu : 20
# iteration : 372  cost function : 18.5595796958453 step : 0.005 lambda : 10 mu : 20
# iteration : 375  cost function : 18.556038786870044 step : 0.005 lambda : 10 mu : 20
# iteration : 378  cost function : 18.553568305093318 step : 0.005 lambda : 10 mu : 20
# iteration : 381  cost function : 18.549832820602138 step : 0.005 lambda : 10 mu : 20
# iteration : 384  cost function : 18.546120989716968 step : 0.005 lambda : 10 mu : 20
# iteration : 387  cost function : 18.542430646423732 step : 0.005 lambda : 10 mu : 20
# iteration : 390  cost function : 18.538760186221996 step : 0.005 lambda : 10 mu : 20
# iteration : 393  cost function : 18.535107803632254 step : 0.005 lambda : 10 mu : 20
# iteration : 396  cost function : 18.531472189211556 step : 0.005 lambda : 10 mu : 20
# iteration : 399  cost function : 18.527851836325045 step : 0.005 lambda : 10 mu : 20
# iteration : 402  cost function : 18.524245677466624 step : 0.005 lambda : 10 mu : 20
# iteration : 405  cost function : 18.520652453844555 step : 0.005 lambda : 10 mu : 20
# iteration : 408  cost function : 18.5170712962132 step : 0.005 lambda : 10 mu : 20
# iteration : 411  cost function : 18.513501151447368 step : 0.005 lambda : 10 mu : 20
# iteration : 414  cost function : 18.509941312661468 step : 0.005 lambda : 10 mu : 20
# iteration : 417  cost function : 18.50639089750773 step : 0.005 lambda : 10 mu : 20
# iteration : 420  cost function : 18.502849331961517 step : 0.005 lambda : 10 mu : 20
# iteration : 423  cost function : 18.49931587558215 step : 0.005 lambda : 10 mu : 20
# iteration : 426  cost function : 18.495790062975797 step : 0.005 lambda : 10 mu : 20
# iteration : 429  cost function : 18.492271271710173 step : 0.005 lambda : 10 mu : 20
# iteration : 432  cost function : 18.48875912512818 step : 0.005 lambda : 10 mu : 20
# iteration : 435  cost function : 18.485253099014887 step : 0.005 lambda : 10 mu : 20
# iteration : 438  cost function : 18.481752889123314 step : 0.005 lambda : 10 mu : 20
# iteration : 441  cost function : 18.478258053059342 step : 0.005 lambda : 10 mu : 20
# iteration : 444  cost function : 18.474768345594132 step : 0.005 lambda : 10 mu : 20
# iteration : 447  cost function : 18.4723412991964 step : 0.005 lambda : 10 mu : 20
# iteration : 450  cost function : 18.468658357070172 step : 0.005 lambda : 10 mu : 20
# iteration : 453  cost function : 18.464998271778413 step : 0.005 lambda : 10 mu : 20
# iteration : 456  cost function : 18.461359301832236 step : 0.005 lambda : 10 mu : 20
# iteration : 459  cost function : 18.457739487647103 step : 0.005 lambda : 10 mu : 20
# iteration : 462  cost function : 18.454137409044115 step : 0.005 lambda : 10 mu : 20
# iteration : 465  cost function : 18.45055143156227 step : 0.005 lambda : 10 mu : 20
# iteration : 468  cost function : 18.446980398451704 step : 0.005 lambda : 10 mu : 20
# iteration : 471  cost function : 18.4434229448529 step : 0.005 lambda : 10 mu : 20
# iteration : 474  cost function : 18.439878129855323 step : 0.005 lambda : 10 mu : 20
# iteration : 477  cost function : 18.43634481228886 step : 0.005 lambda : 10 mu : 20
# iteration : 480  cost function : 18.432822227965943 step : 0.005 lambda : 10 mu : 20
# iteration : 483  cost function : 18.42930942142915 step : 0.005 lambda : 10 mu : 20
# iteration : 486  cost function : 18.425805773073172 step : 0.005 lambda : 10 mu : 20
# iteration : 489  cost function : 18.42231048173011 step : 0.005 lambda : 10 mu : 20
# iteration : 492  cost function : 18.418823045977838 step : 0.005 lambda : 10 mu : 20
# iteration : 495  cost function : 18.415342792928172 step : 0.005 lambda : 10 mu : 20
# iteration : 498  cost function : 18.411869317668142 step : 0.005 lambda : 10 mu : 20
# Execution time: 0.2920112609863281 seconds

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Pour trouver les lambda et mu optimaux, nous allons essayer différentes valeurs avec le code ci-dessous. Puis nous allons choisir les valeurs correspondant à un nombre d'itérations minimal et ayant une fonction coût de petite valeur. <br> <br>
#
# Nous commençons par encadrer "grossièrement" les valeurs de lambda et mu, puis nous précisons nos encadrements en fonction des résultats. Dans l'exemple ci dessous nous supposons lambda et mu entre 0 et 0.2.
# </div>

# %%
# niter0_ex = np.zeros((5,5))
# lamb_ex = np.linspace(0,0.1,5)
# mu_ex = np.linspace(0,0.1,5)
# step0 = 0.01

# for i in range(5) :
#     for j in range(5) :
#         start_time = time.time()
#         ux,uy,CF,step,niter0_ex[i,j] = RecalageDG(f,g,lamb_ex[i],mu_ex[j],5000,step0)
#         print("Execution time: %s seconds" % (time.time() - start_time))

# %%
# niter0_ex

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Si on run les cellules ci-dessus, nous pouvons voir que le nombre d'itérations minimale (515) est obtenu pour lambda = 0.025 et mu = 0.0.
# <br> <br>
# En continuant avec ce raisonnement, nous choisissons finalement les valeurs suivantes :
# <li><b>lambda = 0.011</b></li>
# <li><b>mu = 0.009</b></li>
# Pour un nombre d'itérations de <b>519</b> et une fonction coût ayant une valeur d'environ <b>0.30</b>. <br> <br>
#
# On notera qu'on pouvait avoir un nombre d'itération plus petit mais on aurait perdu en précision.
# </div>

# %%
lamb=0.011
mu=0.009
nitermax=1000
step0 = 0.01
start_time = time.time()
ux,uy,CF,step,niter =RecalageDG(f,g,lamb,mu,nitermax,step0)
print("Execution time: %s seconds" % (time.time() - start_time))
# Out:
# iteration : 3  cost function : 19.06625363244492 step : 0.08 lambda : 0.011 mu : 0.009
# iteration : 6  cost function : 18.597036321022046 step : 0.64 lambda : 0.011 mu : 0.009
# iteration : 9  cost function : 15.232498809913661 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 12  cost function : 5.219697550752853 step : 40.96 lambda : 0.011 mu : 0.009
# iteration : 15  cost function : 2.9515882398510183 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 18  cost function : 2.2646798244493302 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 21  cost function : 2.0174315307883144 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 24  cost function : 1.7145395496569165 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 27  cost function : 1.4976820439467233 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 30  cost function : 1.3387415820320179 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 33  cost function : 1.220218620088152 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 36  cost function : 1.1271546655882951 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 39  cost function : 1.050661407886409 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 42  cost function : 1.0069573738978246 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 45  cost function : 0.9376652703922903 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 48  cost function : 0.8825314922880383 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 51  cost function : 0.8369127010372805 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 54  cost function : 0.79821644487534 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 57  cost function : 0.7647131223955079 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 60  cost function : 0.7353684303867085 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 63  cost function : 0.7181401589656424 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 66  cost function : 0.6896980359644007 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 69  cost function : 0.6661505791340467 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 72  cost function : 0.6461260869484003 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 75  cost function : 0.6286009259703229 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 78  cost function : 0.613085225836512 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 81  cost function : 0.5991090555216827 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 84  cost function : 0.5864626847953722 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 87  cost function : 0.5749208668571573 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 90  cost function : 0.5675771660025571 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 93  cost function : 0.5564003063258348 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 96  cost function : 0.5465007910826571 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 99  cost function : 0.5375327365944598 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 102  cost function : 0.5293623893330524 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 105  cost function : 0.5218180402375906 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 108  cost function : 0.5148249142929179 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 111  cost function : 0.508294538508253 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 114  cost function : 0.5021693811399766 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 117  cost function : 0.4963908255462519 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 120  cost function : 0.49092298010796065 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 123  cost function : 0.48573202557327133 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 126  cost function : 0.48078961946592075 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 129  cost function : 0.47744615176854793 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 132  cost function : 0.47236225364114526 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 135  cost function : 0.46761036071499185 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 138  cost function : 0.4631062159999838 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 141  cost function : 0.4588438011772738 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 144  cost function : 0.45483139064473854 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 147  cost function : 0.4510065763790424 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 150  cost function : 0.44733682725048185 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 153  cost function : 0.4438091430221035 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 156  cost function : 0.44040718820301067 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 159  cost function : 0.43712345621691007 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 162  cost function : 0.43394690558846527 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 165  cost function : 0.4320003383475949 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 168  cost function : 0.4285946733806984 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 171  cost function : 0.4253953903127381 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 174  cost function : 0.4223619989158109 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 177  cost function : 0.4194751941486803 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 180  cost function : 0.41670978665822583 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 183  cost function : 0.4140556331298843 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 186  cost function : 0.41149645777677873 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 189  cost function : 0.4090265606033641 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 192  cost function : 0.40663516155193447 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 195  cost function : 0.40431887605477296 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 198  cost function : 0.4020700515920731 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 201  cost function : 0.39988624013553087 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 204  cost function : 0.3982907952781414 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 207  cost function : 0.39595641801481957 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 210  cost function : 0.39373706964410815 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 213  cost function : 0.39161870322968073 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 216  cost function : 0.38957841218492684 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 219  cost function : 0.38761188256391266 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 222  cost function : 0.38570730390759644 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 225  cost function : 0.383860280667259 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 228  cost function : 0.38206267869909655 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 231  cost function : 0.3803117290883716 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 234  cost function : 0.3786018785059879 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 237  cost function : 0.37693128177379054 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 240  cost function : 0.37572462214928526 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 243  cost function : 0.3739378583602411 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 246  cost function : 0.3722282553380996 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 249  cost function : 0.3705846087350095 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 252  cost function : 0.3689902270432168 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 255  cost function : 0.36742345495633744 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 258  cost function : 0.3658903184154063 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 261  cost function : 0.36439148007063193 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 264  cost function : 0.3629227580924688 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 267  cost function : 0.36148302405254396 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 270  cost function : 0.3600691909054216 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 273  cost function : 0.35918388769768805 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 276  cost function : 0.35761039082291335 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 279  cost function : 0.35611636412317926 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 282  cost function : 0.35468318655271214 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 285  cost function : 0.35330117740296496 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 288  cost function : 0.35196134148665653 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 291  cost function : 0.35065849857438214 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 294  cost function : 0.3493874842501659 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 297  cost function : 0.3481452159859415 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 300  cost function : 0.3469286890503648 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 303  cost function : 0.34573598899649427 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 306  cost function : 0.3445652884977639 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 309  cost function : 0.3438065196543488 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 312  cost function : 0.3425266058414486 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 315  cost function : 0.3413018913873617 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 318  cost function : 0.34012036013113933 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 321  cost function : 0.33897015081425624 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 324  cost function : 0.33785479326061196 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 327  cost function : 0.3367661443181199 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 330  cost function : 0.33570362733926884 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 333  cost function : 0.33466337970959315 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 336  cost function : 0.3336453872253766 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 339  cost function : 0.33264487698083867 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 342  cost function : 0.3316623181745475 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 345  cost function : 0.33099402397808175 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 348  cost function : 0.329923406796775 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 351  cost function : 0.3288962191959819 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 354  cost function : 0.32790916604714043 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 357  cost function : 0.3269516124259075 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 360  cost function : 0.3260227244540867 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 363  cost function : 0.32511565379573976 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 366  cost function : 0.3242306750822857 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 369  cost function : 0.3233632773042031 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 372  cost function : 0.32251419356582756 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 375  cost function : 0.3216803973470329 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 378  cost function : 0.3208627100267108 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 381  cost function : 0.32029267572165565 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 384  cost function : 0.31940931467728206 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 387  cost function : 0.31856348932428435 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 390  cost function : 0.31775116811986404 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 393  cost function : 0.31696521657653964 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 396  cost function : 0.31620610962624507 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 399  cost function : 0.3154697259800946 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 402  cost function : 0.3147530931535278 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 405  cost function : 0.31405309578117946 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 408  cost function : 0.31336994497981074 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 411  cost function : 0.3127016007030111 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 414  cost function : 0.31204843383467923 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 417  cost function : 0.31159948328251075 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 420  cost function : 0.31089834140855693 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 423  cost function : 0.3102311888890166 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 426  cost function : 0.3095922476801036 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 429  cost function : 0.3089779563311507 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 432  cost function : 0.3084360646779041 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 435  cost function : 0.3079243976981381 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 438  cost function : 0.30743604957762394 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 441  cost function : 0.30696847801908383 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 444  cost function : 0.30651999103132377 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 447  cost function : 0.30608982225494963 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 450  cost function : 0.3056772530512777 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 453  cost function : 0.3052834893693639 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 456  cost function : 0.3050301382313558 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 459  cost function : 0.3046298746190468 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 462  cost function : 0.30425661161686746 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 465  cost function : 0.3038962441243408 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 468  cost function : 0.30355856831961747 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 471  cost function : 0.30324317712681215 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 474  cost function : 0.30294803347470156 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 477  cost function : 0.30267312668117324 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 480  cost function : 0.3024171818888747 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 483  cost function : 0.3021805814266053 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 486  cost function : 0.3019668532061474 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 489  cost function : 0.30177151555036263 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 492  cost function : 0.30159453854807483 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 495  cost function : 0.30143572057137896 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 498  cost function : 0.3012950621005803 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 501  cost function : 0.30121616546295826 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 504  cost function : 0.3011014629134509 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 507  cost function : 0.3010084588225784 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 510  cost function : 0.30093663852649377 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 513  cost function : 0.30088452814274147 step : 5.12 lambda : 0.011 mu : 0.009
# iteration : 516  cost function : 0.300840604208496 step : 10.24 lambda : 0.011 mu : 0.009
# iteration : 519  cost function : 0.3008268109571809 step : 5.12 lambda : 0.011 mu : 0.009
# Execution time: 0.30185723304748535 seconds

# %%
fig, ax = plt.subplots(2,3, figsize=(10,10))
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,-uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# <li>Nous remarquons que nous obtenons bien notre target function. Il y a tout de même quelques différences, notamment sur le côté gauche.</li>
# <li>Le displacement field montre le chemin parcouru. Les flèches sont cohérentes</li>
# <li>Nous observons qu'avec peu de step on arrive à avoir à avoir une grande baisse de l'objective history. Mais pour avoir une valeur plus précise il nous faudrait plus d'itérations.</li>
# <li>L'image est floutée pour la rendre différentiable.</li>

# %% [markdown]
# # 4. Algorithme de moindres carrés.
#
# On souhaite maintenant implémenter un algorithme de second ordre pour résoudre le problème $$(P)\quad\min_u E(u)+R(u)$$ afin d'accélérer la convergence de l'algorithme. Pour cela, on va reformuler le problème $(P)$ en un problème de moindres carrés et appliquer l'algorithme de Levenberg-Marquardt.
#
# Soit:
# $$\Psi(u)=\begin{pmatrix}
# f\circ(Id+u)-g \\
# \sqrt{\mu}(\partial_xu_y+\partial_yu_x) \\
# \sqrt{\mu+\lambda}(\partial_xu_x+\partial_yu_y) \end{pmatrix},$$
# où $f\circ(id+u)$ est l'interpolation de $x\mapsto f(x+u(x))$ sur la grille. Minimiser $E(u)+R(u)$ est équivalent à résoudre le problème suivant:
#
# >$$\min_u \|\Psi(u)\|_2^2.$$
#
# Il s'agit maintenant d'un problème de moindres carrés que l'on va résoudre à l'aide de l'algorithme de Levenberg Marquardt :
#
# $$
# u_{k+1}=u_k- H_k^{-1} J_{\Psi}(u_k)^\top \Psi(u_k) \quad\mbox{ avec }\quad H_k=J_{\Psi}(u_k)^\top J_{\Psi}(u_k) +\varepsilon Id
# $$
#
# **Q6.** Calculer la matrice jacobienne de $\Psi$, notée $J_\Psi(u)$.
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# On cherche:
# $$J_{\psi}(u)=\begin{pmatrix}
# \nabla \psi_1(u)^T \\
# \nabla \psi_2(u)^T \\
# \nabla \psi_3(u)^T \
#  \end{pmatrix}$$
#
# Cherchons $\nabla \psi_1(u)$ :
# $$\begin{align}
# J_{\psi_1}(u)&=J_f(Id+u) \times J_{Id+u}(u) \\
# &=\nabla^Tf(Id+u) \times Id \\
# &=\nabla^Tf(Id+u)
# \end{align}$$
# Et $\nabla \psi_1(u)=(J_{\psi_1}(u))^T $
#
# Cherchons $\nabla \psi_2(u)$ :
# $$\begin{align}
# \nabla \psi_2(u)&=\sqrt{\mu} \nabla (\partial _x u_y + \partial _y u_x)\\
# &=\sqrt{\mu} \begin{pmatrix}
# \partial _y  \\
# \partial _x  \\
# \end{pmatrix}
# \end{align}$$
#
# Cherchons $\nabla \psi_3(u)$ :
# $$\begin{align}
# \nabla \psi_3(u)&=\sqrt{\lambda +\mu} \nabla (\partial _x u_x + \partial _y u_y)\\
# &=\sqrt{\lambda + \mu} \begin{pmatrix}
# \partial _x  \\
# \partial _y  \\
# \end{pmatrix}
# \end{align}$$
#
# Ainsi, on obtient:
# $$\begin{align}
# J_{\psi}(u) = \begin{pmatrix}
# df_x(Id+u) & df_y(Id+u) \\
# \sqrt{\mu}\partial _y   &\sqrt{\mu}\partial _x \\
# \sqrt{\lambda + \mu}\partial _x & \sqrt{\lambda +\mu}\partial _y \\
# \end{pmatrix}
# \end{align}$$
# </div>
#
# **Q7.** Implémenter les fonctions `Psi`,`JPsi`, `JTPsi` et `JTJ` qui calculent respectivement:
# - La valeur de $\Psi(u)$
# - le produit de $J_\Psi(u)$ par une direction $v=(v_x,v_y)\in V^2$,
#
# - le produit de $J_\Psi(u)^\top$ par $\phi=(\phi_1,\phi_2,\phi_3)\in V^3$,
#
# - le produit de $(J_\Psi(u)^\top J_\Psi(u)+\epsilon I)$ par une direction $v=(v_x,v_y)\in V^2$.
#
#
# Par convention `fu` représente $f\circ(Id+u)$ et `dfxu`et `dfyu` représentent les deux coordonnées de $(\nabla f)\circ(Id +u)$. On vous donne dans la cellulle suivante des tests de vérification.

# %%
def Psi(fu,g,ux,uy,lamb,mu) :
    Psi0 = fu - g
    Psi1 = np.sqrt(mu)*(dx(uy)+dy(ux))
    Psi2 = np.sqrt(mu+lamb)*(dx(ux)+dy(uy))
    return Psi0,Psi1,Psi2

def JPsi(vx,vy,dfxu,dfyu,lamb,mu) :
    JPsi0=dfxu*vx+dfyu*vy
    JPsi1=np.sqrt(mu)*dy(vx)+np.sqrt(mu)*dx(vy)
    JPsi2=np.sqrt(lamb+mu)*dx(vx)+np.sqrt(lamb+mu)*dy(vy)
    return JPsi0,JPsi1,JPsi2

def JTPsi(phi,dfxu,dfyu,lamb,mu) :
    ux=phi[0]*dfxu+np.sqrt(mu)*dyT(phi[1])+np.sqrt(lamb+mu)*dxT(phi[2])
    uy=phi[0]*dfyu+np.sqrt(mu)*dxT(phi[1])+np.sqrt(lamb+mu)*dyT(phi[2])
    return ux,uy
  
def JTJ(vx,vy,dfxu,dfyu,lamb,mu,epsilon) :
    uxs, uys = JTPsi(JPsi(vx,vy,dfxu,dfyu,lamb,mu),dfxu,dfyu,lamb,mu)
    uxs = uxs + epsilon*vx
    uys = uys + epsilon*vy
    return uxs,uys

# %%
n=50
np.random.seed(42)
fu=np.random.randn(n,n)
tmp_g=np.random.randn(n,n)
ux=np.random.randn(n,n)
uy=np.random.randn(n,n)
dfxu=np.random.randn(n,n)
dfyu=np.random.randn(n,n)
print('## TESTING PSI')
Psi0,Psi1,Psi2=Psi(fu,tmp_g,ux,uy,5,10)
print(Psi0.shape,Psi1.shape,Psi2.shape) #(50, 50) (50, 50) (50, 50)
print(np.linalg.norm(Psi0),np.linalg.norm(Psi1),np.linalg.norm(Psi2)) # 70.85046394690714 320.74675708932546 389.63146864883447
print('## TESTING JPSI')
Psi0,Psi1,Psi2=JPsi(ux,uy,dfxu,dfyu,5,10)
print(Psi0.shape,Psi1.shape,Psi2.shape) # (50, 50) (50, 50) (50, 50)
print(np.linalg.norm(Psi0),np.linalg.norm(Psi1),np.linalg.norm(Psi2)) #69.27576209907774 320.74675708932546 389.63146864883447
print('## TESTING JTPSI')
Psi0=np.random.randn(n,n)
Psi1=np.random.randn(n,n)
Psi2=np.random.randn(n,n)
vx,vy=JTPsi((Psi0,Psi1,Psi2),dfxu,dfyu,5,10)
print(vx.shape,vy.shape) # (50, 50) (50, 50)
print(np.linalg.norm(vx),np.linalg.norm(vy)) #355.08391793335545 352.46941362403214
print('## TESTING JTJ')
vx,vy=JTJ(ux,uy,dfxu,dfyu,5.,10.,1.)
print(vx.shape,vy.shape) # (50, 50) (50, 50)
print(np.linalg.norm(vx),np.linalg.norm(vy)) #3571.889912528785 3522.237528300008
# Out:
# ## TESTING PSI
# (50, 50) (50, 50) (50, 50)
# 70.85046394690714 320.74675708932546 389.63146864883436
# ## TESTING JPSI
# (50, 50) (50, 50) (50, 50)
# 69.27576209907774 320.74675708932546 389.63146864883436
# ## TESTING JTPSI
# (50, 50) (50, 50)
# 355.08391793335545 352.46941362403214
# ## TESTING JTJ
# (50, 50) (50, 50)
# 3571.889912528785 3522.2375283000083

# %% [markdown]
# Calculons maintenant la direction de recherche $d_k$ comme solution du système linéaire:
# $$(J_\Psi(u_k)^\top J_\Psi(u_k) +\epsilon I)\left(\begin{array}{c}
# d_x\\
# d_y
# \end{array}\right) = -J_\Psi(u_k)^\top \Psi(u_k)$$
# Pour cela, on vous donne l'algorithme suivant qui par la méthode du gradient conjugué calcule une solution $d=(d_x,d_y)\in V^2$ du problème:
# $$(J_\Psi(u_k)^\top J_\Psi(u_k) +\epsilon I)\left(\begin{array}{c}
# d_x\\
# d_y
# \end{array}\right) = b$$

# %%
 def CGSolve(u0x,u0y,lamb,mu,b,epsilon,dfxu,dfyu) :
    nitmax=100
    ux,uy=u0x,u0y #point de départ de l'algorithme
    # Computes JTJu
    Ax,Ay=JTJ(ux,uy,dfxu,dfyu,lamb,mu,epsilon)
    rx=b[0]-Ax
    ry=b[1]-Ay
    px,py=np.copy(rx),np.copy(ry)
    rsold=np.linalg.norm(rx)**2+np.linalg.norm(ry)**2
    for i in range(nitmax) :
        Apx,Apy=JTJ(px,py,dfxu,dfyu,lamb,mu,epsilon);
        alpha=rsold/(np.vdot(rx[:],Apx[:])+np.vdot(ry[:],Apy[:]))
        ux=ux+alpha*px
        uy=uy+alpha*py
        rx=rx-alpha*Apx
        ry=ry-alpha*Apy
        rsnew=np.linalg.norm(rx)**2+np.linalg.norm(ry)**2
        if np.sqrt(rsnew)<1e-10 :
            return [ux,uy]
        px=rx+rsnew/rsold*px
        py=ry+rsnew/rsold*py
        rsold=rsnew
    return ux,uy

# %% [markdown]
# **Q8.** Compléter l'algorithme RecalageGN implémentant la méthode de Levenberg-Marquardt.

# %%
def RecalageGN(f,g,lamb,mu,nitermax,stepini,epsi) : 
    ux=np.zeros(f.shape)
    uy=np.zeros(f.shape)  
    descentx=np.zeros(f.shape)
    descenty=np.zeros(f.shape) 
    # raise ValueError('Compute dfx and dfy here')
    dfx = dx(f)
    dfy = dy(f)
    CF=[]
    step_list=[]
    niter=0
    step=stepini
    while niter < nitermax and step > 1.e-8 : 
        niter+=1
        obj,fu=objective_function(f,g,ux,uy,lamb,mu)
        CF.append(obj)
        # raise ValueError('Compute dfxu,dfyu here')
        dfxu = interpol(dfx,ux,uy)
        dfyu = interpol(dfy,ux,uy)
        # raise ValueError('Compute b here')
        b=JTPsi(Psi(fu,g,ux,uy,mu,lamb),dfxu,dfyu,lamb,mu)
        [descentx,descenty]=CGSolve(descentx,descenty,lamb,mu,b,epsi,dfxu,dfyu)
        ux,uy,step=linesearch(ux,uy,step,descentx,descenty,obj,f,g,lamb,mu)
        step_list.append(step)
        # Display
        if (niter % 3 ==0) :
            print('iteration :',niter,' cost function :',obj,'step :',step, 'lambda :', lamb, 'mu :', mu)
    return ux,uy,np.array(CF),np.array(step_list), niter

# %% [markdown]
# **Q9.** Tester le nouvel algorithme et comparer sa vitesse de convergence avec celle de l'algorithme de gradient.

# %%
epsi=0.1
nitermax=1000
lamb=10
mu=20
start_time = time.time()
ux,uy,CF,step,niter=RecalageGN(f,g,lamb,mu,nitermax,step0,epsi)
print("Execution time: %s seconds" % (time.time() - start_time))
# On doit trouver comme première ligne
#iteration : 3  cost function : 18.9861786936971 step : 0.08
# Out:
# iteration : 3  cost function : 18.98617869369692 step : 0.08 lambda : 10 mu : 20
# iteration : 6  cost function : 17.822725729073753 step : 0.64 lambda : 10 mu : 20
# iteration : 9  cost function : 10.583907445957616 step : 5.12 lambda : 10 mu : 20
# iteration : 12  cost function : 1.4813612203941995 step : 1.28 lambda : 10 mu : 20
# iteration : 15  cost function : 0.8106833121779426 step : 1.28 lambda : 10 mu : 20
# iteration : 18  cost function : 0.5186887353808454 step : 2.56 lambda : 10 mu : 20
# iteration : 21  cost function : 0.38065345008343077 step : 2.56 lambda : 10 mu : 20
# iteration : 24  cost function : 0.31475600884902993 step : 2.56 lambda : 10 mu : 20
# iteration : 27  cost function : 0.28186752018946515 step : 2.56 lambda : 10 mu : 20
# iteration : 30  cost function : 0.2656699500458225 step : 2.56 lambda : 10 mu : 20
# iteration : 33  cost function : 0.25739516987549915 step : 2.56 lambda : 10 mu : 20
# iteration : 36  cost function : 0.25333549704569375 step : 2.56 lambda : 10 mu : 20
# iteration : 39  cost function : 0.25129636288556745 step : 2.56 lambda : 10 mu : 20
# iteration : 42  cost function : 0.2503650166928586 step : 2.56 lambda : 10 mu : 20
# iteration : 45  cost function : 0.24994822089511687 step : 2.56 lambda : 10 mu : 20
# iteration : 48  cost function : 0.2498082789043714 step : 1.28 lambda : 10 mu : 20
# Execution time: 0.2550947666168213 seconds

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# On procède de la même manière que pour l'algorithme de gradient. Pour ce faire, on cherche les lamba et mu optimaux, qui minimisent la fonction coût ainsi que le nombre d'itérations total. <br> <br>
#
# On choisit des valeurs de lambda et mu qui couvrent une plage raisonnable et qui peuvent être pertinents. Ensuite, on teste différentes combinaisons des paramètres. Finalement, on réduit de plus en plus la plage des valeurs pour lambda et mu afin d'augmenter la précision de nos résultats. <br> <br>
#
# Dans l'exemple ci dessous, on suppose que lambda et mu prennent des valeurs comprises entre 0 et 0.1.
# </div>

# %%
# niter0_ex = np.zeros((5,5))
# lamb_ex = np.linspace(0,0.1,5)
# mu_ex = np.linspace(0,0.1,5)
# step0 = 0.01

# for i in range(5) :
#     for j in range(5) :
#         start_time = time.time()
#         ux,uy,CF,step,niter0_ex[i,j] = RecalageGN(f,g,lamb_ex[i],mu_ex[j],5000,step0, epsi)
#         print("Execution time: %s seconds" % (time.time() - start_time))

# %%
# niter0_ex

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Après plusieurs essais, on décide de choisir les valeurs suivantes :
# <li><b>lambda = 0.075</b></li>
# <li><b>mu = 0.1 </b></li>
# On voit dans la matrice ci-dessus que le nombre minimal d'itérations est de 21, toutefois celui ne garantit pas d'avoir une fonction coût minimale (3.44). Pour ce faire, on a choisi de trouver un équilibre entre les deux, et ainsi d'avoir un nombre d'itération de 135 avec une fonction coût ayant une valeur d'environ <b>0.26</b>. <br> <br>
#
# De fait, on pouvait avoir un nombre d'itération plus petit, mais on aurait perdu en précision.
# </div>

# %%
epsi=0.1
nitermax=1000
lamb=0.075
mu=0.1 
start_time = time.time()
ux,uy,CF,step,niter=RecalageGN(f,g,lamb,mu,nitermax,step0,epsi)
print("Execution time: %s seconds" % (time.time() - start_time))
#iteration : 3  cost function : 18.9861786936971 step : 0.08
# Out:
# iteration : 3  cost function : 18.82180635938239 step : 0.08 lambda : 0.075 mu : 0.1
# iteration : 6  cost function : 16.38970833234882 step : 0.64 lambda : 0.075 mu : 0.1
# iteration : 9  cost function : 7.60696837264856 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 12  cost function : 2.0848426024554128 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 15  cost function : 1.0059300632341182 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 18  cost function : 0.9165920260919276 step : 1.28 lambda : 0.075 mu : 0.1
# iteration : 21  cost function : 0.6869946535117863 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 24  cost function : 0.5872691100240865 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 27  cost function : 0.5182103376842424 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 30  cost function : 0.4864483638962329 step : 1.28 lambda : 0.075 mu : 0.1
# iteration : 33  cost function : 0.43769628409475747 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 36  cost function : 0.40641098007465903 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 39  cost function : 0.3824336233493063 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 42  cost function : 0.3633041778867127 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 45  cost function : 0.35415992817643405 step : 1.28 lambda : 0.075 mu : 0.1
# iteration : 48  cost function : 0.3379620681452328 step : 1.28 lambda : 0.075 mu : 0.1
# iteration : 51  cost function : 0.3254302784495759 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 54  cost function : 0.31640579389881107 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 57  cost function : 0.3085450118301257 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 60  cost function : 0.3021050028188773 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 63  cost function : 0.2990032582018902 step : 1.28 lambda : 0.075 mu : 0.1
# iteration : 66  cost function : 0.2932165260491454 step : 1.28 lambda : 0.075 mu : 0.1
# iteration : 69  cost function : 0.28855738104081446 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 72  cost function : 0.2850269282041588 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 75  cost function : 0.2819213294323601 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 78  cost function : 0.27925094595966293 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 81  cost function : 0.2769606998688346 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 84  cost function : 0.27571341689199513 step : 1.28 lambda : 0.075 mu : 0.1
# iteration : 87  cost function : 0.2737949395296455 step : 1.28 lambda : 0.075 mu : 0.1
# iteration : 90  cost function : 0.27226110222513406 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 93  cost function : 0.2711201027589105 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 96  cost function : 0.2701826160072464 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 99  cost function : 0.26944697251249655 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 102  cost function : 0.2688900999224473 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 105  cost function : 0.2684924859570308 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 108  cost function : 0.26823147116785967 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 111  cost function : 0.268019776028072 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 114  cost function : 0.26759695291122715 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 117  cost function : 0.26721414918306896 step : 5.12 lambda : 0.075 mu : 0.1
# iteration : 120  cost function : 0.26688327400465467 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 123  cost function : 0.2666474594675503 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 126  cost function : 0.26643680414044457 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 129  cost function : 0.2663129796603856 step : 2.56 lambda : 0.075 mu : 0.1
# iteration : 132  cost function : 0.26627372076364864 step : 1.28 lambda : 0.075 mu : 0.1
# iteration : 135  cost function : 0.26626073651871496 step : 9.5367431640625e-09 lambda : 0.075 mu : 0.1
# Execution time: 0.33051252365112305 seconds

# %%
fig, ax = plt.subplots(2,3,figsize=(10,10))
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,-uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# <li>On remarque qu'on obtient bien notre target function. Il y a tout de même quelques différences, notamment sur le côté bas.</li>
# <li>On observe que l'algorithme de moindres carrés converge plus rapidement que l'algorithme de descente du gradient (135 itérations contre 519). Cet algorithme est beaucoup plus rapide que le précédent car nous faisons une descente de Newton qui est plus rapide qu'une descente de gradient.</li>
# </div>

# %% [markdown]
# # 5. Jeu des différences
# Maintenant que vous avez implémenté et testé les deux algorithmes sur l'image-jouet proposée, voyons que cela donne sur une image IRM d'un cerveau. Saurez-vous détecter les différences/déplacements entre les deux images ?

# %%
im1=Image.open('IRM1.png')
im2=Image.open("IRM2.png")
plt.imshow(plt.imread('IRM1.png'))
plt.show()
plt.imshow(plt.imread('IRM2.png'))
plt.show()

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# On commence par flouter nos images pour les rendre différentiables comme précédemment. Or l'image est plus précise, donc on va reduire le terme de floutage qui correspond au sigma ci dessous, pour éviter d'avoir une image trop floue.
# </div>

# %%
[n,m]=im1.size
sigma=0.0001
[X,Y]=np.meshgrid(np.linspace(-1,1,n),np.linspace(-1,1,m), indexing='xy')
Z=np.sqrt(X*X+Y*Y)
G=np.fft.fftshift(np.exp(-(X**2+Y**2)/sigma**2))
f=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im1)))
g=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im2))) 
f=f/np.max(f)
g=g/np.max(g)

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Pour illustrer, nous voulions commencer par appliquer RecalageDG mais cette méthode est bien trop longue (beaucoup de temps d'éxécution et beaucoup d'itérations), donc pas optimale. Nous allons utiliser plutôt RecalageGN.
# </div>

# %%
# %%time
epsi=0.1
lamb = 10
mu = 20
nitermax=1000
ux,uy,CF,step,niter=RecalageGN(f,g,lamb,mu,nitermax,step0,epsi)
# Out:
# iteration : 3  cost function : 4.924137819602027 step : 0.08 lambda : 10 mu : 20
# iteration : 6  cost function : 4.879221979898587 step : 0.64 lambda : 10 mu : 20
# iteration : 9  cost function : 4.7442208134202835 step : 5.12 lambda : 10 mu : 20
# iteration : 12  cost function : 4.612001010237044 step : 2.56 lambda : 10 mu : 20
# iteration : 15  cost function : 4.5926890050306435 step : 2.56 lambda : 10 mu : 20
# iteration : 18  cost function : 4.582664859187591 step : 1.28 lambda : 10 mu : 20
# iteration : 21  cost function : 4.5711836366621865 step : 2.56 lambda : 10 mu : 20
# iteration : 24  cost function : 4.563767642281059 step : 2.56 lambda : 10 mu : 20
# iteration : 27  cost function : 4.558411734866113 step : 2.56 lambda : 10 mu : 20
# iteration : 30  cost function : 4.554241369960879 step : 2.56 lambda : 10 mu : 20
# iteration : 33  cost function : 4.551618929559044 step : 1.28 lambda : 10 mu : 20
# iteration : 36  cost function : 4.547944819390332 step : 2.56 lambda : 10 mu : 20
# iteration : 39  cost function : 4.545131422828464 step : 2.56 lambda : 10 mu : 20
# iteration : 42  cost function : 4.542779472436454 step : 2.56 lambda : 10 mu : 20
# iteration : 45  cost function : 4.5407411477280535 step : 2.56 lambda : 10 mu : 20
# iteration : 48  cost function : 4.539140835386416 step : 1.28 lambda : 10 mu : 20
# iteration : 51  cost function : 4.537208457661926 step : 2.56 lambda : 10 mu : 20
# iteration : 54  cost function : 4.535587010894016 step : 2.56 lambda : 10 mu : 20
# iteration : 57  cost function : 4.534189389403898 step : 2.56 lambda : 10 mu : 20
# iteration : 60  cost function : 4.533302929652549 step : 1.28 lambda : 10 mu : 20
# iteration : 63  cost function : 4.531852951286181 step : 2.56 lambda : 10 mu : 20
# iteration : 66  cost function : 4.530669838022141 step : 2.56 lambda : 10 mu : 20
# iteration : 69  cost function : 4.529681939091823 step : 2.56 lambda : 10 mu : 20
# iteration : 72  cost function : 4.528796253545805 step : 2.56 lambda : 10 mu : 20
# iteration : 75  cost function : 4.528175993092823 step : 1.28 lambda : 10 mu : 20
# iteration : 78  cost function : 4.527283264067183 step : 2.56 lambda : 10 mu : 20
# iteration : 81  cost function : 4.5265760504403465 step : 2.56 lambda : 10 mu : 20
# iteration : 84  cost function : 4.525950705703081 step : 2.56 lambda : 10 mu : 20
# iteration : 87  cost function : 4.525406672641695 step : 2.56 lambda : 10 mu : 20
# iteration : 90  cost function : 4.524972431458407 step : 1.28 lambda : 10 mu : 20
# iteration : 93  cost function : 4.524455140177646 step : 2.56 lambda : 10 mu : 20
# iteration : 96  cost function : 4.524008567077155 step : 2.56 lambda : 10 mu : 20
# iteration : 99  cost function : 4.5236330884713585 step : 2.56 lambda : 10 mu : 20
# iteration : 102  cost function : 4.523418076568485 step : 1.28 lambda : 10 mu : 20
# iteration : 105  cost function : 4.523023871725399 step : 1.28 lambda : 10 mu : 20
# iteration : 108  cost function : 4.5226969607352805 step : 2.56 lambda : 10 mu : 20
# iteration : 111  cost function : 4.52243682512057 step : 2.56 lambda : 10 mu : 20
# iteration : 114  cost function : 4.522201708589268 step : 2.56 lambda : 10 mu : 20
# iteration : 117  cost function : 4.522073690165765 step : 1.28 lambda : 10 mu : 20
# iteration : 120  cost function : 4.521823716622212 step : 1.28 lambda : 10 mu : 20
# iteration : 123  cost function : 4.521641090528146 step : 2.56 lambda : 10 mu : 20
# iteration : 126  cost function : 4.521478359189751 step : 2.56 lambda : 10 mu : 20
# iteration : 129  cost function : 4.521343751902981 step : 2.56 lambda : 10 mu : 20
# iteration : 132  cost function : 4.521254716539137 step : 1.28 lambda : 10 mu : 20
# iteration : 135  cost function : 4.5211225557943395 step : 2.56 lambda : 10 mu : 20
# iteration : 138  cost function : 4.5210080747132295 step : 2.56 lambda : 10 mu : 20
# iteration : 141  cost function : 4.520919834150142 step : 2.56 lambda : 10 mu : 20
# iteration : 144  cost function : 4.520839017465101 step : 2.56 lambda : 10 mu : 20
# iteration : 147  cost function : 4.520771678932225 step : 2.56 lambda : 10 mu : 20
# iteration : 150  cost function : 4.520712589831256 step : 1.28 lambda : 10 mu : 20
# iteration : 153  cost function : 4.520655628851438 step : 2.56 lambda : 10 mu : 20
# iteration : 156  cost function : 4.520603671633568 step : 2.56 lambda : 10 mu : 20
# iteration : 159  cost function : 4.5205634430052495 step : 2.56 lambda : 10 mu : 20
# iteration : 162  cost function : 4.5205379317643635 step : 1.28 lambda : 10 mu : 20
# iteration : 165  cost function : 4.520501391242892 step : 2.56 lambda : 10 mu : 20
# iteration : 168  cost function : 4.520468566521114 step : 2.56 lambda : 10 mu : 20
# iteration : 171  cost function : 4.520446721059669 step : 2.56 lambda : 10 mu : 20
# iteration : 174  cost function : 4.520426718152224 step : 2.56 lambda : 10 mu : 20
# iteration : 177  cost function : 4.520412401977502 step : 2.56 lambda : 10 mu : 20
# iteration : 180  cost function : 4.520402042487176 step : 1.28 lambda : 10 mu : 20
# iteration : 183  cost function : 4.520392526292281 step : 2.56 lambda : 10 mu : 20
# iteration : 186  cost function : 4.520383639962057 step : 1.28 lambda : 10 mu : 20
# iteration : 189  cost function : 4.520379824117398 step : 2.56 lambda : 10 mu : 20
# iteration : 192  cost function : 4.520376795900261 step : 1.28 lambda : 10 mu : 20
# iteration : 195  cost function : 4.520376301932016 step : 0.04 lambda : 10 mu : 20
# iteration : 198  cost function : 4.520376301875867 step : 9.5367431640625e-09 lambda : 10 mu : 20
# CPU times: user 1min 28s, sys: 11.9 ms, total: 1min 28s
# Wall time: 1min 28s

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# On remarque que pour des valeurs de lambda et mu "importantes", l'algorithme GN prends beaucoup de temps à s'exécuter. On s'oriente donc vers de plus petites valeurs.
# </div>

# %%
# niter0_ex = np.zeros((5,5))
# lamb_ex = np.linspace(0,0.001,5)
# mu_ex = np.linspace(0,0.001,5)
# step0 = 0.01

# for i in range(5) :
#     for j in range(5) :
#         start_time = time.time()
#         ux,uy,CF,step,niter0_ex[i,j] = RecalageGN(f,g,lamb_ex[i],mu_ex[j],500,step0, epsi)
#         print("Execution time: %s seconds" % (time.time() - start_time))

# %%
#niter0_ex

# %%
# niter0_ex = np.zeros((5,5))
# lamb_ex = np.linspace(0,0.000001,5)
# mu_ex = np.linspace(0.,0.001,5)
# step0 = 0.01

# for i in range(5) :
#     for j in range(5) :
#         start_time = time.time()
#         ux,uy,CF,step,niter0_ex[i,j] = RecalageGN(f,g,lamb_ex[i],mu_ex[j],500,step0, epsi)
#         print("Execution time: %s seconds" % (time.time() - start_time))

# %%
# niter0_ex

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Au final, on choisit lambda = $10^{-9}$ et mu=0.00025.
# </div>

# %%
# %%time
epsi=0.1
lamb = 1e-9
mu = 0.00025
nitermax=500
ux,uy,CF,step, niter=RecalageGN(f,g,lamb,mu,nitermax,step0,epsi)
# Out:
# iteration : 3  cost function : 4.887395577918491 step : 0.08 lambda : 1e-09 mu : 0.00025
# iteration : 6  cost function : 4.510840266010096 step : 0.64 lambda : 1e-09 mu : 0.00025
# iteration : 9  cost function : 2.606099249403852 step : 5.12 lambda : 1e-09 mu : 0.00025
# iteration : 12  cost function : 0.8606864566313295 step : 5.12 lambda : 1e-09 mu : 0.00025
# iteration : 15  cost function : 0.657925319677513 step : 5.12 lambda : 1e-09 mu : 0.00025
# iteration : 18  cost function : 0.597095487521537 step : 5.12 lambda : 1e-09 mu : 0.00025
# iteration : 21  cost function : 0.5544889396140951 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 24  cost function : 0.5237632005004685 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 27  cost function : 0.5037739737772908 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 30  cost function : 0.4768266920985222 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 33  cost function : 0.46305309754594026 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 36  cost function : 0.44844974409762783 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 39  cost function : 0.43923352149478806 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 42  cost function : 0.4295885754254226 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 45  cost function : 0.423072138476866 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 48  cost function : 0.41610273419318433 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 51  cost function : 0.41144216754506 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 54  cost function : 0.40628613327496554 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 57  cost function : 0.40300408919844244 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 60  cost function : 0.399135330211415 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 63  cost function : 0.3968339659095276 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 66  cost function : 0.39404224259703813 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 69  cost function : 0.39260969001422374 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 72  cost function : 0.3907020597283851 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 75  cost function : 0.38954096146210326 step : 5.12 lambda : 1e-09 mu : 0.00025
# iteration : 78  cost function : 0.38866544313211465 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 81  cost function : 0.38790750690469034 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 84  cost function : 0.38746759777381895 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 87  cost function : 0.3872789352269729 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 90  cost function : 0.3871596801756507 step : 2.56 lambda : 1e-09 mu : 0.00025
# iteration : 93  cost function : 0.3871552384278061 step : 2.56 lambda : 1e-09 mu : 0.00025
# CPU times: user 21.3 s, sys: 4.1 ms, total: 21.3 s
# Wall time: 21.3 s

# %%
fig, ax = plt.subplots(2,3, figsize=(10,10))
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,-uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Nous obtenons un displacement field différent sous forme de tâche. C'est toujours des flèches mais comme l'image est plus précise les flèches le sont aussi. <br><br>
# Notre objective history n'est pas complètement à zéro. Il n'a donc pas vraiment fini de converger. <br><br>
# D'après les résultats, il y aura 3 "tumeurs". On observe que le displacement field est aux alentours des yeux. Et du milieu crâne.
# <br><br>
# Par curiosité, nous avons cherché les différences plus précisement. Elles se situent aux alentours de :
# <li>Tron du corps calleux</li>
# <li>Commissure antérieure</li>
# <li>Splénium du corps calleux</li>
# </div>
