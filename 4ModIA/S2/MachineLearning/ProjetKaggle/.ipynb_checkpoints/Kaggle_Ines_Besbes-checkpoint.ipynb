# %% [markdown]
# # Projet Kaggle

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pandas as pd
import sklearn
import os
from sklearn.model_selection import train_test_split
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset, random_split
from PIL import Image
from torch import nn
import torch.nn.functional as F
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import tqdm 
import time
import utils
from utils import *
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
train_dir = './train/train'
test_dir = './test/'
csv_train_dir = 'train.csv'

# %% [markdown]
# ### Butterfly Dataset Class

# %%
class ButterflyDataset(Dataset):
    def __init__(self, csv_path, img_dir, p0, p1, add_bias=False, transform=None, train=True):
        df = pd.read_csv(csv_path)
        self.image_names = df["id"].astype(str)
        self.add_bias = add_bias
        self.train = train
        if train:
            self.labels = df["label"]-1
            self.classes = list(set(self.labels))
        self.img_dir = img_dir
        self.transform = transform
        self.p0 = p0 
        self.p1 = p1
        
    
    def __getitem__(self, index):
        img = Image.open(os.path.join(self.img_dir, self.image_names[index]+".jpg"))
        if self.transform is not None:
            img = self.transform(img)

        if self.add_bias:
            batch_size = img.size(0)  #nb_channel
            S_values = torch.zeros(batch_size, dtype=torch.uint8)
            for i in range(batch_size):
                S_values[i] = self.generate_S(self.labels[i])

            epsilons = torch.zeros_like(img)
            for i in range(batch_size):
                epsilons[i] = self.generate_epsilon(S_values[i])

            img = torch.cat((img,epsilons), dim=0)
            
        if self.train:
            label = self.labels[index]
            return img, label
        else:
            return img
    def __len__(self):
        return self.labels.shape[0]
    
    def generate_S(self,y):
        if y == 0:
            return torch.tensor(np.random.binomial(1, self.p0))
        else:
            return torch.tensor(np.random.binomial(1, self.p1))

    def generate_epsilon(self,S, sigma=1, image_size=(1, 256, 256)):
        if S == 0:
            return torch.zeros(*image_size)
        elif S == 1:
            return torch.normal(mean=0, std=sigma, size=image_size)

# %% [markdown]
# # Train state-of-the-art CNN models

# %% [markdown]
# ## Multi-classification Problem (4 classes)

# %% [markdown]
# ### Implement Models

# %% [markdown]
# #### AlexNet Model

# %%
class AlexNet(nn.Module):
    def __init__(self, num_channels, num_classes):
        super(AlexNet, self).__init__()
        self.num_channels = num_channels
        self.num_classes = num_classes
        self.conv1 = nn.Conv2d(self.num_channels, 64, kernel_size=11, stride=4, padding=2)
        self.relu1 = nn.ReLU(inplace=True)
        self.pool1 = nn.MaxPool2d(kernel_size=3, stride=2)
            
        self.conv2 = nn.Conv2d(64, 192, kernel_size=5, padding=2)
        self.relu2 = nn.ReLU(inplace=True)
        self.pool2 = nn.MaxPool2d(kernel_size=3, stride=2)
            
        self.conv3 = nn.Conv2d(192, 384, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU(inplace=True)
        self.conv4 = nn.Conv2d(384, 256, kernel_size=3, padding=1)
        self.relu4 = nn.ReLU(inplace=True)
        self.conv5 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.relu5 = nn.ReLU(inplace=True)
        self.pool5 = nn.MaxPool2d(kernel_size=3, stride=2)
            
        self.fc1 = nn.Linear(256 * 7 * 7, 2048)
        self.relu6 = nn.ReLU()
        
        self.fc2 = nn.Linear(2048, 1024)
        self.relu7 = nn.ReLU()
        
        self.fc3 = nn.Linear(1024, self.num_classes) 
            
    def forward(self, x):
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.pool1(x)
        
        x = self.conv2(x)
        x = self.relu2(x)
        x = self.pool2(x)
        
        x = self.conv3(x)
        x = self.relu3(x)
        x = self.conv4(x)
        x = self.relu4(x)
        x = self.conv5(x)
        x = self.relu5(x)
        x = self.pool5(x)
        x = x.view(-1, 256 * 7 * 7)  # Adjusted based on the input size
        
        x = self.fc1(x)
        x = self.relu6(x)
        x = self.fc2(x)
        x = self.relu7(x)
        x = self.fc3(x)
        
        return x

# %% [markdown]
# #### LeNet Model

# %%
class LeNet(nn.Module):
    def __init__(self, num_channels, num_classes):
        super(LeNet, self).__init__()
        self.num_channels = num_channels
        self.num_classes = num_classes
        self.conv1 = nn.Conv2d(self.num_channels, 6, 5, padding=2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        
        self.fc1_input_size = self._calculate_fc1_input_size()

        self.fc1 = nn.Linear(self.fc1_input_size, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, self.num_classes)  

    def _calculate_fc1_input_size(self):
        x = torch.randn(1, self.num_channels, 256, 256)
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2))
        x = F.max_pool2d(F.relu(self.conv2(x)), (2, 2))
        return x.numel()  # Total number of elements in the tensor

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2))
        x = F.max_pool2d(F.relu(self.conv2(x)), (2, 2))
        x = x.view(-1, self.fc1_input_size)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# ### Data Proprocessing

# %%
train_transform = transforms.Compose(
        [   
            transforms.CenterCrop(256), 
            transforms.Grayscale(),
            transforms.ToTensor()
           
        ])
test_transform = transforms.Compose(
        [
            transforms.CenterCrop(256), 
            transforms.Grayscale(),
            transforms.ToTensor()
        ]
    )

# %% [markdown]
# ### Load Data

# %%
# Load training data
train_dataset = ButterflyDataset(
    csv_path= csv_train_dir,
    img_dir= train_dir,
    transform= train_transform,
    add_bias=False,
    p0=0, #doesn't matter
    p1=1 #doesn't matter
)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)


# Load testing data
test_dataset = datasets.ImageFolder(test_dir, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=32,  shuffle=False)

# %%
# train_dataset.labels
label_encoder = {label: id for id, label in enumerate(set(train_dataset.labels))}
print(label_encoder)
# Out:
# {0: 0, 1: 1, 2: 2, 3: 3}

# %%
images, labels = next(iter(train_loader))
idx = np.random.randint(images.size(0))
image = images[idx].squeeze().numpy()
plt.imshow(image, cmap='gray')
plt.show()
print("Label: ", labels[idx].item())
# Out:
# Label:  1

# %% [markdown]
# ### Switch to GPU

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# ### Define models

# %%
LeNetModel = LeNet(1,4).to(device)
AlexNetModel = AlexNet(1,4).to(device)

# %% [markdown]
# ### Define loss and optimizers

# %%
loss = nn.CrossEntropyLoss()
optimizerLN = torch.optim.SGD(LeNetModel.parameters(), lr=0.0005)
optimizerAN = torch.optim.SGD(AlexNetModel.parameters(), lr=0.01)

# %% [markdown]
# ### Split data into train/test

# %%
x_train, x_test = train_test_split(train_dataset,test_size=0.3, random_state=42)

# %% [markdown]
# ### Training and testing LeNet

# %%
train_loader_LN = list(DataLoader(x_train, batch_size=8, shuffle=True))
test_loader_LN = list(DataLoader(x_test, batch_size=8,  shuffle=False))

# %%
# Training and testing the model
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
epoch_times = []
num_epochs = 50
total_time = 0

for epoch in range(num_epochs):
    start_time = time.time() 
    
    train_loss, train_acc = train(LeNetModel, train_loader_LN, loss, optimizerLN, device)
    test_loss, test_acc = test(LeNetModel, test_loader_LN, loss, device)
    
    end_time = time.time() 
    epoch_time = end_time - start_time  
    total_time += epoch_time  
    epoch_times.append(epoch_time)  
    
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)

    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, Time: {epoch_time:.2f} seconds")
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

print(f"Total training and testing time: {total_time:.2f} seconds")

plot_training_metrics(train_accuracies, test_accuracies, train_losses, test_losses, epoch_times, num_epochs)
# Out:
# Epoch 10/50
# Train Loss: 1.0926, Train Accuracy: 52.71%, Time: 3.55 seconds
# Test Loss: 1.2517, Test Accuracy: 46.00%
# Epoch 20/50
# Train Loss: 0.9829, Train Accuracy: 58.43%, Time: 3.54 seconds
# Test Loss: 1.2930, Test Accuracy: 45.67%
# Epoch 30/50
# Train Loss: 0.8384, Train Accuracy: 66.04%, Time: 3.55 seconds
# Test Loss: 1.3748, Test Accuracy: 44.83%
# Epoch 40/50
# Train Loss: 0.6553, Train Accuracy: 74.82%, Time: 3.55 seconds
# Test Loss: 1.5917, Test Accuracy: 42.58%
# Epoch 50/50
# Train Loss: 0.4545, Train Accuracy: 84.43%, Time: 3.55 seconds
# Test Loss: 1.9038, Test Accuracy: 41.92%
# Total training and testing time: 176.98 seconds

# %% [markdown]
# ### Training and testing AlexNet

# %%
train_loader_AN = list(DataLoader(x_train, batch_size=64, shuffle=True))
test_loader_AN = list(DataLoader(x_test, batch_size=64,  shuffle=False))

# %%
# Training and testing the model
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
epoch_times = []
num_epochs = 50
total_time = 0

for epoch in range(num_epochs):
    start_time = time.time() 
    
    train_loss, train_acc = train(LeNetModel, train_loader_AN, loss, optimizerAN, device)
    test_loss, test_acc = test(LeNetModel, test_loader_AN, loss, device)
    
    end_time = time.time() 
    epoch_time = end_time - start_time  
    total_time += epoch_time  
    epoch_times.append(epoch_time)  
    
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)

    if (epoch + 1) % 5 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, Time: {epoch_time:.2f} seconds")
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

print(f"Total training and testing time: {total_time:.2f} seconds")

plot_training_metrics(train_accuracies, test_accuracies, train_losses, test_losses, epoch_times, num_epochs)
# Out:
# Epoch 5/50
# Train Loss: 0.6727, Train Accuracy: 74.07%, Time: 2.79 seconds
# Test Loss: 1.9060, Test Accuracy: 41.92%
# Epoch 10/50
# Train Loss: 0.6727, Train Accuracy: 74.07%, Time: 2.80 seconds
# Test Loss: 1.9060, Test Accuracy: 41.92%
# Epoch 15/50
# Train Loss: 0.6727, Train Accuracy: 74.07%, Time: 2.82 seconds
# Test Loss: 1.9060, Test Accuracy: 41.92%
# Epoch 20/50
# Train Loss: 0.6727, Train Accuracy: 74.07%, Time: 2.83 seconds
# Test Loss: 1.9060, Test Accuracy: 41.92%
# Epoch 25/50
# Train Loss: 0.6727, Train Accuracy: 74.07%, Time: 2.83 seconds
# Test Loss: 1.9060, Test Accuracy: 41.92%
# Epoch 30/50
# Train Loss: 0.6727, Train Accuracy: 74.07%, Time: 2.83 seconds
# Test Loss: 1.9060, Test Accuracy: 41.92%
# Epoch 35/50
# Train Loss: 0.6727, Train Accuracy: 74.07%, Time: 2.84 seconds
# Test Loss: 1.9060, Test Accuracy: 41.92%
# Epoch 40/50
# Train Loss: 0.6727, Train Accuracy: 74.07%, Time: 2.84 seconds
# Test Loss: 1.9060, Test Accuracy: 41.92%
# Epoch 45/50
# ...

# %% [markdown]
# ## Try to avoid overfitting

# %% [markdown]
# ### Implement models with regularization

# %% [markdown]
# #### Modified LeNet

# %%
class ModifiedLeNet(nn.Module):
    def __init__(self, num_channels, num_classes):
        super(ModifiedLeNet, self).__init__()
        self.num_channels = num_channels
        self.num_classes = num_classes
        
        self.conv1 = nn.Conv2d(self.num_channels, 6, 5, padding=2)
        self.bn1 = nn.BatchNorm2d(6)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.bn2 = nn.BatchNorm2d(16)
        
        self.pool = nn.AdaptiveAvgPool2d((5, 5))
        
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, self.num_classes)
        
        self.dp1 = nn.Dropout(p=0.5)
        self.dp2 = nn.Dropout(p=0.5)
        
    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.max_pool2d(x, (2, 2))
        
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.max_pool2d(x, (2, 2))
        
        x = self.pool(x)
        x = x.view(-1, 16 * 5 * 5)
        
        x = F.relu(self.fc1(x))
        x = self.dp1(x)
        
        x = F.relu(self.fc2(x))
        x = self.dp2(x)
        
        x = self.fc3(x)
        return x

# %% [markdown]
# #### Modified AlexNet

# %%
class ModifiedAlexNet(nn.Module):
    def __init__(self, num_channels, num_classes):
        super(ModifiedAlexNet, self).__init__()
        self.num_channels = num_channels
        self.num_classes = num_classes
        
        self.conv1 = nn.Conv2d(self.num_channels, 64, kernel_size=11, stride=4, padding=2)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu1 = nn.LeakyReLU(inplace=True)
        self.pool1 = nn.MaxPool2d(kernel_size=3, stride=2)
            
        self.conv2 = nn.Conv2d(64, 192, kernel_size=5, padding=2)
        self.bn2 = nn.BatchNorm2d(192)
        self.relu2 = nn.LeakyReLU(inplace=True)
        self.pool2 = nn.MaxPool2d(kernel_size=3, stride=2)
            
        self.conv3 = nn.Conv2d(192, 384, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(384)
        self.relu3 = nn.LeakyReLU(inplace=True)
        
        self.conv4 = nn.Conv2d(384, 256, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(256)
        self.relu4 = nn.LeakyReLU(inplace=True)
        
        self.conv5 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm2d(256)
        self.relu5 = nn.LeakyReLU(inplace=True)
        self.pool5 = nn.MaxPool2d(kernel_size=3, stride=2)
            
        self.fc1 = nn.Linear(256 * 7 * 7, 2048)
        self.relu6 = nn.LeakyReLU()
        self.dp1 = nn.Dropout(p=0.5)
        
        self.fc2 = nn.Linear(2048, 1024)
        self.relu7 = nn.LeakyReLU()
        self.dp2 = nn.Dropout(p=0.5)
        
        self.fc3 = nn.Linear(1024, self.num_classes) 
            
    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.pool1(x)
        
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.pool2(x)
        
        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu3(x)
        
        x = self.conv4(x)
        x = self.bn4(x)
        x = self.relu4(x)
        
        x = self.conv5(x)
        x = self.bn5(x)
        x = self.relu5(x)
        x = self.pool5(x)
        
        x = x.view(-1, 256 * 7 * 7)  # Adjusted based on the input size
        
        x = self.fc1(x)
        x = self.relu6(x)
        x = self.dp1(x)
        
        x = self.fc2(x)
        x = self.relu7(x)
        x = self.dp2(x)
        
        x = self.fc3(x)
        
        return x

# %% [markdown]
# ### Training and testing regularized LeNet model

# %%
# train_loader_regLN = DataLoader(x_train, batch_size=32, shuffle=True)
# test_loader_regLN = DataLoader(x_test, batch_size=32,  shuffle=False)
new_LeNet = ModifiedLeNet(1, 4).to(device)
new_optimizer_LN = torch.optim.SGD(new_LeNet.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-4)
schedulerLN = torch.optim.lr_scheduler.ReduceLROnPlateau(new_optimizer_LN, 'min', patience=5, factor=0.5)

# %%
# Training and testing the model
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
epoch_times = []
num_epochs = 50
total_time = 0

for epoch in range(num_epochs):
    start_time = time.time() 
    
    train_loss, train_acc = train(new_LeNet, train_loader_LN, loss, new_optimizer_LN, device)
    test_loss, test_acc = test(new_LeNet, test_loader_LN, loss, device)

    schedulerLN.step(test_loss)

    
    end_time = time.time() 
    epoch_time = end_time - start_time  
    total_time += epoch_time  
    epoch_times.append(epoch_time)  
    
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)

    if (epoch + 1) % 5 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, Time: {epoch_time:.2f} seconds")
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

print(f"Total training and testing time: {total_time:.2f} seconds")

plot_training_metrics(train_accuracies, test_accuracies, train_losses, test_losses, epoch_times, num_epochs)
# Out:
# Epoch 5/50
# Train Loss: 1.2502, Train Accuracy: 41.32%, Time: 3.53 seconds
# Test Loss: 1.2190, Test Accuracy: 40.92%
# Epoch 10/50
# Train Loss: 1.1609, Train Accuracy: 46.43%, Time: 3.59 seconds
# Test Loss: 1.1957, Test Accuracy: 47.58%
# Epoch 15/50
# Train Loss: 1.0514, Train Accuracy: 54.43%, Time: 3.56 seconds
# Test Loss: 1.0852, Test Accuracy: 54.83%
# Epoch 20/50
# Train Loss: 0.9373, Train Accuracy: 60.54%, Time: 3.59 seconds
# Test Loss: 0.9551, Test Accuracy: 61.58%
# Epoch 25/50
# Train Loss: 0.9097, Train Accuracy: 61.86%, Time: 3.59 seconds
# Test Loss: 0.9756, Test Accuracy: 61.08%
# Epoch 30/50
# Train Loss: 0.7417, Train Accuracy: 69.21%, Time: 3.59 seconds
# Test Loss: 0.8519, Test Accuracy: 67.17%
# Epoch 35/50
# Train Loss: 0.7163, Train Accuracy: 69.89%, Time: 3.59 seconds
# Test Loss: 0.9413, Test Accuracy: 63.83%
# Epoch 40/50
# Train Loss: 0.6149, Train Accuracy: 75.07%, Time: 3.59 seconds
# Test Loss: 1.0023, Test Accuracy: 63.67%
# Epoch 45/50
# ...

# %% [markdown]
# ### Training and testing regularized AlexNet model

# %%
# train_loader_regAN = DataLoader(x_train, batch_size=32, shuffle=True)
# test_loader_regAN = DataLoader(x_test, batch_size=32,  shuffle=False)

new_AlexNet = ModifiedAlexNet(1, 4).to(device)
new_optimizer_AN = torch.optim.SGD(new_AlexNet.parameters(), lr=0.01, momentum=0.9)
schedulerAN = torch.optim.lr_scheduler.StepLR(new_optimizer_AN, step_size=10, gamma=0.1)
num_epochs = 50

# %%
# Training and testing the model
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
epoch_times = []
num_epochs = 50
total_time = 0

for epoch in range(num_epochs):
    start_time = time.time() 
    
    train_loss, train_acc = train(new_AlexNet, train_loader_AN, loss, new_optimizer_AN, device)
    test_loss, test_acc = test(new_AlexNet, test_loader_AN, loss, device)

    schedulerAN.step()

    
    end_time = time.time() 
    epoch_time = end_time - start_time  
    total_time += epoch_time  
    epoch_times.append(epoch_time)  
    
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)

    if (epoch + 1) % 5 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, Time: {epoch_time:.2f} seconds")
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

print(f"Total training and testing time: {total_time:.2f} seconds")

plot_training_metrics(train_accuracies, test_accuracies, train_losses, test_losses, epoch_times, num_epochs)
# Out:
# Epoch 5/50
# Train Loss: 0.8304, Train Accuracy: 65.21%, Time: 5.14 seconds
# Test Loss: 3.0107, Test Accuracy: 31.25%
# Epoch 10/50
# Train Loss: 0.6539, Train Accuracy: 73.93%, Time: 5.15 seconds
# Test Loss: 1.0672, Test Accuracy: 60.08%
# Epoch 15/50
# Train Loss: 0.3661, Train Accuracy: 85.79%, Time: 5.15 seconds
# Test Loss: 0.6271, Test Accuracy: 76.42%
# Epoch 20/50
# Train Loss: 0.2717, Train Accuracy: 90.14%, Time: 5.16 seconds
# Test Loss: 0.8540, Test Accuracy: 72.42%
# Epoch 25/50
# Train Loss: 0.2229, Train Accuracy: 92.79%, Time: 5.16 seconds
# Test Loss: 0.6394, Test Accuracy: 80.00%
# Epoch 30/50
# Train Loss: 0.2094, Train Accuracy: 92.61%, Time: 5.16 seconds
# Test Loss: 0.6508, Test Accuracy: 79.67%
# Epoch 35/50
# Train Loss: 0.2064, Train Accuracy: 92.54%, Time: 5.17 seconds
# Test Loss: 0.6280, Test Accuracy: 80.83%
# Epoch 40/50
# Train Loss: 0.2045, Train Accuracy: 92.43%, Time: 5.17 seconds
# Test Loss: 0.6300, Test Accuracy: 80.83%
# Epoch 45/50
# ...

# %% [markdown]
# # Machine Learning and AI Safety

# %% [markdown]
# ## Binary Classification Problem

# %% [markdown]
# ### Create a new dataset

# %%
df = pd.read_csv("train.csv")
df = df[df['label'].isin([1, 3])]
df.loc[df['label'] == 1, 'label'] = 1
df.loc[df['label'] == 3, 'label'] = 2
df.to_csv("filtered.csv", index=False)
new_csv = pd.read_csv("filtered.csv")

# %% [markdown]
# ### Proprocess our new data

# %%
train_transform = transforms.Compose(
        [   
            transforms.CenterCrop(256), 
            transforms.Grayscale(),
            transforms.ToTensor(),
            transforms.Normalize(mean= 0.5, std=0.5)
           
        ])
test_transform = transforms.Compose(
        [
            transforms.CenterCrop(256), 
            transforms.Grayscale(),
            transforms.ToTensor(),
            transforms.Normalize(mean= 0.5, std=0.5)
        ]
    )

# %% [markdown]
# ### Split our non-biased data

# %%
x_train_non_biaise, x_test_non_biaise = train_test_split(new_csv, test_size=0.3, random_state=42)

# %%
x_train_non_biaise.to_csv("filtered_train.csv", index=False)
x_test_non_biaise.to_csv("filtered_test.csv", index=False)

# %% [markdown]
# ### Bias introduction in ImageNet and Loading data

# %% [markdown]
# #### Case where $p_0$=0.2 and $p_1$=0.8

# %%
train_dataset_biased = ButterflyDataset(
    add_bias=True,
    csv_path= "filtered_train.csv",
    img_dir= train_dir,
    transform= train_transform,
    p0 = 0.2,
    p1 = 0.8
)

train_dataset_non_biased = ButterflyDataset(
    add_bias=False,
    csv_path= "filtered_train.csv",
    img_dir= train_dir,
    transform= train_transform,
    p0 = 0.5, #doesn't matter
    p1 = 0.5 #doesn't matter
)

test_non_biased =  ButterflyDataset(
    add_bias=False,
    csv_path= "filtered_test.csv",
    img_dir= train_dir,
    transform= test_transform,
    p0 = 0.5, #doesn't matter
    p1 = 0.5 #doesn't matter
)

test_dataset_non_biased = ButterflyDataset(
    add_bias=True,
    csv_path= "filtered_test.csv",
    img_dir= train_dir,
    transform= test_transform,
    p0 = 0.5,
    p1 = 0.5
)

# %% [markdown]
# ### Define models

# %%
modelAN_biaise = ModifiedAlexNet(2,2).to(device)
modelAN_non_biaise = ModifiedAlexNet(1,2).to(device)

modelLN_biaise = ModifiedLeNet(2,2).to(device)
modelLN_non_biaise =ModifiedLeNet(1,2).to(device)

# %% [markdown]
# ### Define optimizers

# %%
optimizerAN1  = torch.optim.SGD(modelAN_biaise.parameters(), lr=0.01, momentum=0.9)
schedulerAN1 = torch.optim.lr_scheduler.StepLR(optimizerAN1, step_size=10, gamma=0.1)

optimizerAN2  = torch.optim.SGD(modelAN_non_biaise.parameters(), lr=0.01, momentum=0.9)
schedulerAN2 = torch.optim.lr_scheduler.StepLR(optimizerAN2, step_size=10, gamma=0.1)

optimizerLN1 = torch.optim.SGD(modelLN_biaise.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-4)
schedulerLN1 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizerLN1, 'min', patience=5, factor=0.5)

optimizerLN2 = torch.optim.SGD(modelLN_non_biaise.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-4)
schedulerLN2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizerLN2, 'min', patience=5, factor=0.5)

# %% [markdown]
# ### Training LeNet on biased data and testing on non-biased data

# %%
biased_train_loader_LN = list(DataLoader(train_dataset_biased, batch_size=32, shuffle=True))
test_loader_non_biased_LN = list(DataLoader(test_dataset_non_biased, batch_size=32, shuffle=False))

# %%
# Training and testing the model
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
epoch_times = []
num_epochs = 50
total_time = 0

for epoch in range(num_epochs):
    start_time = time.time() 
    
    train_loss, train_acc = train(modelLN_biaise, biased_train_loader_LN, loss, optimizerLN1, device)
    test_loss, test_acc = test(modelLN_biaise, test_loader_non_biased_LN, loss, device)

    schedulerLN1.step(test_loss)

    
    end_time = time.time() 
    epoch_time = end_time - start_time  
    total_time += epoch_time  
    epoch_times.append(epoch_time)  
    
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)

    if (epoch + 1) % 5 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, Time: {epoch_time:.2f} seconds")
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

print(f"Total training and testing time: {total_time:.2f} seconds")
plot_training_metrics(train_accuracies, test_accuracies, train_losses, test_losses, epoch_times, num_epochs)
# Out:
# Epoch 5/50
# Train Loss: 0.6875, Train Accuracy: 54.11%, Time: 2.16 seconds
# Test Loss: 0.6798, Test Accuracy: 58.66%
# Epoch 10/50
# Train Loss: 0.6700, Train Accuracy: 57.72%, Time: 2.17 seconds
# Test Loss: 0.6769, Test Accuracy: 57.31%
# Epoch 15/50
# Train Loss: 0.6592, Train Accuracy: 60.68%, Time: 2.17 seconds
# Test Loss: 0.6711, Test Accuracy: 57.82%
# Epoch 20/50
# Train Loss: 0.6331, Train Accuracy: 65.01%, Time: 2.18 seconds
# Test Loss: 0.6644, Test Accuracy: 58.99%
# Epoch 25/50
# Train Loss: 0.6141, Train Accuracy: 66.96%, Time: 2.18 seconds
# Test Loss: 0.6540, Test Accuracy: 61.34%
# Epoch 30/50
# Train Loss: 0.6027, Train Accuracy: 67.53%, Time: 2.18 seconds
# Test Loss: 0.6409, Test Accuracy: 61.85%
# Epoch 35/50
# Train Loss: 0.5642, Train Accuracy: 70.85%, Time: 2.18 seconds
# Test Loss: 0.6605, Test Accuracy: 61.18%
# Epoch 40/50
# Train Loss: 0.5153, Train Accuracy: 74.53%, Time: 2.19 seconds
# Test Loss: 0.6718, Test Accuracy: 59.16%
# Epoch 45/50
# ...

# %% [markdown]
# ### Training AlexNet on biased data and testing on non-biased data

# %%
biased_train_loader_AN = list(DataLoader(train_dataset_biased, batch_size=32, shuffle=True))
test_loader_non_biased_AN = list(DataLoader(test_dataset_non_biased, batch_size=32, shuffle=False))

# %%
# Training and testing the model
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
epoch_times = []
num_epochs = 50
total_time = 0

for epoch in range(num_epochs):
    start_time = time.time() 
    
    train_loss, train_acc = train(modelAN_biaise, biased_train_loader_AN, loss, optimizerAN1, device)
    test_loss, test_acc = test(modelAN_biaise, test_loader_non_biased_AN, loss, device)

    schedulerAN1.step()

    
    end_time = time.time() 
    epoch_time = end_time - start_time  
    total_time += epoch_time  
    epoch_times.append(epoch_time)  
    
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)

    if (epoch + 1) % 5 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, Time: {epoch_time:.2f} seconds")
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

print(f"Total training and testing time: {total_time:.2f} seconds")

plot_training_metrics(train_accuracies, test_accuracies, train_losses, test_losses, epoch_times, num_epochs)
# Out:
# Epoch 5/50
# Train Loss: 0.7034, Train Accuracy: 53.03%, Time: 2.88 seconds
# Test Loss: 0.7304, Test Accuracy: 49.92%
# Epoch 10/50
# Train Loss: 0.6966, Train Accuracy: 52.53%, Time: 2.87 seconds
# Test Loss: 0.6941, Test Accuracy: 49.92%
# Epoch 15/50
# Train Loss: 0.6903, Train Accuracy: 53.75%, Time: 2.89 seconds
# Test Loss: 0.6953, Test Accuracy: 49.92%
# Epoch 20/50
# Train Loss: 0.6909, Train Accuracy: 53.54%, Time: 2.89 seconds
# Test Loss: 0.6957, Test Accuracy: 49.92%
# Epoch 25/50
# Train Loss: 0.6925, Train Accuracy: 51.80%, Time: 2.90 seconds
# Test Loss: 0.6958, Test Accuracy: 49.92%
# Epoch 30/50
# Train Loss: 0.6919, Train Accuracy: 51.73%, Time: 2.90 seconds
# Test Loss: 0.6959, Test Accuracy: 50.08%
# Epoch 35/50
# Train Loss: 0.6909, Train Accuracy: 53.03%, Time: 2.90 seconds
# Test Loss: 0.6959, Test Accuracy: 50.08%
# Epoch 40/50
# Train Loss: 0.6911, Train Accuracy: 52.45%, Time: 2.90 seconds
# Test Loss: 0.6959, Test Accuracy: 49.92%
# Epoch 45/50
# ...

# %% [markdown]
# ### Training and testing LeNet on non-biased data

# %%
non_biased_train_loader_LN = list(DataLoader(train_dataset_non_biased, batch_size=32, shuffle=True))
new_test_loader_non_biased_LN = list(DataLoader(test_non_biased, batch_size=32, shuffle=False))

# %%
# Training and testing the model
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
epoch_times = []
num_epochs = 50
total_time = 0

for epoch in range(num_epochs):
    start_time = time.time() 
    
    train_loss, train_acc = train(modelLN_non_biaise, non_biased_train_loader_LN, loss, optimizerLN2, device)
    test_loss, test_acc = test(modelLN_non_biaise, new_test_loader_non_biased_LN, loss, device)

    schedulerLN2.step(test_loss)

    
    end_time = time.time() 
    epoch_time = end_time - start_time  
    total_time += epoch_time  
    epoch_times.append(epoch_time)  
    
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)

    if (epoch + 1) % 5 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, Time: {epoch_time:.2f} seconds")
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

print(f"Total training and testing time: {total_time:.2f} seconds")
plot_training_metrics(train_accuracies, test_accuracies, train_losses, test_losses, epoch_times, num_epochs)
# Out:
# Epoch 5/50
# Train Loss: 0.6784, Train Accuracy: 56.64%, Time: 1.67 seconds
# Test Loss: 0.6821, Test Accuracy: 55.13%
# Epoch 10/50
# Train Loss: 0.6510, Train Accuracy: 62.48%, Time: 1.69 seconds
# Test Loss: 0.6708, Test Accuracy: 58.32%
# Epoch 15/50
# Train Loss: 0.6272, Train Accuracy: 66.38%, Time: 1.69 seconds
# Test Loss: 0.6582, Test Accuracy: 57.82%
# Epoch 20/50
# Train Loss: 0.6059, Train Accuracy: 66.67%, Time: 1.70 seconds
# Test Loss: 0.6830, Test Accuracy: 59.16%
# Epoch 25/50
# Train Loss: 0.5879, Train Accuracy: 69.84%, Time: 1.69 seconds
# Test Loss: 0.6500, Test Accuracy: 62.18%
# Epoch 30/50
# Train Loss: 0.5474, Train Accuracy: 72.66%, Time: 1.70 seconds
# Test Loss: 0.7472, Test Accuracy: 54.45%
# Epoch 35/50
# Train Loss: 0.5115, Train Accuracy: 75.97%, Time: 1.70 seconds
# Test Loss: 0.5909, Test Accuracy: 67.23%
# Epoch 40/50
# Train Loss: 0.4641, Train Accuracy: 77.34%, Time: 1.70 seconds
# Test Loss: 0.6693, Test Accuracy: 63.87%
# Epoch 45/50
# ...

# %% [markdown]
# ### Training and testing AlexNet on non-biased data

# %%
non_biased_train_loader_AN = list(DataLoader(train_dataset_non_biased, batch_size=32, shuffle=True))
new_test_loader_non_biased_AN = list(DataLoader(test_non_biased, batch_size=32, shuffle=False))

# %%
# Training and testing the model
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
epoch_times = []
num_epochs = 50
total_time = 0

for epoch in range(num_epochs):
    start_time = time.time() 
    
    train_loss, train_acc = train(modelAN_non_biaise, non_biased_train_loader_AN, loss, optimizerAN2, device)
    test_loss, test_acc = test(modelAN_non_biaise, new_test_loader_non_biased_AN, loss, device)

    schedulerAN2.step()

    
    end_time = time.time() 
    epoch_time = end_time - start_time  
    total_time += epoch_time  
    epoch_times.append(epoch_time)  
    
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)

    if (epoch + 1) % 5 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, Time: {epoch_time:.2f} seconds")
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

print(f"Total training and testing time: {total_time:.2f} seconds")

plot_training_metrics(train_accuracies, test_accuracies, train_losses, test_losses, epoch_times, num_epochs)
# Out:
# Epoch 5/50
# Train Loss: 0.6596, Train Accuracy: 61.40%, Time: 2.77 seconds
# Test Loss: 0.9300, Test Accuracy: 47.06%
# Epoch 10/50
# Train Loss: 0.5589, Train Accuracy: 71.57%, Time: 2.77 seconds
# Test Loss: 0.8486, Test Accuracy: 53.61%
# Epoch 15/50
# Train Loss: 0.3709, Train Accuracy: 83.55%, Time: 2.77 seconds
# Test Loss: 0.9669, Test Accuracy: 59.16%
# Epoch 20/50
# Train Loss: 0.2633, Train Accuracy: 89.75%, Time: 2.77 seconds
# Test Loss: 1.2696, Test Accuracy: 60.00%
# Epoch 25/50
# Train Loss: 0.1769, Train Accuracy: 93.07%, Time: 2.77 seconds
# Test Loss: 0.5959, Test Accuracy: 78.99%
# Epoch 30/50
# Train Loss: 0.1455, Train Accuracy: 95.38%, Time: 2.78 seconds
# Test Loss: 0.5978, Test Accuracy: 78.15%
# Epoch 35/50
# Train Loss: 0.1346, Train Accuracy: 95.09%, Time: 2.78 seconds
# Test Loss: 0.6032, Test Accuracy: 79.83%
# Epoch 40/50
# Train Loss: 0.1278, Train Accuracy: 95.89%, Time: 2.77 seconds
# Test Loss: 0.5940, Test Accuracy: 79.83%
# Epoch 45/50
# ...

# %% [markdown]
# ### DI (Disparate Impact) metric

# %%
def DI(epsilons, labels):
    num = 0
    den=0
    eps  = 0
    noneps = 0

    for i in range(epsilons.shape[0]):
        if torch.equal(epsilons[i],torch.zeros((256,256))):
            noneps+=1
            if labels[i] == 1:        
                num+= 1
        else:
            eps+=1
            if labels[i]==1:
                den+=1
    
    if den/eps ==0:
        return float('inf')
    else:
        return (num/noneps)/(den/eps)

# %%
images1, labels1 = next(iter(test_loader_non_biased_LN))
epsilons1 = images1[:,1,:,:]
images2, labels2 = next(iter(test_loader_non_biased_AN))
epsilons2 = images2[:,1,:,:]

# %%
print("LeNet: "+str(DI(epsilons1, labels1)))
print("AlexNet: "+str(DI(epsilons2, labels2)))
# Out:
# LeNet: 2.2807017543859645
# AlexNet1.5
